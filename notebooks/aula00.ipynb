# %% [markdown]
# # Aula 00 · Primeiros passos em programação (estudo)
#
# Este é um **caderno de estudo**: você o faz sozinho, antes da primeira aula,
# junto com o [capítulo 0 do site](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/). Ele é para quem **nunca programou**, e
# vai do zero até um programa que decide e repete.
#
# **Ao fim deste caderno você consegue:**
#
# 1. guardar valores em variáveis e reconhecer os tipos básicos;
# 2. fazer o programa decidir com `if`, `elif` e `else`;
# 3. repetir com `while` e `for`;
# 4. completar uma função com `return` — o formato de todos os exercícios do curso.
#
# **Roteiro:** 🔥 aquecimento · 📟 chamado · 1. o que é um programa · 2. variáveis ·
# 3. tipos · 4. erros · 5. comparações · 6. `if` · 7. `elif` e `else` · 8. `and`,
# `or`, `not` · 9. `while` · 10. `for` · 11. juntando tudo · 12. a primeira função ·
# 📟 resolvendo o chamado · 🚪 antes de sair
#
# Tempo: umas três horas. Pode parar no meio e voltar outro dia — só lembre de rodar
# a célula ⚙️ de novo quando voltar.

# %% [markdown]
# ## Como usar este caderno
#
# 📖 [capítulo 0 · Como estudar este capítulo](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#como-estudar-este-capitulo)
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo: clique nela e aperte
#   **`Shift+Enter`** (e rode de novo se o Colab reiniciar ou se você voltar outro
#   dia).
# - **✍️ Passo:** cada passo diz o que escrever na célula vazia logo abaixo. São
#   pedaços pequenos, de uma a cinco linhas. **Digite** — não copie e cole: é
#   digitando que se aprende.
# - Depois de escrever e **antes de rodar**, escreva a sua previsão: o que você acha
#   que vai aparecer. Só então rode e abra o **▶ O que aconteceu**. Errar a
#   previsão é normal e é a parte que mais ensina.
# - **🎯 Sua vez:** escreva a solução no lugar indicado e rode a célula `confere`
#   logo abaixo dela — ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A
#   dica está recolhida: tente antes de abrir.
# - Se aparecer uma mensagem de erro em vermelho, **não se assuste**: leia a última
#   linha. A seção 4 ensina como.
# - Termo de telecom estranho? A página [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/) explica.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — sem computador
#
# Um programa guarda valores em **caixas com nome**. Imagine três instruções,
# seguidas nesta ordem:
#
# 1. ponha o número 5 na caixa **A**;
# 2. ponha o número 3 na caixa **B**;
# 3. troque o conteúdo da caixa **A** por uma cópia do que está na caixa **B**.
#
# No fim, quanto há em cada caixa?

# %% [markdown]
# <details>
# <summary><b>Resposta</b></summary>
#
# **A tem 3 e B tem 3.** No passo 3, o 5 que estava em A é jogado fora e entra uma
# *cópia* do 3 — a caixa B não fica vazia. Guarde as duas ideias: as instruções
# acontecem **em ordem**, e pôr um valor novo numa caixa **substitui** o antigo. É
# exatamente assim que as variáveis funcionam em Python.
#
# </details>

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0001 — NOC Maré Net**
# >
# > *"Seja bem-vindo à Maré Net! Antes do seu primeiro dia no NOC, uma tarefa de
# > aquecimento: o técnico de campo mediu a potência do sinal nas ONUs de uma rua
# > inteira. Pela nossa regra, potência **abaixo de −27 dBm** é crítica e precisa de
# > visita técnica. Quantas ONUs dessa rua estão críticas? Não quero a conta feita à
# > mão: quero um programa que faça a conta para qualquer rua."*
#
# A **ONU** é o aparelho na casa do cliente que recebe a internet pela fibra, e o
# **dBm** é a unidade em que se mede a força do sinal. Na fibra os valores são
# negativos, e **quanto mais negativo, mais fraco**: −20 dBm é bom, −28 dBm é fraco
# demais (veja [Potência, dB e dBm](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/#potencia-db-e-dbm)).
#
# No fim do caderno você escreve esse programa.

# %% [markdown]
# ## 1. O que é um programa
#
# Um programa é uma lista de instruções que o computador executa **de cima para
# baixo**, uma de cada vez, ao pé da letra. `print(...)` é a instrução que mostra
# alguma coisa embaixo da célula; o texto vai entre aspas.
#
# 📖 [capítulo 0 · O que é um programa](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#o-que-e-um-programa)

# %% [markdown]
# > 💡 **Pense assim: uma receita de bolo.** A receita diz o que fazer e em que ordem. O computador segue a receita sem
# > pular passos, sem adivinhar o que você quis dizer e sem corrigir erro de
# > digitação.

# %% [markdown]
# **✍️ Passo 1.** Escreva três linhas, uma embaixo da outra: `print("1. abrir o chamado")`,
# `print("2. conferir o equipamento")` e `print("3. fechar o chamado")`.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** em que ordem as três frases vão aparecer?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Aparecem na mesma ordem em que foram escritas: 1, 2, 3. O Python executa a
# primeira linha, depois a segunda, depois a terceira. Se você trocar duas linhas de
# lugar, a saída troca junto — experimente.
#
# </details>

# %% [markdown]
# **✍️ Passo 2.** Na mesma célula, escreva `Print("oi")` — com **P maiúsculo** — e rode.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** o Python vai entender o `Print` com P maiúsculo?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não: aparece `NameError: name 'Print' is not defined`. Para o Python, `print` e
# `Print` são nomes diferentes, e só o primeiro existe. É o "ao pé da letra" da
# receita: maiúsculas e minúsculas contam. Apague essa linha antes de seguir.
#
# </details>

# %% [markdown]
# ## 2. Variáveis: nomes que guardam valores
#
# Uma **variável** é um nome que guarda um valor. `clientes = 30` quer dizer
# "guarde 30 no nome `clientes`". O sinal `=` **não** é o "igual" da matemática: é
# **guarde**. Primeiro o Python calcula o lado direito, depois guarda o resultado no
# nome da esquerda.
#
# 📖 [capítulo 0 · Variáveis: nomes que guardam valores](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#variaveis-nomes-que-guardam-valores)

# %% [markdown]
# > 💡 **Pense assim: uma etiqueta numa caixa.** `clientes = 30` cola a etiqueta `clientes` numa caixa e põe 30 dentro. Usar
# > `clientes` depois é abrir a caixa e pegar o que está lá. Guardar outro valor com o
# > mesmo nome troca o conteúdo da caixa.

# %% [markdown]
# **✍️ Passo 3.** Escreva `clientes = 30` e, na linha de baixo, `print(clientes)`. Depois
# acrescente `clientes = clientes + 1` e mais um `print(clientes)`.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** a linha `clientes = clientes + 1` faz sentido? O que o segundo `print` mostra?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Mostra `30` e depois `31`. Como equação, `clientes = clientes + 1` seria absurdo;
# como instrução, quer dizer: pegue o valor atual de `clientes` (30), some 1 e guarde
# o resultado (31) de volta no mesmo nome. É assim que se conta alguma coisa num
# programa.
#
# </details>

# %% [markdown]
# **✍️ Passo 4.** Escreva `print(clientes)` sozinho numa célula. Depois, com o botão de menu do
# Colab, vá em *Ambiente de execução → Reiniciar sessão*, e rode **só** esta célula
# de novo.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** depois de reiniciar, o Python ainda lembra de `clientes`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não: depois de reiniciar, dá `NameError`. As variáveis vivem na **sessão**: só
# existem depois que a célula que as cria roda. Reiniciar apaga tudo. Rode de novo a
# célula ⚙️ e as células de cima (ou use *Executar anteriores*) antes de seguir.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** As células guardam o que foi executado **na ordem em que você executou**, não na
# > ordem em que aparecem na tela. Se algo ficar estranho, use *Ambiente de execução →
# > Reiniciar e executar tudo*.

# %% [markdown]
# ### 🎯 Sua vez — Clientes da OLT
#
# Uma OLT tem `portas = 16`, e cada porta atende `por_porta = 32` clientes. Crie a
# variável `total` com o número de clientes que a OLT atende. Use as variáveis, e não
# os números: o `*` multiplica.

# %%
portas = 16
por_porta = 32
# sua solução aqui
total = None

# %%
confere_valor("total", total, 512)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Troque o `None` por uma conta com os dois nomes: `portas * por_porta`.
#
# </details>

# %% [markdown]
# ## 3. Tipos: número, texto e verdadeiro ou falso
#
# Todo valor tem um **tipo**. Os quatro do começo: `int` (inteiro), `float` (com
# casas decimais, marcadas com **ponto**), `str` (texto, entre aspas) e `bool`
# (`True` ou `False`). `type(valor)` diz o tipo.
#
# 📖 [capítulo 0 · Tipos: número, texto e verdadeiro ou falso](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#tipos-numero-texto-e-verdadeiro-ou-falso)

# %% [markdown]
# **✍️ Passo 5.** Imprima, uma por linha: `type(16)`, `type(-21.4)`, `type("16")` e `type(True)`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** `16` e `"16"` têm o mesmo tipo?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não: `16` é `int` e `"16"`, entre aspas, é `str` — texto que por acaso tem
# dígitos. `-21.4` é `float` e `True` é `bool`. As aspas mudam tudo.
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Imprima `3 + 4` e, na linha de baixo, `"3" + "4"`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** as duas linhas dão `7`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# A primeira dá `7`; a segunda dá `34`. Com números, o `+` soma; com textos, ele
# **emenda** um no outro. O tipo decide o que a operação faz.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** A casa decimal é com **ponto**. `potencia = -21,4` (com vírgula) não dá erro:
# > o Python entende como **dois** valores, `-21` e `4`, e guarda o par. O programa
# > segue e a conta sai errada lá na frente. Escreva sempre `-21.4`.

# %% [markdown]
# ## 4. Quando dá erro: lendo a mensagem
#
# Toda mensagem de erro diz **o tipo do erro** e **a linha** em que ele apareceu.
# Leia de **baixo para cima**: a última linha é a mais importante.
#
# 📖 [capítulo 0 · Quando dá erro: lendo a mensagem](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#quando-da-erro-lendo-a-mensagem)

# %% [markdown]
# **✍️ Passo 7.** Escreva `potencia_dbm = -21.4` e, na linha de baixo, `print(potencia_dmb)` — com
# as letras **trocadas de propósito**.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** vai dar erro? Qual palavra da mensagem mostra o nome que o Python não achou?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `NameError: name 'potencia_dmb' is not defined. Did you mean: 'potencia_dbm'?`
# — o nome não existe, e o Python ainda sugere o certo ("você quis dizer…?"). Repare
# também na setinha ou no número de linha indicando **onde** está o problema. Quase
# todo erro de iniciante se resolve lendo com calma a última linha.
#
# </details>

# %% [markdown]
# > 💡 **Pense assim: a luz no painel do carro.** A luz do painel não diz só "quebrou": diz qual sistema tem problema. A
# > mensagem de erro é essa luz — leia o que está escrito antes de mexer no código.

# %% [markdown]
# ## 5. Comparações: perguntas de sim ou não
#
# Uma comparação é uma pergunta cuja resposta é `True` ou `False`: `<` (menor),
# `>` (maior), `<=`, `>=`, `==` (igual: **dois** sinais) e `!=` (diferente).
#
# 📖 [capítulo 0 · Comparações: perguntas de sim ou não](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#comparacoes-perguntas-de-sim-ou-nao)

# %% [markdown]
# **✍️ Passo 8.** Crie `potencia = -24.0` e imprima, uma por linha: `potencia < -27`,
# `potencia > -27` e `potencia == -24.0`.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** −24 é maior ou menor que −27?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `False`, `True`, `True`. −24 é **maior** que −27: está mais perto do zero,
# como −24 °C é menos frio que −27 °C. Em potência, −24 dBm é um sinal mais forte
# que −27 dBm. Com números negativos, vale a pena parar e pensar antes de comparar.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Sinal fraco?
#
# O técnico mediu `potencia = -28.3`. Crie a variável `fraco` com o **resultado da
# comparação** que pergunta se a potência está abaixo de −27. Não escreva `True`
# à mão: escreva a comparação.

# %%
potencia = -28.3
# sua solução aqui
fraco = None

# %%
confere_valor("fraco", fraco, True)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Uma comparação já vale `True` ou `False`, então pode ir direto para a variável: `fraco = potencia < ...`.
#
# </details>

# %% [markdown]
# ## 6. `if`: decidir
#
# O `if` executa um bloco **só se** a pergunta der `True`. A linha do `if` termina
# com **dois-pontos**, e as linhas de dentro ficam **recuadas** quatro espaços (a
# tecla `Tab` faz isso no Colab). A primeira linha sem recuo já está fora do `if`.
#
# 📖 [capítulo 0 · if: decidir](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#if-decidir)

# %% [markdown]
# > 💡 **Pense assim: o porteiro da festa.** O porteiro olha a pulseira: **se** tem, a pessoa entra. Quem não tem, não
# > entra, e a festa continua. O bloco recuado é o que acontece só com quem passou
# > pela porta.

# %% [markdown]
# **✍️ Passo 9.** Escreva:
#
# ```
# potencia = -28.5
# if potencia < -27:
#     print("ALERTA: sinal fraco")
#     print("abrir chamado")
# print("fim da verificacao")
# ```

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** quais das três mensagens aparecem?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# As três: a pergunta deu `True` (−28,5 é menor que −27), então as duas linhas
# recuadas rodam, e o "fim da verificacao", que está fora do `if`, roda sempre.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** Na mesma célula, troque `-28.5` por `-20.0` e rode de novo.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** e agora, quais mensagens aparecem?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Só `fim da verificacao`. A pergunta deu `False`, e o bloco recuado foi
# **pulado** inteiro. É o recuo que diz ao Python quais linhas dependem da
# pergunta.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Dois erros campeões: escrever `if potencia = -27:` com **um** sinal de igual (o
# > Python responde `SyntaxError` e sugere `==`), e esquecer os dois-pontos no fim da
# > linha do `if`. Os dois dão erro na hora — leia a mensagem.

# %% [markdown]
# ## 7. `elif` e `else`: mais de um caminho
#
# `elif` ("senão, se") faz outra pergunta, só se as de cima deram `False`. `else`
# ("senão") pega o que sobrou e não tem pergunta. O Python pergunta de cima para
# baixo e roda **só o primeiro** bloco cuja pergunta der `True`.
#
# 📖 [capítulo 0 · elif e else: mais de um caminho](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#elif-e-else-mais-de-um-caminho)

# %% [markdown]
# > 💡 **Pense assim: a triagem do pronto-socorro.** Risco de vida? Vermelho. Senão, é urgente? Amarelo. Senão: verde. Cada
# > paciente sai com **uma** cor, e a ordem das perguntas importa. O NOC classifica os
# > alarmes de rede do mesmo jeito.

# %% [markdown]
# **✍️ Passo 11.** Escreva:
#
# ```
# potencia = -26.0
# if potencia >= -25:
#     print("bom")
# elif potencia >= -27:
#     print("atencao")
# else:
#     print("critico")
# ```

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** o que sai? E se `potencia` fosse `-30.0`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Com −26 sai `atencao`: a primeira pergunta deu `False` (−26 não é maior ou igual
# a −25), a segunda deu `True`, e o resto foi pulado. Com −30, as duas perguntas dão
# `False` e sobra o `else`: `critico`. Teste os dois valores.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Classificando uma medição
#
# Para `potencia = -25.5`, crie a variável `situacao` valendo `"bom"`, `"atencao"`
# ou `"critico"`, com as mesmas regras do passo anterior. Use `if`, `elif` e `else`,
# guardando o texto na variável em vez de imprimir.

# %%
potencia = -25.5
# sua solução aqui
situacao = None

# %%
confere_valor("situacao", situacao, "atencao")

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Copie a estrutura do passo anterior e troque cada `print("...")` por
# `situacao = "..."`. Apague a linha `situacao = None` do fim, senão ela desfaz o
# seu trabalho.
#
# </details>

# %% [markdown]
# ## 8. `and`, `or` e `not`
#
# `a and b` é `True` só se **as duas** forem `True`; `a or b`, se **pelo menos
# uma** for; `not a` inverte.
#
# 📖 [capítulo 0 · and, or e not](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#and-or-e-not)

# %% [markdown]
# **✍️ Passo 12.** Crie `potencia = -28.0` e `em_servico = True`. Imprima
# `em_servico and potencia < -27`, depois `potencia < -27 or potencia > -8`, e por
# fim `not em_servico`.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** qual das três linhas dá `False`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `True`, `True`, `False`. O `and` precisava das duas (o cliente está em
# serviço **e** o sinal está fraco); o `or` precisava de uma; o `not` inverteu o
# `True`. Mude `em_servico` para `False` e veja o `and` virar `False`.
#
# </details>

# %% [markdown]
# > 💡 **Pense assim: a regra do estacionamento.** "Estaciona quem é morador **e** tem vaga": precisa das duas. "Entra de graça
# > quem é criança **ou** idoso": basta uma.

# %% [markdown]
# ## 9. `while`: repetir enquanto
#
# O `while` repete o bloco **enquanto** a pergunta der `True`. Cada divisor
# (*splitter*) que reparte o sinal em dois tira 3 dB da potência: quantos cabem até
# o sinal chegar a −27 dBm?
#
# 📖 [capítulo 0 · while: repetir enquanto](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#while-repetir-enquanto)

# %% [markdown]
# **✍️ Passo 13.** Escreva:
#
# ```
# potencia = -15.0
# divisores = 0
# while potencia > -27:
#     potencia = potencia - 3
#     divisores = divisores + 1
#     print(divisores, potencia)
# print("total:", divisores)
# ```

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** quantas linhas o laço imprime antes do `total`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Quatro: −18, −21, −24 e −27. Na quinta pergunta, `-27 > -27` dá `False` (−27 não
# é **maior** que −27), e o laço termina. `divisores` é um **contador**: começa em
# zero antes do laço e ganha 1 a cada volta.
#
# </details>

# %% [markdown]
# > 💡 **Pense assim: encher o balde.** "**Enquanto** não chegar na marca, jogue mais uma caneca." Confere-se a marca
# > antes de cada caneca. Quem esquece de jogar a água confere a marca para sempre.

# %% [markdown]
# > ⚠️ **Armadilha.** Se o bloco do `while` não mudar a variável da pergunta (apague a linha
# > `potencia = potencia - 3` para ver), a pergunta dá `True` para sempre: é o **laço
# > infinito**. A célula fica rodando sem parar — pare no botão ■ ao lado dela.

# %% [markdown]
# ## 10. `for`: repetir para cada item
#
# O `for` repete o bloco **uma vez para cada item** de uma sequência. `range(4)` gera
# 0, 1, 2 e 3 (começa no zero e para **antes** do 4); `range(1, 5)` gera 1, 2, 3 e 4.
# O `for` também percorre uma lista de valores entre colchetes.
#
# 📖 [capítulo 0 · for: repetir para cada item](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#for-repetir-para-cada-item)

# %% [markdown]
# **✍️ Passo 14.** Escreva um `for volta in range(4):` com `print("volta", volta)` recuado dentro
# dele.

# %%
# ✍️ passo 14

# %% [markdown]
# **Preveja:** quantas voltas? Qual é o primeiro número e qual é o último?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Quatro voltas: 0, 1, 2 e 3. A contagem começa no **zero** e para **antes** do 4 —
# um costume da programação que vai aparecer o curso inteiro.
#
# </details>

# %% [markdown]
# **✍️ Passo 15.** Agora `for porta in range(1, 5):` com `print("testando a porta", porta)`.

# %%
# ✍️ passo 15

# %% [markdown]
# **Preveja:** a porta 5 é testada?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não: saem as portas 1, 2, 3 e 4. O segundo número do `range` fica **de fora**.
# Para ir até 5, seria `range(1, 6)`.
#
# </details>

# %% [markdown]
# **✍️ Passo 16.** Por fim, `for potencia in [-21.4, -28.0, -19.5]:` com `print("medicao:", potencia)`.

# %%
# ✍️ passo 16

# %% [markdown]
# **Preveja:** a variável `potencia` vale o quê na segunda volta?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Vale `-28.0`. A cada volta, a variável recebe o próximo item da lista, na ordem.
# O `for` para sozinho depois do último item — você não precisa contar quantos são.
#
# </details>

# %% [markdown]
# > 💡 **Pense assim: a chamada na sala de aula.** **Para cada** nome da lista de presença, o professor chama e marca. Ele não
# > precisa saber quantos alunos são: vai do primeiro ao último. A variável do `for` é
# > o nome da vez.

# %% [markdown]
# ### 🎯 Sua vez — Somando de 1 a 10
#
# Use um `for` com `range` para somar os números de 1 a 10 na variável `soma`, que
# começa em 0. (Sim, dá 55 — mas o objetivo é o programa chegar lá sozinho.)

# %%
soma = 0
# sua solução aqui

# %%
confere_valor("soma", soma, 55)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# `for numero in range(1, 11):` e, dentro, `soma = soma + numero`. Lembre: o 11
# fica de fora, então o último número é o 10.
#
# </details>

# %% [markdown]
# ## 11. Juntando tudo
#
# Um `for` com um `if` dentro e um contador: o formato de boa parte dos programas do
# curso. O **recuo** conta a história: o que está antes do `for` roda uma vez; o que
# está dentro, uma vez por item; o que está dentro do `if`, só para os itens que
# passam na pergunta; o que está depois, uma vez no fim.
#
# 📖 [capítulo 0 · Juntando tudo](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#juntando-tudo)

# %%
# 📦 dados prontos — só rode esta célula
medicoes = [-21.4, -28.0, -19.5, -27.3, -24.8]

# %% [markdown]
# **✍️ Passo 17.** Crie `abaixo = 0`. Faça um `for potencia in medicoes:` e, dentro dele, um `if
# potencia < -27:` que soma 1 em `abaixo`. Depois do laço (sem recuo), imprima
# `abaixo`.

# %%
# ✍️ passo 17

# %% [markdown]
# **Preveja:** quanto vale `abaixo` no fim?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Vale `2`: só −28,0 e −27,3 estão abaixo de −27. Agora mova o `print` para dentro
# do `for` (quatro espaços) e rode: o valor aparece a cada volta, crescendo. O mesmo
# código, com outro recuo, faz outra coisa.
#
# </details>

# %% [markdown]
# ## 12. Uma primeira função
#
# Todo exercício do curso é uma **função** para completar. `def` define a função:
# nome, valores que ela recebe (os **parâmetros**) e o bloco recuado com a conta.
# `return` **devolve** o resultado a quem chamou. Definir não executa nada: a função
# roda quando é **chamada**, como em `margem(-21.5, -27)`.
#
# 📖 [capítulo 0 · Uma primeira função](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#uma-primeira-funcao)

# %% [markdown]
# > 💡 **Pense assim: a máquina de café.** Você põe cápsula e água (o que a função **recebe**), a máquina trabalha lá
# > dentro, e sai o café (o que ela **devolve**). Dá para usar a mesma máquina muitas
# > vezes, com cápsulas diferentes.

# %% [markdown]
# **✍️ Passo 18.** Escreva:
#
# ```
# def margem(potencia, sensibilidade):
#     resultado = potencia - sensibilidade
#     return resultado
# ```
#
# e rode.

# %%
# ✍️ passo 18

# %% [markdown]
# **Preveja:** aparece alguma coisa embaixo da célula?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Nada. `def` só **ensina** ao Python o que `margem` faz; ninguém pediu para usar
# ainda. É como escrever a receita no caderno: o bolo não aparece.
#
# </details>

# %% [markdown]
# **✍️ Passo 19.** Imprima `margem(-21.5, -27)` e, na linha de baixo, guarde `folga = margem(-26.0,
# -27)` e imprima `folga`.

# %%
# ✍️ passo 19

# %% [markdown]
# **Preveja:** quanto vale cada chamada?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `5.5` e `1.0`. Na primeira chamada, `potencia` vale −21,5 e `sensibilidade` vale
# −27 dentro da função; o `return` devolve 5,5, e a chamada inteira "vira" esse
# valor — que o `print` mostra, ou que vai para a variável `folga`.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** `print` **mostra**; `return` **devolve**. Uma função que faz `print(resultado)`
# > em vez de `return resultado` mostra o número na tela, mas devolve `None` ("nada"):
# > quem chamou não recebe o valor. A correção automática diz "devolveu None — faltou o
# > return?" quando isso acontece.

# %% [markdown]
# ### 🎯 Sua vez — Margem suficiente
#
# Complete a função `margem_ok(potencia, sensibilidade)`, que devolve `True` se a
# margem (a potência menos a sensibilidade) for de **pelo menos 3 dB**, e `False` se
# não for.

# %%
def margem_ok(potencia, sensibilidade):
    # sua solução aqui
    pass

# %%
confere(margem_ok, [((-21.5, -27), True), ((-26.0, -27), False), ((-24.0, -27), True), ((-30.0, -27), False)])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Calcule a margem numa variável e devolva a comparação dela com 3: `return margem >= 3`.
# "Pelo menos 3" inclui o próprio 3, por isso é `>=`.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O supervisor quer um programa que sirva para **qualquer rua**: uma função que
# recebe a lista de medições e devolve quantas estão críticas.

# %% [markdown]
# ### 🎯 Sua vez — Quantas ONUs críticas
#
# Complete a função `quantas_criticas(medicoes)`, que devolve quantas medições da
# lista estão **abaixo de −27 dBm**.

# %%
def quantas_criticas(medicoes):
    # sua solução aqui
    pass

# %%
confere(quantas_criticas, [(([-21.4, -28.0, -19.5, -27.3, -24.8],), 2), (([-20.0, -22.0],), 0), (([-30.0],), 1), (([],), 0)])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o programa da seção 11 dentro de uma função: contador em 0, `for` sobre
# `medicoes`, `if` somando 1, e `return` do contador **depois** do laço (sem recuo em
# relação ao `for`).
#
# </details>

# %%
# 📦 as medições da rua, enviadas pelo técnico — rode depois de completar a função
rua_das_gaivotas = [-21.4, -23.0, -28.1, -19.7, -27.9, -24.5, -26.8, -30.2, -22.3, -25.0]
print("ONUs críticas:", quantas_criticas(rua_das_gaivotas))

# %% [markdown]
# **Resposta ao chamado:** na Rua das Gaivotas, **3 ONUs** estão críticas (−28,1,
# −27,9 e −30,2 dBm) e precisam de visita técnica. Repare na −26,8: está perto do
# limite, mas ainda não o cruzou. E a função serve para a próxima rua sem mudar uma
# linha.

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Depois de `x = 5` e, em seguida, `x = x * 2`, quanto vale `x`?
# a) 5  b) 10  c) `x * 2`  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. O lado direito é calculado com o valor atual (5 × 2) e o resultado substitui
# o antigo.
#
# </details>

# %% [markdown]
# **2.** Com `potencia = -26.0`, o que este código imprime?
#
# ```python
# if potencia < -27:
#     print("critico")
# elif potencia < -25:
#     print("atencao")
# else:
#     print("bom")
# ```
#
# a) `critico`  b) `atencao`  c) `bom`  d) `atencao` e `bom`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. −26 não é menor que −27 (primeira pergunta `False`), mas é menor que −25
# (segunda `True`). Só um bloco roda, então o `else` é pulado.
#
# </details>

# %% [markdown]
# **3.** Quantas vezes `for i in range(1, 4):` repete o bloco?
# a) 1  b) 3  c) 4  d) 5

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **b**. `range(1, 4)` gera 1, 2 e 3 — o 4 fica de fora.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 00](https://lacouth.github.io/python_telecom-site/listas/lista00/) — dez exercícios curtos, com testes
#   automáticos no Colab.
# - Leia [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/): o vocabulário de telecom que as aulas usam.
# - Releia o [capítulo 0 do site](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/) no que ficou difícil. A primeira aula parte
#   daqui.
