# %% [markdown]
# # Aula 01 · O ambiente, os tipos e o primeiro script
#
# Esta aula apresenta o [capítulo 1 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/). A ideia central: **em Python o tipo vem do
# valor, não de uma declaração** — e quase todo dado que chega de um arquivo ou de
# um equipamento chega como **texto**, precisando ser convertido antes da conta.
#
# **Ao fim da aula você consegue:**
#
# 1. rodar código no Colab e entender por que a ordem de execução das células importa;
# 2. dizer o tipo de um valor e converter texto em número com `float` e `int`;
# 3. escolher entre `/`, `//` e `%`, e converter mW em dBm.
#
# **Roteiro:** 🔥 aquecimento · 📟 chamado · 1. onde o código roda · 2. o primeiro
# script · 3. os tipos · 4. as contas · 5. a conta do dBm · 6. nomes de variáveis ·
# 📟 resolvendo o chamado · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **✍️ Passo:** o código é escrito ao vivo, em pedaços pequenos — a instrução
#   está logo acima de cada célula vazia. Estudando sozinho, escreva você mesmo; o
#   código completo está no capítulo do site (links 📖).
# - Depois de escrever e **antes de rodar**, registre a sua previsão. Só então rode
#   e abra o **▶ O que aconteceu**. A previsão errada é a parte que ensina — não a
#   apague.
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica e uma solução
#   estão recolhidas: tente antes de abrir.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — o que você já sabe
#
# Sem rodar nada: o que este trecho imprime?
#
# ```python
# medicoes = [-20.5, -28.0, -19.0]
# ruins = 0
# for m in medicoes:
#     if m < -27:
#         ruins = ruins + 1
# print(ruins)
# ```

# %% [markdown]
# <details>
# <summary><b>Resposta</b></summary>
#
# Imprime `1`. Só `-28.0` é menor que `-27`. Repare que `-19.0` é **maior** que
# `-27` — com números negativos, "mais perto de zero" é maior. Em potência óptica
# isso quer dizer: sinal mais forte.
#
# </details>

# %% [markdown]
# > 🔁 **Relembre antes de começar.**
# >
# > Se `if`, `for` ou `def` ainda soam estranhos, faça antes o
# > [Capítulo 0](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/) e o caderno
# > de estudo dele. E se *dBm*, *OLT* ou *ONU* não dizem nada, leia
# > [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/): este
# > capítulo usa esses termos desde o primeiro exemplo.

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0101 — NOC Maré Net**
# >
# > *"Bem-vindo ao NOC, estagiário. Primeiro chamado: um cliente reclamou de
# > internet lenta e o técnico mediu **0,02 mW** na ONU dele. A nossa planilha só
# > fala em **dBm**, e o limite de recepção da ONU é **−27 dBm**. Isso é quantos
# > dBm? Está dentro do limite?"*
#
# No fim da aula você escreve a conta em Python — e ela passa a servir para
# qualquer medição, não só para esta.

# %% [markdown]
# ## 1. Onde o código roda
#
# Você está num **caderno do Colab**: Python já instalado, no navegador. Escreve-se
# o código numa célula e aperta-se **`Shift+Enter`**; o resultado aparece embaixo.
#
# 📖 [capítulo 1 · Onde o código roda](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#onde-o-codigo-roda)

# %% [markdown]
# > 💡 **Pense assim: a lousa da sala.**
# >
# > O caderno é como uma lousa em que cada célula é um quadro. Rodar uma célula é
# > copiar o que está naquele quadro para a memória do Python. Se você apaga e
# > reescreve o quadro 2 depois de já ter rodado o 3, a memória guarda a última coisa
# > que foi copiada — não o que está escrito na tela. *Reiniciar e executar tudo*
# > apaga a memória e copia os quadros de novo, em ordem.

# %% [markdown]
# **✍️ Passo 1.** Escreva `site = "OLT-CENTRO-01"` e rode. Depois, na **mesma** célula, acrescente
# uma segunda linha `print(site)` e rode de novo.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** na primeira vez, sem o `print`, aparece alguma coisa embaixo da célula?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Na primeira vez não aparece nada: atribuir não imprime. Na segunda, aparece
# `OLT-CENTRO-01`. A variável `site` passou a existir **na sessão** a partir do
# momento em que a célula rodou — e continua existindo para as células de baixo.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** As células guardam o que foi executado **na ordem em que você executou**, não na
# > ordem em que aparecem na tela. Se algo ficar estranho — uma variável com valor
# > antigo, um nome que "não existe" —, use *Ambiente de execução → Reiniciar e
# > executar tudo*. Isso resolve a maioria dos mistérios.

# %% [markdown]
# ## 2. O primeiro script
#
# Um script é uma sequência de linhas que rodam de cima para baixo. O `print`
# mostra valores; a **f-string** monta um texto com valores dentro — é o jeito
# padrão de montar texto em Python, e vai aparecer no curso inteiro.
#
# 📖 [capítulo 1 · O primeiro script](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#o-primeiro-script)

# %% [markdown]
# > 💡 **Pense assim: um formulário com lacunas.**
# >
# > `f"{site} esta em {potencia_dbm} dBm"` é um formulário com dois espaços em branco:
# > "___ está em ___ dBm". As chaves marcam as lacunas, e o Python preenche cada uma
# > com o valor atual da variável. Sem o `f` na frente, as chaves são impressas como
# > estão, e as lacunas ficam sem preencher.

# %% [markdown]
# **✍️ Passo 2.** Crie `potencia_dbm = -21.4` e imprima, com um único `print`, três coisas separadas
# por vírgula: `"potencia:"`, `potencia_dbm` e `"dBm"`.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** o que aparece entre as três partes na saída?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `potencia: -21.4 dBm`. O `print` com vários argumentos separados por vírgula
# põe **um espaço** entre eles, sozinho.
#
# </details>

# %% [markdown]
# **✍️ Passo 3.** Imprima `f"{site} esta em {potencia_dbm} dBm"`. Na linha de baixo, imprima a
# **mesma** coisa, mas **sem o `f`** antes das aspas.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** o que muda na saída quando o `f` some?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Com o `f`, as chaves são trocadas pelos valores: `OLT-CENTRO-01 esta em -21.4 dBm`.
# Sem o `f`, o Python não olha dentro das chaves e imprime o texto literalmente,
# com `{site}` e tudo. Uma letra de diferença, e nenhuma mensagem de erro.
#
# </details>

# %% [markdown]
# ## 3. Os tipos: o tipo vem do valor
#
# Em Python não se declara o tipo da variável — mas ela **tem** tipo, e ele vem do
# valor que você atribui. Os quatro que resolvem quase tudo no começo: `int`,
# `float`, `str` e `bool`.
#
# 📖 [capítulo 1 · Os tipos que você vai encontrar](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#os-tipos-que-voce-vai-encontrar)

# %% [markdown]
# > 💡 **Pense assim: o número anotado no papel.**
# >
# > Um telefone anotado num papel é uma sequência de símbolos: dá para ler, copiar,
# > comparar, mas não dá para somar dois telefones. Um valor lido de um arquivo ou de
# > um equipamento chega assim, como **texto** — `"-21.4"`, com aspas. `float()` e
# > `int()` são o ato de ler aqueles símbolos **como número**, e só depois disso a
# > conta funciona.

# %% [markdown]
# **✍️ Passo 4.** Crie `quantidade = 12`, `potencia = -21.4` e `no_ar = True`. Imprima o `type()` de
# cada um e também `type(site)`.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** que tipo sai para cada uma das quatro variáveis?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `int`, `float`, `bool` e `str`. Ninguém disse o tipo: ele saiu do valor. `12` sem
# ponto é inteiro; `-21.4`, com ponto, é real; `True` é booleano; entre aspas é
# texto.
#
# </details>

# %% [markdown]
# **✍️ Passo 5.** O valor lido de um arquivo chega como texto. Escreva `lido = "3"` e, na linha de
# baixo, `print(lido + 4)`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** esta célula vai dar erro. Antes de rodar: **qual** erro, e em que linha?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `TypeError` na linha do `print`, dizendo que só dá para concatenar `str` com `str`.
# O Python não adivinha que `"3"` era para ser um número: entre texto e número, o
# `+` não sabe se é soma ou concatenação, e se recusa.
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Agora converta antes da conta: imprima `float("-21.4") + 1`, depois
# `int("42") * 2` e, por fim, `str(-21.4) + " dBm"`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** cada uma das três linhas dá número ou texto?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# As duas primeiras dão número (`-20.4` e `84`); a terceira dá o texto `-21.4 dBm`.
# `float()` e `int()` transformam texto em número; `str()` faz o caminho de volta.
# **Toda leitura de arquivo, de CSV e de equipamento chega como `str`** — a conversão
# é o primeiro passo de quase todo programa deste curso.
#
# </details>

# %% [markdown]
# **✍️ Passo 7.** Escreva `print(potencia_dmb)` — com as letras trocadas de propósito.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** o Python vai reclamar? Do quê, e quando?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `NameError: name 'potencia_dmb' is not defined`. O erro de digitação **não aparece
# enquanto você escreve**: aparece quando a linha roda. Leia sempre a última linha da
# mensagem de erro — ela diz o tipo do erro e o nome que o Python não achou.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Somando a margem
#
# O equipamento devolveu a potência como texto em `lido`. Crie a variável
# `com_margem` com essa potência **somada a 3 dB**, como número.

# %%
lido = "-21.4"   # chegou do equipamento como texto
# sua solução aqui
com_margem = None

# %%
confere_valor("com_margem", com_margem, -18.4)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Somar `lido + 3` dá erro — o texto precisa virar número antes. Qual das funções
# do passo anterior transforma `"-21.4"` em `-21.4`?
#
# </details>

# %% [markdown]
# ## 4. As contas: `/`, `//`, `%` e `**`
#
# `/` é a divisão de verdade e **sempre** devolve `float`. `//` é a divisão inteira,
# `%` é o resto, `**` é a potência. A dupla `//` e `%` resolve hora, minuto e
# segundo — e qualquer pergunta do tipo "quantos inteiros cabem".
#
# 📖 [capítulo 1 · Contas: as quatro que você vai repetir](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#contas-as-quatro-que-voce-vai-repetir)

# %% [markdown]
# **✍️ Passo 8.** Imprima, uma por linha: `7 / 2`, `7 // 2`, `7 % 2` e `2 ** 10`.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** a primeira linha dá `3` ou `3.5`? E a segunda?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `3.5`, `3`, `1` e `1024`. `/` preserva a parte fracionária mesmo entre inteiros;
# quando você quer o `3` — quantos cabos de 50 m cabem em 175 m, quantos racks
# completos —, peça com `//`. Usar `/` no lugar de `//` não dá erro: o programa
# roda e entrega `3.5` cabos.
#
# </details>

# %% [markdown]
# **✍️ Passo 9.** Imprima `10 / 3` e, na linha de baixo, `round(10 / 3, 2)`.

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** quantas casas decimais aparecem em cada linha?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# A primeira sai com uma cauda enorme de casas; a segunda, `3.33`. `round(valor, casas)`
# aparece em quase todo exercício do curso por isso: ninguém quer dezesseis casas
# num relatório de potência.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** Um enlace ficou `total = 3661` segundos fora do ar. Imprima numa linha só:
# `total // 3600`, `total % 3600 // 60` e `total % 60`.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** o que cada um dos três números significa?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `1 1 1`: **1 hora, 1 minuto e 1 segundo**. `// 3600` conta as horas inteiras;
# `% 3600` é o que sobra depois delas, e `// 60` desse resto dá os minutos; `% 60`
# dá os segundos que sobram.
#
# </details>

# %% [markdown]
# **✍️ Passo 11.** Com número negativo: imprima `5 // 2` e depois `-5 // 2`.

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** `-5 // 2` dá `-2` ou `-3`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Dá `-3`. O `//` não "corta a parte decimal": ele **arredonda para baixo**, e para
# baixo de `-2.5` é `-3`. Com positivos dá no mesmo, por isso quase ninguém percebe.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Tempo fora do ar
#
# O enlace ficou `segundos = 7384` fora do ar. Crie as variáveis `horas`, `minutos`
# e `resto_segundos` com a duração no formato horas, minutos e segundos.

# %%
segundos = 7384
# sua solução aqui
horas = None
minutos = None
resto_segundos = None

# %%
confere_valor("horas", horas, 2)
confere_valor("minutos", minutos, 3)
confere_valor("resto_segundos", resto_segundos, 4)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É a mesma conta do passo com `3661`, trocando o número. `// 3600` para as horas,
# `% 3600 // 60` para os minutos, `% 60` para os segundos.
#
# </details>

# %% [markdown]
# ## 5. A conta que abre qualquer projeto de telecom
#
# Potência óptica se mede em **dBm**: a mesma grandeza numa escala logarítmica,
# tendo 1 mW como referência. Em dB, ganhos e perdas ao longo do enlace viram **soma
# e subtração** em vez de multiplicação e divisão:
#
# $$P_{dBm} = 10 \cdot \log_{10}(P_{mW})$$
#
# O `log10` está no módulo `math`, que é preciso **importar**: `import math` abre a
# caixa, e `math.log10(...)` usa o que tem dentro.
#
# 📖 [capítulo 1 · A conta que abre qualquer projeto de telecom](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#a-conta-que-abre-qualquer-projeto-de-telecom)

# %% [markdown]
# > 📡 **Na rede: potência e dBm.**
# >
# > **Potência** é a força do sinal que chega pela fibra — quanta luz chega à ONU, o
# > aparelho na casa do cliente. Ela é minúscula (milésimos de miliwatt), e por isso
# > se mede em **dBm**: 0 dBm é 1 miliwatt, e valores negativos são menores que isso.
# > Na fibra quase tudo é negativo, e **quanto mais negativo, mais fraco**: −20 dBm é
# > um sinal bom; abaixo de −27 dBm, a ONU da Maré Net pode deixar de entender o sinal.
# > O **enlace** é a ligação entre dois pontos (a central e a casa, duas antenas).
# > Veja [Potência, dB e dBm](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/#potencia-db-e-dbm).

# %% [markdown]
# > 💡 **Pense assim: a caixa de ferramentas emprestada.**
# >
# > O Python já vem com as ferramentas básicas à mão (`print`, `round`, `int`). As
# > outras ficam guardadas em caixas separadas, os módulos, para não pesar: `math` é a
# > caixa das contas científicas. `import math` é ir buscar essa caixa uma vez; daí em
# > diante, `math.log10` quer dizer "a ferramenta `log10` da caixa `math`".

# %% [markdown]
# **✍️ Passo 12.** Escreva `import math`, crie `potencia_mw = 0.001` e calcule
# `potencia_dbm = 10 * math.log10(potencia_mw)`. Imprima `potencia_dbm`. Depois faça
# o caminho de volta, `10 ** (potencia_dbm / 10)`, e imprima.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** 0,001 mW dá quantos dBm? E o caminho de volta devolve o valor original?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `-30.0` e depois `0.001`. Cada fator de 10 abaixo de 1 mW são 10 dB a menos:
# 0,1 mW é −10 dBm, 0,01 é −20, 0,001 é −30. O caminho de volta desfaz a conta — é
# útil para conferir.
#
# </details>

# %% [markdown]
# **✍️ Passo 13.** Imprima `round(10 * math.log10(2), 2)`, depois o mesmo com `4` e com `8`.

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** o dobro da potência dá quantos dB a mais? E quatro vezes? E oito?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `3.01`, `6.02` e `9.03`. **3 dB é o dobro da potência**, e a cada dobra somam-se
# mais 3 dB: é a escala logarítmica transformando multiplicação em soma. Um enlace
# que perde 3 dB entregou **metade** do que recebeu.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Achar que a escala logarítmica é só coisa de prova. **+3 dB é o dobro, −3 dB é a
# > metade** — é a conta que se faz de cabeça em campo, e o Python aqui serve para
# > conferir a intuição, não para substituí-la.

# %% [markdown]
# ### 🎯 Sua vez — Razão em dB
#
# Escreva `razao_para_db(razao)`, que recebe quantas vezes a potência mudou e devolve
# o valor em dB **arredondado com 2 casas**.

# %%
import math


def razao_para_db(razao):
    # sua solução aqui
    pass

# %%
confere(razao_para_db, [
    ((2,), 3.01),
    ((4,), 6.02),
    ((0.5,), -3.01),
    ((1,), 0.0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É a conta do passo anterior, com `razao` no lugar do `2`, dentro de um `return`.
# Repare no terceiro caso: metade da potência dá dB **negativo**.
#
# </details>

# %% [markdown]
# ## 6. Escolhendo o nome das variáveis
#
# O padrão de Python é `minusculas_com_underscore`, e o nome deve dizer a grandeza
# **e a unidade** quando houver ambiguidade: `potencia_dbm`, não `p`.
#
# 📖 [capítulo 1 · Escolhendo o nome das variáveis](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#escolhendo-o-nome-das-variaveis)

# %% [markdown]
# > ⚠️ **Armadilha.** Confundir `mW` com `dBm` é um erro que aparece em relatório de campo: `-21.4` e
# > `0.007` são a mesma potência, e uma variável chamada só `potencia` não diz qual
# > das duas ela guarda. O nome da variável é a defesa mais barata contra isso.

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# Hora de responder ao supervisor com uma conta que serve para qualquer medição.

# %% [markdown]
# ### 🎯 Sua vez — mW para dBm
#
# Escreva duas funções:
#
# - `mw_para_dbm(potencia_mw)`, que devolve a potência em dBm **arredondada com 2
#   casas**;
# - `sinal_ok(potencia_mw)`, que devolve `True` se a potência, em dBm, está **entre
#   −27 e −8 dBm** (inclusive), e `False` caso contrário.

# %%
import math


def mw_para_dbm(potencia_mw):
    # sua solução aqui
    pass


def sinal_ok(potencia_mw):
    pass

# %%
confere(mw_para_dbm, [((0.02,), -16.99), ((1,), 0.0), ((0.001,), -30.0), ((2,), 3.01)])
confere(sinal_ok, [((0.02,), True), ((0.001,), False), ((1,), False), ((0.002,), True)])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# `sinal_ok` pode **usar** `mw_para_dbm`: converta primeiro, depois compare. Em
# Python dá para escrever a faixa de uma vez: `-27 <= dbm <= -8`.
#
# </details>

# %% [markdown]
# **Resposta ao chamado:** 0,02 mW são cerca de **−17 dBm** — dentro do limite, e
# com folga de uns 10 dB. A lentidão do cliente não é falta de sinal óptico: o
# chamado segue para a equipe de rede.

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Qual o valor e o tipo de `9 / 3`?
# a) `3`, int  b) `3.0`, float  c) `3.0`, int  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. `/` sempre devolve `float`, mesmo quando a divisão é exata.
#
# </details>

# %% [markdown]
# **2.** Depois de `x = "3.5"`, qual expressão dá o número `7.0`?
# a) `x * 2`  b) `int(x) * 2`  c) `float(x) * 2`  d) `x + x`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **c**. `int("3.5")` dá `ValueError` — `int` não aceita parte decimal em texto. E
# `x * 2` dá `"3.53.5"`: texto vezes 2 repete o texto.
#
# </details>

# %% [markdown]
# **3.** Um técnico mediu 2 mW num ponto e 1 mW no seguinte. A perda foi de:
# a) 1 dB  b) 2 dB  c) 3 dB  d) 50 dB

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **c**. Metade da potência é −3 dB.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 01](https://lacouth.github.io/python_telecom-site/listas/lista01/) — tipos,
#   contas e dBm, com testes automáticos no Colab.
# - Releia o [capítulo 1 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/).
# - **Na próxima aula:** mini-teste sobre esta aula (tipos, divisão e dBm).
