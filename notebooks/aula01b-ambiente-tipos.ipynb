# %% [markdown]
# # Aula 01B · O ambiente, os tipos e o primeiro script
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 1 do
# site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula01a-ambiente-tipos.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 01, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# Qual o valor e o tipo de `9 / 3`?
# a) `3`, int  b) `3.0`, float  c) `3.0`, int  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. `/` sempre devolve `float`, mesmo quando a divisão é exata.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **Antes da conta, o tipo e a unidade.** Todo número desta noite chegou de algum lugar — um arquivo, um equipamento, a
# anotação de um técnico — e chegou com um **tipo** e uma **unidade**. Antes de
# escrever a conta, faça as duas perguntas:
#
# - isto é **texto** ou **número**? Se for texto, converta primeiro (`float`, `int`);
# - está em **mW** ou em **dBm**? Em **segundos** ou em **horas**?
#
# A conta com o tipo errado quebra na hora. A conta com a unidade errada roda, dá um
# número e está errada — é essa que chega ao relatório.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Vem do bloco *4. As contas: `/`, `//`, `%` e `**`* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 1 · Contas: as quatro que você vai repetir](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#contas-as-quatro-que-voce-vai-repetir)

# %% [markdown]
# ### 🎯 Sua vez — Tempo fora do ar
#
# O enlace ficou `segundos = 7384` fora do ar. Crie as variáveis `horas`, `minutos`
# e `resto_segundos` com a duração no formato horas, minutos e segundos.

# %%
segundos = 7384
# sua solução aqui
horas = None
minutos = None
resto_segundos = None

# %%
confere_valor("horas", horas, 2)
confere_valor("minutos", minutos, 3)
confere_valor("resto_segundos", resto_segundos, 4)

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É a mesma conta do passo com `3661`, trocando o número. `// 3600` para as horas,
# `% 3600 // 60` para os minutos, `% 60` para os segundos.
#
# </details>

# %% [markdown]
# Vem do bloco *5. A conta que abre qualquer projeto de telecom* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 1 · A conta que abre qualquer projeto de telecom](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/#a-conta-que-abre-qualquer-projeto-de-telecom)

# %% [markdown]
# ### 🎯 Sua vez — Razão em dB
#
# Escreva `razao_para_db(razao)`, que recebe quantas vezes a potência mudou e devolve
# o valor em dB **arredondado com 2 casas**.

# %%
import math


def razao_para_db(razao):
    # sua solução aqui
    pass

# %%
confere(razao_para_db, [
    ((2,), 3.01),
    ((4,), 6.02),
    ((0.5,), -3.01),
    ((1,), 0.0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É a conta do passo anterior, com `razao` no lugar do `2`, dentro de um `return`.
# Repare no terceiro caso: metade da potência dá dB **negativo**.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #0101 — NOC Maré Net**
# >
# > *"Bem-vindo ao NOC, estagiário. Primeiro chamado: um cliente reclamou de
# > internet lenta e o técnico mediu **0,02 mW** na ONU dele. A nossa planilha só
# > fala em **dBm**, e o limite de recepção da ONU é **−27 dBm**. Isso é quantos
# > dBm? Está dentro do limite?"*
#
# Hora de responder ao supervisor com uma conta que serve para qualquer medição.

# %% [markdown]
# ### 🎯 Sua vez — mW para dBm
#
# Escreva duas funções:
#
# - `mw_para_dbm(potencia_mw)`, que devolve a potência em dBm **arredondada com 2
#   casas**;
# - `sinal_ok(potencia_mw)`, que devolve `True` se a potência, em dBm, está **entre
#   −27 e −8 dBm** (inclusive), e `False` caso contrário.

# %%
import math


def mw_para_dbm(potencia_mw):
    # sua solução aqui
    pass


def sinal_ok(potencia_mw):
    pass

# %%
confere(mw_para_dbm, [((0.02,), -16.99), ((1,), 0.0), ((0.001,), -30.0), ((2,), 3.01)])
confere(sinal_ok, [((0.02,), True), ((0.001,), False), ((1,), False), ((0.002,), True)])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# `sinal_ok` pode **usar** `mw_para_dbm`: converta primeiro, depois compare. Em
# Python dá para escrever a faixa de uma vez: `-27 <= dbm <= -8`.
#
# </details>

# %% [markdown]
# **Resposta ao chamado:** 0,02 mW são cerca de **−17 dBm** — dentro do limite, e
# com folga de uns 10 dB. A lentidão do cliente não é falta de sinal óptico: o
# chamado segue para a equipe de rede.

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 01](https://lacouth.github.io/python_telecom-site/listas/lista01/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista01.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `mw_para_dbm`**

# %% [markdown]
# **1.** Você já escreveu esta conta hoje, no chamado. O que muda no ex01?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# Só o nome do parâmetro (`mw`) e o lugar: agora ela roda no caderno da lista, com os testes de lá. Escreva de novo, sem copiar — é a segunda vez que fixa.
#
# </details>

# %% [markdown]
# **2.** Em que ordem vêm a conta e o arredondamento?

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# A conta primeiro, `10 * math.log10(mw)`, guardada numa variável; o `round(..., 2)` por último, sobre o resultado. Arredondar antes estraga a conta.
#
# </details>

# %% [markdown]
# **3.** Como conferir sem o teste?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# À mão, com os dois casos do enunciado: 1 mW é 0 dBm, e 0,001 mW é −30 dBm. Se deu `30.0`, o sinal sumiu em algum lugar.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Com `segundos = 7384`, quanto vale `segundos // 3600`?
# a) `2.05`  b) `2`  c) `3`  d) `2.0`

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. `//` descarta a parte fracionária: 7384 segundos são 2 horas completas e mais um pouco, e o "mais um pouco" é o `%`.
#
# </details>

# %% [markdown]
# **2.** `round(10 * math.log10(0.5), 2)` dá:
# a) `-3.01`  b) `3.01`  c) `-0.5`  d) `0.5`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **a**. Metade da potência é −3 dB — a mesma conta da perda entre 2 mW e 1 mW.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 01](https://lacouth.github.io/python_telecom-site/listas/lista01/) — tipos,
#   contas e dBm, com testes automáticos no Colab.
# - Releia o [capítulo 1 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/01-ambiente-tipos/).
# - **Na próxima noite A:** mini-teste sobre esta aula (tipos, divisão e dBm).
