# %% [markdown]
# # Aula 02 · Strings
#
# Esta aula apresenta o [capítulo 2 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/). A ideia central: **quase tudo que sai de um
# equipamento é texto** — log, identificador, IP, saída de comando. Saber fatiar,
# limpar, separar e montar texto é o que transforma uma linha de log num dado.
#
# **Ao fim da aula você consegue:**
#
# 1. pegar pedaços de uma string por posição, inclusive do fim para o começo;
# 2. explicar por que `bruto.strip()` sozinho não muda `bruto`;
# 3. separar uma linha de log em campos com `split` e montar um relatório alinhado
#    com f-string.
#
# **Roteiro:** 📟 chamado · 🔥 aquecimento · 1. a string é uma sequência · 2. os
# métodos · 3. `split` e `join` · 4. dissecando uma linha de log · 5. f-strings ·
# 📟 resolvendo o chamado · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **✍️ Passo:** o código é escrito ao vivo, em pedaços pequenos — a instrução
#   está logo acima de cada célula vazia. Estudando sozinho, escreva você mesmo; o
#   código completo está no capítulo do site (links 📖).
# - Depois de escrever e **antes de rodar**, registre a sua previsão. Só então rode
#   e abra o **▶ O que aconteceu**. A previsão errada é a parte que ensina — não a
#   apague.
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica e uma solução
#   estão recolhidas: tente antes de abrir.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0207 — NOC Maré Net**
# >
# > *"Estagiário, o painel de alarmes caiu e só temos o syslog cru. Chegam linhas
# > assim:*
# >
# > `2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3`
# >
# > *Preciso que cada linha vire um resumo curto — **hora, severidade, equipamento
# > e mensagem** —, para a equipe de campo ler no celular."*
#
# No fim da aula você escreve a função que faz essa conversão.

# %% [markdown]
# ## 🔥 Aquecimento — da aula passada
#
# Sem rodar nada: o que este trecho imprime?
#
# ```python
# total = 125
# print(total // 60, total % 60)
# print(type(total / 5))
# ```

# %% [markdown]
# <details>
# <summary><b>Resposta</b></summary>
#
# Imprime `2 5` (2 minutos e 5 segundos) e `<class 'float'>`. A divisão com `/`
# **sempre** devolve `float`, mesmo quando é exata — `125 / 5` dá `25.0`.
#
# </details>

# %% [markdown]
# ## 1. A string é uma sequência
#
# Uma string é uma **sequência de caracteres**, cada um numa posição que começa em
# **0**. Com colchetes pega-se um caractere; com dois-pontos, um **pedaço** (fatia).
# Índice negativo conta do fim.
#
# 📖 [capítulo 2 · Uma string é uma sequência](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#uma-string-e-uma-sequencia)

# %% [markdown]
# **✍️ Passo 1.** Crie `identificador = "OLT-CENTRO-01"` e imprima `len(identificador)`,
# `identificador[0]` e `identificador[-1]`.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** quantos caracteres tem o identificador? O que é o índice `-1`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `13`, `O` e `1`. O primeiro caractere está na posição **0**, e `-1` é o último —
# sem precisar saber o tamanho.
#
# </details>

# %% [markdown]
# **✍️ Passo 2.** Imprima `identificador[0:3]` e `identificador[4:10]`.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** o caractere da posição 10 entra na fatia `[4:10]`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `OLT` e `CENTRO`. O primeiro número **entra**, o segundo **fica de fora**:
# `[4:10]` pega as posições 4 a 9. Por isso `[0:3]` tem exatamente 3 caracteres.
#
# </details>

# %% [markdown]
# **✍️ Passo 3.** Imprima `identificador[-2:]`, `identificador[3:]` e `identificador[:3]`.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** o que acontece quando um dos lados dos dois-pontos fica vazio?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `01`, `-CENTRO-01` e `OLT`. Lado vazio quer dizer "desde o começo" ou "até o fim".
# `[-2:]` pega os dois últimos **sem saber o tamanho** — e continua certo com
# `"ONU-SUL-4512"`, sem mudar nada.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Contar posições na mão e escrever `identificador[11:13]` para pegar o final.
# > Funciona para este identificador e quebra no próximo, de tamanho diferente.
# > `[-2:]` diz o que você quer: os dois últimos.

# %% [markdown]
# **✍️ Passo 4.** Tente trocar a primeira letra: `identificador[0] = "X"`.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** funciona? O que acontece?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `TypeError`: a string **não aceita atribuição** a um item. String é **imutável** —
# depois de criada, não muda. Para "mudar" uma string, monta-se **outra**, com
# fatias ou métodos.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — O número do site
#
# Escreva `numero_do_site(identificador)`, que devolve os **dois últimos**
# caracteres do identificador.

# %%
def numero_do_site(identificador):
    # sua solução aqui
    pass

# %%
confere(numero_do_site, [
    (("OLT-CENTRO-01",), "01"),
    (("ONU-SUL-4512",), "12"),
    (("SWITCH-NORTE-02",), "02"),
])

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def numero_do_site(identificador):
#     return identificador[-2:]
# ```
#
# </details>

# %% [markdown]
# ## 2. Os métodos que resolvem o dia a dia
#
# Métodos são funções que vêm junto da string: `texto.strip()`, `texto.upper()`,
# `texto.replace(a, b)`… Como a string é imutável, **todo método devolve uma string
# nova** — a original fica como estava.
#
# 📖 [capítulo 2 · Os métodos que resolvem o dia a dia](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#os-metodos-que-resolvem-o-dia-a-dia)

# %% [markdown]
# **✍️ Passo 5.** Crie `bruto = "  olt-centro-01  "` (com espaços dos dois lados). Imprima
# `repr(bruto.strip())` e `bruto.strip().upper()`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** o que o `repr` mostra de diferente de um `print` comum?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `'olt-centro-01'` e `OLT-CENTRO-01`. O `repr` mostra as **aspas**, e assim dá para
# ver que os espaços sumiram. Métodos podem ser encadeados: o `.upper()` age sobre o
# que o `.strip()` devolveu.
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Agora escreva `bruto.strip()` numa linha **sozinha** e, embaixo,
# `print(repr(bruto))`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** depois do `.strip()`, o que tem em `bruto`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `'  olt-centro-01  '` — os espaços continuam lá. O `.strip()` devolveu uma string
# nova e ninguém a guardou. Para manter o resultado:
# `bruto = bruto.strip()`.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Chamar o método e seguir em frente. `bruto.strip()` sozinho não faz nada — e **não
# > dá erro**: o programa roda com o texto sujo, e a comparação `bruto == "OLT-CENTRO-01"`
# > dá `False` sem ninguém entender por quê. É o defeito mais comum das primeiras
# > listas.

# %% [markdown]
# **✍️ Passo 7.** Imprima `"OLT-CENTRO-01".replace("-", "_")`, `"OLT-CENTRO-01".startswith("OLT")`,
# `"CENTRO" in "OLT-CENTRO-01"` e `"OLT-CENTRO-01".count("-")`.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** quais dessas linhas dão texto, quais dão `True`/`False` e qual dá número?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `OLT_CENTRO_01` (texto), `True`, `True` e `2` (número). `startswith` e `in`
# respondem perguntas de sim ou não; `count` conta; `replace` monta uma string nova
# com as trocas.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Normalizar o nome
#
# Nomes de equipamento chegam digitados de todo jeito. Escreva `normaliza(nome)`, que
# devolve o nome **sem espaços nas pontas** e em **maiúsculas**.

# %%
def normaliza(nome):
    # sua solução aqui
    pass

# %%
confere(normaliza, [
    (("  olt-centro-01  ",), "OLT-CENTRO-01"),
    (("Onu-Sul-4512",), "ONU-SUL-4512"),
    (("SWITCH-NORTE-02",), "SWITCH-NORTE-02"),
])

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def normaliza(nome):
#     return nome.strip().upper()
# ```
#
# </details>

# %% [markdown]
# ## 3. `split` e `join`: o par que separa e junta
#
# `split` quebra uma string numa **lista** de pedaços, usando um separador. `join`
# faz o caminho de volta: cola uma lista de strings usando um separador. Juntos,
# resolvem boa parte do trabalho com identificadores, IPs e linhas de log.
#
# 📖 [capítulo 2 · `split` e `join`: o par que separa e junta](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#split-e-join-o-par-que-separa-e-junta)

# %% [markdown]
# **✍️ Passo 8.** Faça `partes = identificador.split("-")` e imprima `partes` e `partes[1]`.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** o que o `split` devolve — texto ou outra coisa? E o `-` continua lá?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `['OLT', 'CENTRO', '01']` e `CENTRO`. Devolve uma **lista**, e o separador some. A
# partir daí, é lista: índice, `len`, laço — tudo o que você já sabe.
#
# </details>

# %% [markdown]
# **✍️ Passo 9.** Crie `ip = "10.0.3.47"`, faça `octetos = ip.split(".")`, troque o último por
# `octetos[3] = "x"` e imprima `".".join(octetos)`.

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** quem "sabe colar" — a lista ou o ponto? O que sai?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `10.0.3.x`. Quem cola é o **separador**: `".".join(lista)`. Parece de trás para
# frente no começo; leia como "*ponto*, junte estes pedaços". E repare que deu para
# trocar o octeto porque a **lista** pode mudar — a string não podia.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** Crie `linha = "2026-03-02  14:03:17   CRITICAL OLT-CENTRO-01"` (com espaços a mais
# entre os campos) e imprima `linha.split()` — sem argumento.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** quantos pedaços saem? Os espaços extras viram pedaços vazios?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Quatro pedaços, sem nenhum vazio. `split()` **sem argumento** quebra em qualquer
# quantidade de espaço em branco — é o que se usa para linhas de log, onde o
# alinhamento com espaços varia.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Mascarar o IP
#
# Para publicar um relatório sem expor o endereço completo, escreva `mascara_ip(ip)`,
# que troca o **último octeto** por `x`.

# %%
def mascara_ip(ip):
    # sua solução aqui
    pass

# %%
confere(mascara_ip, [
    (("10.0.3.47",), "10.0.3.x"),
    (("192.168.1.1",), "192.168.1.x"),
    (("172.16.200.254",), "172.16.200.x"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o passo do `ip` acima, com `return`. Lembre-se de que o índice `-1` pega o último
# elemento de uma lista também.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def mascara_ip(ip):
#     octetos = ip.split(".")
#     octetos[-1] = "x"
#     return ".".join(octetos)
# ```
#
# </details>

# %% [markdown]
# ## 4. Dissecando uma linha de log
#
# Uma linha de syslog tem formato fixo: **data, hora, severidade, equipamento e
# mensagem**. Com `split()`, cada campo vira uma posição da lista — mas a mensagem
# tem espaços dentro, e isso muda a conta.
#
# 📖 [capítulo 2 · Dissecando uma linha de log](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#dissecando-uma-linha-de-log)

# %% [markdown]
# **✍️ Passo 11.** Crie
# `linha = "2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3"`,
# faça `campos = linha.split()` e imprima `len(campos)`.

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** o formato tem cinco campos. Quantos pedaços o `split` devolve?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Devolve **10**. O `split` não sabe o que é um "campo" do log: ele quebra em todo
# espaço, e a mensagem tem seis palavras. Os quatro primeiros campos são uma palavra
# cada; a mensagem é **tudo da posição 4 em diante**.
#
# </details>

# %% [markdown]
# **✍️ Passo 12.** Separe os campos: `severidade = campos[2]`, `equipamento = campos[3]` e
# `mensagem = " ".join(campos[4:])`. Imprima os três.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** o que o `" ".join(campos[4:])` faz com os seis pedaços da mensagem?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `CRITICAL`, `OLT-CENTRO-01` e `perda de sinal na porta GPON0/1/3`. A fatia
# `campos[4:]` pega os pedaços da mensagem, e o `join` os cola de volta com espaço —
# `split` e `join` trabalhando juntos.
#
# </details>

# %% [markdown]
# **✍️ Passo 13.** Crie `outra = "2026-03-02 15:00:00 INFO OLT-CENTRO-01 alarme CRITICAL encerrado"`.
# Imprima `"CRITICAL" in outra` e, na linha de baixo, `outra.split()[2] == "CRITICAL"`.

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** as duas perguntam se o alarme é crítico. Dão a mesma resposta?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# A primeira dá `True`, a segunda `False`. São perguntas **diferentes**: `in`
# responde "a palavra aparece em algum lugar da linha?"; o campo `[2]` responde "a
# severidade é essa?". Só a segunda é o que o relatório quer.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Usar `in` como busca genérica em log. Uma mensagem pode citar outra severidade
# > ("alarme CRITICAL encerrado", "limpa WARNING anterior") e o contador conta errado —
# > **sem erro nenhum**. Compare o **campo**.

# %% [markdown]
# **✍️ Passo 14.** Por fim, uma linha truncada: imprima `"2026-03-02 14:03:17".split()[2]`.

# %%
# ✍️ passo 14

# %% [markdown]
# **Preveja:** por que esta linha quebra, se ela parece uma linha de log?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `IndexError: list index out of range`. Ela só tem dois pedaços, e o código pediu o
# terceiro. Linha em branco e linha cortada existem em log de verdade, e derrubam o
# script no `[2]` — na Aula 03 você aprende a pular essas linhas com um `if`, e na
# Aula 08, a tratá-las.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — É crítico mesmo?
#
# Escreva `e_critico(linha)`, que devolve `True` só se a **severidade** da linha for
# `CRITICAL`.

# %%
def e_critico(linha):
    # sua solução aqui
    pass

# %%
confere(e_critico, [
    (("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal",), True),
    (("2026-03-02 15:00:00 INFO OLT-CENTRO-01 alarme CRITICAL encerrado",), False),
    (("2026-03-02 09:00:00 WARNING SWITCH-NORTE-02 porta 3",), False),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# O segundo caso é a armadilha: a palavra aparece, mas não no campo de severidade.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def e_critico(linha):
#     return linha.split()[2] == "CRITICAL"
# ```
#
# </details>

# %% [markdown]
# ## 5. f-strings: número que vira relatório
#
# Dentro das chaves de uma f-string cabe, depois de dois-pontos, um **formato**:
# quantas casas decimais, que largura, alinhado para que lado. É o que transforma
# número solto em relatório legível.
#
# 📖 [capítulo 2 · f-strings: número que vira relatório](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#f-strings-numero-que-vira-relatorio)

# %% [markdown]
# **✍️ Passo 15.** Crie `site = "OLT-CENTRO-01"` e `potencia = -21.456`. Imprima
# `f"{site}: {potencia}"` e `f"{site}: {potencia:.2f} dBm"`.

# %%
# ✍️ passo 15

# %% [markdown]
# **Preveja:** o que o `:.2f` faz com o número? Arredonda ou corta?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `OLT-CENTRO-01: -21.456` e `OLT-CENTRO-01: -21.46 dBm`. O `.2f` mostra 2 casas,
# **arredondando** (o 6 da terceira casa faz a segunda subir de 5 para 6). O valor de `potencia`
# não muda: só a forma de mostrar.
#
# </details>

# %% [markdown]
# **✍️ Passo 16.** Imprima `f"[{site:<16}]"`, `f"[{site:>16}]"` e `f"[{potencia:>8.2f}]"`. Os
# colchetes estão ali só para você enxergar onde o texto começa e termina.

# %%
# ✍️ passo 16

# %% [markdown]
# **Preveja:** todas as linhas impressas têm o mesmo comprimento? O que fazem `<` e `>`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# As duas primeiras ocupam 16 caracteres entre os colchetes: `<` alinha à esquerda,
# `>` à direita, e o espaço que sobra é preenchido. A terceira ocupa 8. É assim que
# se monta uma coluna: **largura fixa**, sem contar espaços na mão.
#
# </details>

# %% [markdown]
# **✍️ Passo 17.** Imprima `f"{7:02d}:{5:02d}"` e `f"{0.9987:.2%}"`.

# %%
# ✍️ passo 17

# %% [markdown]
# **Preveja:** o que o `02d` faz com o 7? E o `%` com 0,9987?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `07:05` e `99.87%`. `02d` completa o inteiro com zero à esquerda até 2 dígitos —
# hora e minuto. `.2%` multiplica por 100 e põe o símbolo — disponibilidade de
# enlace.
#
# </details>

# %% [markdown]
# **✍️ Passo 18.** Um nome maior que a coluna: imprima
# `f"[{'OLT-CENTRO-01-SECUNDARIA':<16}{-21.456:>8.2f}]"`.

# %%
# ✍️ passo 18

# %% [markdown]
# **Preveja:** o nome, que tem mais de 16 caracteres, é cortado?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não é cortado: a largura é **mínima**, e a coluna **estoura** para a direita,
# desalinhando a tabela. Se a coluna precisa caber, escolha uma largura maior que o
# maior nome.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Uma linha do relatório
#
# Escreva `linha_relatorio(site, potencia)`, que devolve o nome numa coluna de **16
# caracteres alinhada à esquerda** seguido da potência numa coluna de **8
# caracteres alinhada à direita, com 2 casas**.

# %%
def linha_relatorio(site, potencia):
    # sua solução aqui
    pass

# %%
confere(linha_relatorio, [
    (("OLT-CENTRO-01", -21.456), "OLT-CENTRO-01     -21.46"),
    (("ONU-SUL-4512", -27.0), "ONU-SUL-4512      -27.00"),
])

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def linha_relatorio(site, potencia):
#     return f"{site:<16}{potencia:>8.2f}"
# ```
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# A equipe de campo quer, para cada linha de syslog, um resumo neste formato:
#
# ```
# 14:03 | CRITICAL | OLT-CENTRO-01 | perda de sinal na porta GPON0/1/3
# ```
#
# A hora vai **sem os segundos**, e os campos são separados por `" | "`.

# %% [markdown]
# ### 🎯 Sua vez — O resumo do alarme
#
# Escreva `resumo(linha)`, que devolve o resumo da linha no formato acima.

# %%
def resumo(linha):
    # sua solução aqui
    pass

# %%
confere(resumo, [
    (("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3",),
     "14:03 | CRITICAL | OLT-CENTRO-01 | perda de sinal na porta GPON0/1/3"),
    (("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 porta ativada",),
     "09:00 | INFO | SWITCH-NORTE-02 | porta ativada"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Três ferramentas da aula: `split()` para os campos; a fatia `[:5]` na hora para
# tirar os segundos; `" ".join(campos[4:])` para a mensagem. Para montar o resultado,
# uma f-string — ou um `" | ".join(...)` de uma lista com os quatro pedaços.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def resumo(linha):
#     campos = linha.split()
#     hora = campos[1][:5]
#     severidade = campos[2]
#     equipamento = campos[3]
#     mensagem = " ".join(campos[4:])
#     return f"{hora} | {severidade} | {equipamento} | {mensagem}"
# ```
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `"OLT-CENTRO-01"[4:10]` devolve:
# a) `"CENTRO"`  b) `"CENTRO-"`  c) `"-CENTRO"`  d) `"ENTRO-"`

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **a**. Posições 4 a 9; a 10 fica de fora.
#
# </details>

# %% [markdown]
# **2.** Depois de `s = " ONU "` e `s.strip()`, o valor de `s` é:
# a) `"ONU"`  b) `" ONU "`  c) `""`  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. String é imutável; o resultado do `.strip()` foi descartado. Faltou
# `s = s.strip()`.
#
# </details>

# %% [markdown]
# **3.** Para juntar `["10", "0", "3", "x"]` em `"10.0.3.x"`:
# a) `lista.join(".")`  b) `".".join(lista)`  c) `join(lista, ".")`  d) `lista + "."`

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **b**. Quem sabe colar é o separador.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 02](https://lacouth.github.io/python_telecom-site/listas/lista02/) —
#   strings e logs, com testes automáticos no Colab.
# - Releia o [capítulo 2 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/).
# - **Na próxima aula:** mini-teste sobre esta aula (fatias, métodos e `split`).
