# %% [markdown]
# # Aula 02B · Strings
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 2 do
# site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula02a-strings.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 02, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# `"OLT-CENTRO-01"[4:10]` devolve:
# a) `"CENTRO"`  b) `"CENTRO-"`  c) `"-CENTRO"`  d) `"ENTRO-"`

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **a**. Posições 4 a 9; a 10 fica de fora.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **String não muda: guarde o resultado.** Todo método de string — `strip`, `upper`, `replace` — devolve uma string
# **nova** e deixa a original como estava. Quando o resultado não é guardado, o
# programa não reclama: ele só continua usando o texto antigo.
#
# Em cada exercício de hoje, olhe para cada chamada de método e pergunte: **para
# onde foi o resultado?** Se a resposta for "para lugar nenhum", falta um
# `nome = nome.strip()`.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Vem do bloco *2. Os métodos que resolvem o dia a dia* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 2 · Os métodos que resolvem o dia a dia](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#os-metodos-que-resolvem-o-dia-a-dia)

# %% [markdown]
# ### 🎯 Sua vez — Normalizar o nome
#
# Nomes de equipamento chegam digitados de todo jeito. Escreva `normaliza(nome)`, que
# devolve o nome **sem espaços nas pontas** e em **maiúsculas**.

# %%
def normaliza(nome):
    # sua solução aqui
    pass

# %%
confere(normaliza, [
    (("  olt-centro-01  ",), "OLT-CENTRO-01"),
    (("Onu-Sul-4512",), "ONU-SUL-4512"),
    (("SWITCH-NORTE-02",), "SWITCH-NORTE-02"),
])

# %% [markdown]
# Vem do bloco *3. `split` e `join`: o par que separa e junta* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 2 · `split` e `join`: o par que separa e junta](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#split-e-join-o-par-que-separa-e-junta)

# %% [markdown]
# ### 🎯 Sua vez — Mascarar o IP
#
# Para publicar um relatório sem expor o endereço completo, escreva `mascara_ip(ip)`,
# que troca o **último octeto** por `x`.

# %%
def mascara_ip(ip):
    # sua solução aqui
    pass

# %%
confere(mascara_ip, [
    (("10.0.3.47",), "10.0.3.x"),
    (("192.168.1.1",), "192.168.1.x"),
    (("172.16.200.254",), "172.16.200.x"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o passo do `ip` acima, com `return`. Lembre-se de que o índice `-1` pega o último
# elemento de uma lista também.
#
# </details>

# %% [markdown]
# Vem do bloco *4. Dissecando uma linha de log* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 2 · Dissecando uma linha de log](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#dissecando-uma-linha-de-log)

# %% [markdown]
# ### 🎯 Sua vez — É crítico mesmo?
#
# Escreva `e_critico(linha)`, que devolve `True` só se a **severidade** da linha for
# `CRITICAL`.

# %%
def e_critico(linha):
    # sua solução aqui
    pass

# %%
confere(e_critico, [
    (("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal",), True),
    (("2026-03-02 15:00:00 INFO OLT-CENTRO-01 alarme CRITICAL encerrado",), False),
    (("2026-03-02 09:00:00 WARNING SWITCH-NORTE-02 porta 3",), False),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# O segundo caso é a armadilha: a palavra aparece, mas não no campo de severidade.
#
# </details>

# %% [markdown]
# Vem do bloco *5. f-strings: número que vira relatório* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 2 · f-strings: número que vira relatório](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/#f-strings-numero-que-vira-relatorio)

# %% [markdown]
# ### 🎯 Sua vez — Uma linha do relatório
#
# Escreva `linha_relatorio(site, potencia)`, que devolve o nome numa coluna de **16
# caracteres alinhada à esquerda** seguido da potência numa coluna de **8
# caracteres alinhada à direita, com 2 casas**.

# %%
def linha_relatorio(site, potencia):
    # sua solução aqui
    pass

# %%
confere(linha_relatorio, [
    (("OLT-CENTRO-01", -21.456), "OLT-CENTRO-01     -21.46"),
    (("ONU-SUL-4512", -27.0), "ONU-SUL-4512      -27.00"),
])

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #0207 — NOC Maré Net**
# >
# > *"Estagiário, o painel de alarmes caiu e só temos o syslog cru. Chegam linhas
# > assim:*
# >
# > `2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3`
# >
# > *Preciso que cada linha vire um resumo curto — **hora, severidade, equipamento
# > e mensagem** —, para a equipe de campo ler no celular."*
#
# A equipe de campo quer, para cada linha de syslog, um resumo neste formato:
#
# ```
# 14:03 | CRITICAL | OLT-CENTRO-01 | perda de sinal na porta GPON0/1/3
# ```
#
# A hora vai **sem os segundos**, e os campos são separados por `" | "`.

# %% [markdown]
# ### 🎯 Sua vez — O resumo do alarme
#
# Escreva `resumo(linha)`, que devolve o resumo da linha no formato acima.

# %%
def resumo(linha):
    # sua solução aqui
    pass

# %%
confere(resumo, [
    (("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3",),
     "14:03 | CRITICAL | OLT-CENTRO-01 | perda de sinal na porta GPON0/1/3"),
    (("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 porta ativada",),
     "09:00 | INFO | SWITCH-NORTE-02 | porta ativada"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Três ferramentas da aula: `split()` para os campos; a fatia `[:5]` na hora para
# tirar os segundos; `" ".join(campos[4:])` para a mensagem. Para montar o resultado,
# uma f-string — ou um `" | ".join(...)` de uma lista com os quatro pedaços.
#
# </details>

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 02](https://lacouth.github.io/python_telecom-site/listas/lista02/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista02.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `normaliza_site`**

# %% [markdown]
# **1.** Quais métodos resolvem o exercício?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# Dois: `strip()` tira os espaços das pontas e `upper()` passa para maiúsculas.
#
# </details>

# %% [markdown]
# **2.** Por que este código devolve o nome ainda com espaços?
#
# ```python
# nome.strip()
# return nome.upper()
# ```

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# Porque o resultado do `strip()` foi descartado: `nome` continua como chegou. Guarde cada passo numa variável — `limpo = nome.strip()` — e trabalhe sobre ela.
#
# </details>

# %% [markdown]
# **3.** Que caso vale testar à mão, além do enunciado?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# Um nome que já chega limpo, como `"OLT-SUL-03"`: a função tem de devolvê-lo igual. Normalizar duas vezes não pode estragar nada.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `"a b  c".split()` devolve:
# a) `['a', 'b', '', 'c']`  b) `['a', 'b', 'c']`  c) `['a b  c']`  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. Sem argumento, o `split` trata qualquer sequência de espaços como um separador só. O pedaço vazio aparece com `split(" ")`.
#
# </details>

# %% [markdown]
# **2.** `f"{-21.456:.1f}"` dá:
# a) `"-21.4"`  b) `"-21.5"`  c) `"-21.46"`  d) `"-21"`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. Uma casa decimal, arredondada: o `5` da segunda casa sobe o `4`.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 02](https://lacouth.github.io/python_telecom-site/listas/lista02/) —
#   strings e logs, com testes automáticos no Colab.
# - Releia o [capítulo 2 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/02-strings/).
# - **Na próxima noite A:** mini-teste sobre esta aula (fatias, métodos e `split`).
