# %% [markdown]
# # Aula 03 · Listas e os padrões de laço
#
# Esta aula apresenta o [capítulo 3 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/). A ideia central: **quase todo laço que você vai
# escrever é um de cinco padrões** — acumulador, contador, filtro, extremo e
# transformação. Reconhecer o padrão é metade do problema resolvido; a outra metade
# é saber **onde cada variável nasce**.
#
# **Ao fim da aula você consegue:**
#
# 1. criar uma lista vazia e fazê-la crescer com `append`;
# 2. escrever os cinco padrões de laço e dizer o que precisa existir antes do laço
#    em cada um;
# 3. achar **qual** item é o extremo com `enumerate`, e ordenar sem estragar a lista
#    original.
#
# **Roteiro:** 🔥 aquecimento · 📟 chamado · 1. a lista · 2. os cinco padrões · 3.
# percorrendo com posição · 4. ordenar · 📟 resolvendo o chamado · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **✍️ Passo:** o código é escrito ao vivo, em pedaços pequenos — a instrução
#   está logo acima de cada célula vazia. Estudando sozinho, escreva você mesmo; o
#   código completo está no capítulo do site (links 📖).
# - Depois de escrever e **antes de rodar**, registre a sua previsão. Só então rode
#   e abra o **▶ O que aconteceu**. A previsão errada é a parte que ensina — não a
#   apague.
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica e uma solução
#   estão recolhidas: tente antes de abrir.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — da aula passada
#
# Sem rodar nada: o que este trecho imprime?
#
# ```python
# linha = "2026-03-02 09:12:44 WARNING SWITCH-NORTE-02 porta 12 com erros"
# print(linha.split()[2])
# nome = "  olt-sul-03 "
# nome.upper()
# print(nome)
# ```

# %% [markdown]
# <details>
# <summary><b>Resposta</b></summary>
#
# Imprime `WARNING` e depois `  olt-sul-03 ` — **sem** mudança. `nome.upper()`
# devolveu uma string nova que ninguém guardou; a string original é imutável. Faltou
# `nome = nome.strip().upper()`.
#
# </details>

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0315 — NOC Maré Net**
# >
# > *"Estagiário, o técnico coletou a potência de recepção das ONUs do bairro Sul
# > durante o dia. Para o relatório de fechamento, preciso de três números: **a pior
# > medição, a média, e quantas ficaram abaixo do limite**. Hoje isso é feito na
# > planilha, arrastando fórmula. Dá para automatizar?"*
#
# No fim da aula você escreve uma função que monta essa linha de relatório para
# qualquer lista de medições.

# %% [markdown]
# ## 1. A lista
#
# A lista guarda vários valores em ordem, entre colchetes. Índice e fatia funcionam
# **como na string** — mas, diferente da string, a lista **muda**: cresce com
# `append`, e cada posição pode ser trocada.
#
# 📖 [capítulo 3 · A lista](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#a-lista)

# %% [markdown]
# **✍️ Passo 1.** Crie `potencias = [-21.4, -19.8, -27.0, -25.1]` e imprima `len(potencias)`,
# `potencias[0]`, `potencias[-1]` e `potencias[1:3]`.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** a fatia `[1:3]` segue a mesma regra da string? Quantos elementos ela tem?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `4`, `-21.4`, `-25.1` e `[-19.8, -27.0]`. Mesma regra da string: o primeiro índice
# entra, o segundo fica de fora — dois elementos.
#
# </details>

# %% [markdown]
# **✍️ Passo 2.** Faça `potencias.append(-30.2)` e depois `potencias[0] = -22.0`. Imprima `potencias`.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** quantos elementos a lista tem agora, e o que aconteceu com o primeiro?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Cinco elementos, com `-22.0` no lugar de `-21.4` e `-30.2` no fim. A lista **muda
# no lugar** — o que a string não deixava fazer.
#
# </details>

# %% [markdown]
# **✍️ Passo 3.** Crie `coletadas = []`, faça dois `append` (`-21.0` e `-19.0`) e imprima `coletadas`
# e `len(coletadas)`.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** quantas posições foram reservadas quando a lista foi criada?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Nenhuma: a lista nasceu **vazia** e cresceu a cada `append`. Sai `[-21.0, -19.0] 2`.
# Não se reserva espaço "por garantia": quantas ONUs essa OLT tem hoje? E depois da
# próxima expansão? A lista cresce, e `len` responde sozinha.
#
# </details>

# %% [markdown]
# **✍️ Passo 4.** Imprima `potencias[10]`.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** o que acontece ao pedir uma posição que não existe?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `IndexError: list index out of range`. A lista tem 5 elementos, índices de 0 a 4.
# É o mesmo erro da linha de log truncada da Aula 02.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — As últimas medições
#
# Escreva `ultimas(medicoes, n)`, que devolve uma lista com as `n` **últimas**
# medições (considere `n` maior que zero).

# %%
def ultimas(medicoes, n):
    # sua solução aqui
    pass

# %%
confere(ultimas, [
    (([-21.4, -19.8, -27.0, -25.1], 2), [-27.0, -25.1]),
    (([-21.4, -19.8, -27.0, -25.1], 1), [-25.1]),
    (([-21.4, -19.8], 5), [-21.4, -19.8]),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# O `[-2:]` da Aula 02 pegava os dois últimos caracteres. Troque o `2` pela variável.
#
# </details>

# %% [markdown]
# ## 2. Os cinco padrões
#
# | Padrão | Pergunta que responde | Antes do laço |
# |---|---|---|
# | acumulador | "quanto dá tudo junto?" | `soma = 0` |
# | contador | "quantos atendem à condição?" | `quantos = 0` |
# | filtro | "quais atendem?" | `escolhidos = []` |
# | extremo | "qual o maior/menor?" | `candidato = lista[0]` |
# | transformação | "e se eu mudar cada um?" | `novos = []` |
#
# A última coluna é o que mais importa: **cada padrão tem uma variável que nasce
# antes do laço**. Colocá-la no lugar errado é o erro mais comum deste capítulo — e
# ele não dá mensagem.
#
# 📖 [capítulo 3 · Os cinco padrões](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#os-cinco-padroes)

# %% [markdown]
# **✍️ Passo 5.** Recrie `potencias = [-21.4, -19.8, -27.0, -25.1]`. **Acumulador:** crie `soma = 0`,
# percorra a lista somando cada `p` em `soma`, e depois imprima `round(soma, 2)` e a
# média `round(soma / len(potencias), 2)`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** o que precisa existir **antes** do laço para esta soma funcionar?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `-93.3` e `-23.33`. A variável `soma` precisa existir antes do laço, valendo
# `0`: na primeira volta, `soma + p` precisa de um `soma` para somar.
#
# 📖 [capítulo 3 · 1. Acumulador — juntar tudo num número só](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#1-acumulador-juntar-tudo-num-numero-so)
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Agora copie o mesmo laço, mas coloque o `soma = 0` **dentro** do `for`, como
# primeira linha dele. Imprima `round(soma, 2)`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** imprime a mesma coisa? Se não, o quê?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Imprime `-25.1` — o **último** elemento. A cada volta, `soma` é zerada antes de
# somar; no fim, sobra só a última parcela.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** O acumulador nascendo dentro do laço **não dá mensagem nenhuma** e devolve um
# > número plausível (−25,1 dBm parece uma potência!). Por isso o jeito de pegar esse
# > erro é conferir com uma conta de cabeça: a soma de quatro valores em torno de −20
# > tinha que dar perto de −80.

# %% [markdown]
# **✍️ Passo 7.** **Contador:** crie `fora = 0` e percorra `potencias`; **se** `p < -25`, faça
# `fora = fora + 1`. Imprima `fora`.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** quantas medições estão abaixo de −25?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `2`: `-27.0` e `-25.1` (que é menor que −25, por pouco). No contador, o que se
# soma é **sempre 1** — a pergunta é "quantos", não "quanto".
#
# 📖 [capítulo 3 · 2. Contador — quantos atendem à condição](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#2-contador-quantos-atendem-a-condicao)
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Quantas fora da faixa
#
# Escreva `quantas_fora(potencias, minimo, maximo)`, que devolve **quantas**
# medições estão **fora** da faixa: menores que `minimo` ou maiores que `maximo`.

# %%
def quantas_fora(potencias, minimo, maximo):
    # sua solução aqui
    pass

# %%
confere(quantas_fora, [
    (([-21.4, -19.8, -27.0, -25.1], -27, -8), 0),
    (([-30.0, -5.0, -20.0], -27, -8), 2),
    (([-27.0, -8.0], -27, -8), 0),
    (([], -27, -8), 0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o contador, com uma condição de duas partes ligadas por `or`. O terceiro caso
# testa as bordas: `-27.0` e `-8.0` estão **dentro** da faixa.
#
# </details>

# %% [markdown]
# **✍️ Passo 8.** **Filtro:** crie `criticas = []`, percorra `potencias` e, **se** `p < -25`, faça
# `criticas.append(p)`. Imprima `criticas` e depois `potencias`.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** depois do laço, quantos elementos tem `potencias`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `criticas` sai `[-27.0, -25.1]` e `potencias` continua com os **quatro**. Filtrar
# não é remover: nasce uma lista **nova**, e a original fica intacta — que é o que se
# quer, porque ela ainda vai servir para a média.
#
# 📖 [capítulo 3 · 3. Filtro — uma lista nova, menor](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#3-filtro-uma-lista-nova-menor)
#
# </details>

# %% [markdown]
# **✍️ Passo 9.** **Transformação:** crie `com_margem = []` e, para cada `p`, faça
# `com_margem.append(round(p - 3, 2))`. Imprima `com_margem` e os dois tamanhos,
# `len(potencias)` e `len(com_margem)`.

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** a lista de saída tem o mesmo tamanho da de entrada?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Tem: `4 4`. Na transformação **todo item entra**, só que modificado — diferente do
# filtro, em que só alguns entram.
#
# 📖 [capítulo 3 · 5. Transformação — mesma quantidade, valores novos](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#5-transformacao-mesma-quantidade-valores-novos)
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — De texto para número
#
# As medições vieram de um arquivo e chegaram como texto. Escreva
# `converte(lidas)`, que devolve uma lista **nova** com cada valor convertido em
# `float`.

# %%
def converte(lidas):
    # sua solução aqui
    pass

# %%
confere(converte, [
    ((["-21.4", "-19.8"],), [-21.4, -19.8]),
    ((["-27"],), [-27.0]),
    (([],), []),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o padrão transformação: lista vazia antes, `append` dentro, com `float(valor)`.
# Sem essa conversão, somar as medições daria `TypeError` — texto não soma com número.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** **Extremo:** crie `pior = potencias[0]` e percorra a lista; **se** `p < pior`,
# troque: `pior = p`. Imprima `pior`.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** por que o candidato começa valendo `potencias[0]`, e não outro número qualquer?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `-27.0`. O candidato começa sendo **um elemento da própria lista** — assim ele é,
# com certeza, um valor possível. O passo seguinte mostra o que acontece quando não é.
#
# 📖 [capítulo 3 · 4. Extremo — o maior ou o menor](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#4-extremo-o-maior-ou-o-menor)
#
# </details>

# %% [markdown]
# **✍️ Passo 11.** Procure agora a **maior** potência, mas com o candidato começando em zero:
# `maior_zero = 0` e, no laço, **se** `p > maior_zero`, `maior_zero = p`. Imprima
# `maior_zero`.

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** qual é a maior potência da lista? O laço acha?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Imprime `0` — um valor que **nem está na lista**. Toda potência em dBm aqui é
# negativa, e nenhuma é maior que zero; o candidato inicial nunca é trocado. Com
# `maior = potencias[0]`, sairia `-19.8`.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Inicializar o máximo com zero funciona em toda lista de valores positivos e falha
# > **em silêncio** na primeira lista de dBm. E "começar em −999" só empurra o problema
# > para outra lista. O candidato certo é **o primeiro elemento**.

# %% [markdown]
# ### 🎯 Sua vez — O melhor sinal
#
# Escreva `melhor_sinal(potencias)`, que devolve a **maior** potência da lista, sem
# usar `max`. A lista tem pelo menos um elemento.

# %%
def melhor_sinal(potencias):
    # sua solução aqui
    pass

# %%
confere(melhor_sinal, [
    (([-21.4, -19.8, -27.0, -25.1],), -19.8),
    (([-30.0],), -30.0),
    (([3.0, 1.5, 7.2],), 7.2),
])

# %% [markdown]
# Os cinco padrões juntos, num programa só, estão no capítulo:
# 📖 [capítulo 3 · Os cinco de uma vez](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#os-cinco-de-uma-vez)
#
# ## 3. Percorrendo com posição
#
# Às vezes o valor não basta: você quer saber **em que posição** ele está, ou
# percorrer **duas listas lado a lado**. `enumerate` entrega posição e valor;
# `zip` entrega um item de cada lista por vez.
#
# 📖 [capítulo 3 · Percorrendo com posição](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#percorrendo-com-posicao)

# %%
# 📦 dados prontos — só rode esta célula
sites = ["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02"]
potencias = [-21.4, -27.0, -19.8]   # uma medição por site, na mesma ordem

# %% [markdown]
# **✍️ Passo 12.** Com as listas da célula de dados acima, escreva `for i, site in enumerate(sites):`
# imprimindo `i, site`.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** por onde a contagem de `i` começa?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Por **0**: `0 OLT-CENTRO-01`, `1 ONU-SUL-4512`, `2 OLT-NORTE-02`. `enumerate` entrega
# um par (posição, valor), e o `for` o desempacota nas duas variáveis.
#
# </details>

# %% [markdown]
# **✍️ Passo 13.** Agora percorra as duas listas juntas:
# `for site, potencia in zip(sites, potencias):` imprimindo
# `f"{site:<16}{potencia:>8.2f}"`.

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** como o `zip` sabe qual potência vai com qual site?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Pela **posição**: o primeiro site com a primeira potência, o segundo com a segunda.
# Sai uma tabela alinhada de três linhas. Se as listas estiverem fora de ordem, o
# `zip` junta errado sem avisar.
#
# </details>

# %% [markdown]
# **✍️ Passo 14.** Ache **o site** da pior potência: `pior = 0` (uma **posição**) e
# `for i, p in enumerate(potencias):` — **se** `p < potencias[pior]`, `pior = i`.
# Imprima `pior` e `sites[pior]`.

# %%
# ✍️ passo 14

# %% [markdown]
# **Preveja:** qual site vai aparecer?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `1 ONU-SUL-4512`. Aqui o candidato é uma **posição**, não um valor — e com a posição
# em mãos, dá para pegar o nome na outra lista.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Achar que achar o extremo é achar o número. Em campo ninguém vai consertar
# > `-27.0`; vão consertar **o equipamento**. O relatório precisa do nome.

# %% [markdown]
# ### 🎯 Sua vez — Qual é o pior site?
#
# Escreva `pior_site(sites, potencias)`, que devolve o **nome** do site com a menor
# potência.

# %%
def pior_site(sites, potencias):
    # sua solução aqui
    pass

# %%
confere(pior_site, [
    ((["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02"], [-21.4, -27.0, -19.8]),
     "ONU-SUL-4512"),
    ((["A", "B", "C"], [-30.0, -10.0, -20.0]), "A"),
    ((["X"], [-15.0]), "X"),
])

# %% [markdown]
# ## 4. Ordenar
#
# `sorted(lista)` devolve uma lista **nova**, ordenada; a original fica como estava.
# `lista.sort()` ordena **a própria lista** e não devolve nada. A pergunta que decide
# entre os dois: *eu ainda vou precisar da ordem original?*
#
# 📖 [capítulo 3 · Ordenar](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#ordenar)

# %% [markdown]
# **✍️ Passo 15.** Recrie `potencias = [-21.4, -19.8, -27.0, -25.1]`. Imprima `sorted(potencias)`,
# depois `potencias`, e por fim `sorted(potencias)[:2]`.

# %%
# ✍️ passo 15

# %% [markdown]
# **Preveja:** a lista `potencias` fica ordenada depois do `sorted`? E o que é o `[:2]`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `sorted` devolve `[-27.0, -25.1, -21.4, -19.8]`, e `potencias` continua na ordem
# original. `sorted(potencias)[:2]` são as **duas menores** — as duas piores
# medições. Com `reverse=True`, seriam as duas maiores.
#
# </details>

# %% [markdown]
# **✍️ Passo 16.** Crie `copia = [-21.4, -19.8, -27.0]`, faça `resultado = copia.sort()` e imprima
# `copia` e `resultado`.

# %%
# ✍️ passo 16

# %% [markdown]
# **Preveja:** o que fica guardado em `resultado`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `copia` sai ordenada, e `resultado` é **`None`**. O `.sort()` altera a lista no
# lugar e não devolve nada — quem guardou o "resultado" guardou `None`.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Esperar que todo método devolva o resultado. Os de string devolvem (porque a string
# > não muda); o `.sort()` e o `.append()` da lista **não**, porque mudam a própria
# > lista. `resultado = lista.sort()` é um erro clássico, e silencioso até a próxima
# > linha usar `resultado`.

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# Rode a célula abaixo: são as medições do bairro Sul.

# %%
medicoes_sul = [-21.4, -19.8, -27.6, -25.1, -22.3, -28.4, -20.0, -24.7]

# %% [markdown]
# ### 🎯 Sua vez — A linha do relatório
#
# Escreva `relatorio(potencias, limite)`, que devolve um texto no formato
#
# ```
# pior: -28.4 dBm | média: -23.7 dBm | abaixo de -27: 2
# ```
#
# com a pior e a média **com uma casa decimal**. Não use `min`, `max` nem `sum` —
# use os padrões da aula. A lista tem pelo menos um elemento.

# %%
def relatorio(potencias, limite):
    # sua solução aqui
    pass

# %%
confere(relatorio, [
    ((medicoes_sul, -27), "pior: -28.4 dBm | média: -23.7 dBm | abaixo de -27: 2"),
    (([-20.0], -27), "pior: -20.0 dBm | média: -20.0 dBm | abaixo de -27: 0"),
    (([-30.0, -10.0], -25), "pior: -30.0 dBm | média: -20.0 dBm | abaixo de -25: 1"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Três padrões no mesmo laço (ou em três laços, se preferir): **extremo** para a pior,
# **acumulador** para a média, **contador** para os abaixo do limite. No fim, uma
# f-string com `:.1f`.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `soma` foi criada **dentro** do `for`. O resultado impresso ao final será:
# a) a soma correta  b) zero  c) o último elemento  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **c**. E sem nenhuma mensagem de erro.
#
# </details>

# %% [markdown]
# **2.** Numa lista de potências em dBm (todas negativas), inicializar o máximo com
# `0` faz o programa:
# a) dar `IndexError`  b) devolver `0`  c) devolver o menor valor  d) funcionar normalmente

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. Nenhum valor é maior que zero, e o candidato nunca é trocado.
#
# </details>

# %% [markdown]
# **3.** `resultado = lista.sort()` deixa em `resultado`:
# a) a lista ordenada  b) uma cópia da lista  c) `None`  d) o menor elemento

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **c**. Quem quer uma lista nova usa `sorted(lista)`.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 03](https://lacouth.github.io/python_telecom-site/listas/lista03/) — os
#   cinco padrões, com testes automáticos no Colab.
# - Releia o [capítulo 3 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/).
# - **Na próxima aula:** mini-teste sobre esta aula (os padrões e onde nasce cada
#   variável).
