# %% [markdown]
# # Aula 03B · Listas e os padrões de laço
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 3 do
# site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula03a-listas-lacos.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 03, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# `soma` foi criada **dentro** do `for`. O resultado impresso ao final será:
# a) a soma correta  b) zero  c) o último elemento  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **c**. E sem nenhuma mensagem de erro.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **Onde a variável nasce decide o resultado.** Os cinco padrões têm a mesma armadilha: a variável que guarda o resultado — a
# soma, o contador, a lista nova, o pior valor — nasce **antes** do laço, uma vez
# só. Se ela nascer **dentro** do laço, renasce a cada volta, e o programa entrega
# só o que aconteceu na última. Sem mensagem de erro nenhuma.
#
# E o extremo tem uma regra a mais: ele nasce com o **primeiro item da lista**,
# nunca com `0`. Em potência óptica, todo valor é negativo, e o `0` ganharia de
# todos.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Vem do bloco *2. Os cinco padrões* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 3 · Os cinco padrões](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#os-cinco-padroes)

# %% [markdown]
# ### 🎯 Sua vez — De texto para número
#
# As medições vieram de um arquivo e chegaram como texto. Escreva
# `converte(lidas)`, que devolve uma lista **nova** com cada valor convertido em
# `float`.

# %%
def converte(lidas):
    # sua solução aqui
    pass

# %%
confere(converte, [
    ((["-21.4", "-19.8"],), [-21.4, -19.8]),
    ((["-27"],), [-27.0]),
    (([],), []),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o padrão transformação: lista vazia antes, `append` dentro, com `float(valor)`.
# Sem essa conversão, somar as medições daria `TypeError` — texto não soma com número.
#
# </details>

# %% [markdown]
# Vem do bloco *2. Os cinco padrões* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 3 · Os cinco padrões](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#os-cinco-padroes)

# %% [markdown]
# ### 🎯 Sua vez — O melhor sinal
#
# Escreva `melhor_sinal(potencias)`, que devolve a **maior** potência da lista, sem
# usar `max`. A lista tem pelo menos um elemento.

# %%
def melhor_sinal(potencias):
    # sua solução aqui
    pass

# %%
confere(melhor_sinal, [
    (([-21.4, -19.8, -27.0, -25.1],), -19.8),
    (([-30.0],), -30.0),
    (([3.0, 1.5, 7.2],), 7.2),
])

# %% [markdown]
# Vem do bloco *2. Os cinco padrões* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 3 · Os cinco padrões](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/#os-cinco-padroes)

# %% [markdown]
# ### 🎯 Sua vez — Qual é o pior site?
#
# Escreva `pior_site(sites, potencias)`, que devolve o **nome** do site com a menor
# potência.

# %%
def pior_site(sites, potencias):
    # sua solução aqui
    pass

# %%
confere(pior_site, [
    ((["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02"], [-21.4, -27.0, -19.8]),
     "ONU-SUL-4512"),
    ((["A", "B", "C"], [-30.0, -10.0, -20.0]), "A"),
    ((["X"], [-15.0]), "X"),
])

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #0315 — NOC Maré Net**
# >
# > *"Estagiário, o técnico coletou a potência de recepção das ONUs do bairro Sul
# > durante o dia. Para o relatório de fechamento, preciso de três números: **a pior
# > medição, a média, e quantas ficaram abaixo do limite**. Hoje isso é feito na
# > planilha, arrastando fórmula. Dá para automatizar?"*
#
# Rode a célula abaixo: são as medições do bairro Sul.

# %%
medicoes_sul = [-21.4, -19.8, -27.6, -25.1, -22.3, -28.4, -20.0, -24.7]

# %% [markdown]
# ### 🎯 Sua vez — A linha do relatório
#
# Escreva `relatorio(potencias, limite)`, que devolve um texto no formato
#
# ```
# pior: -28.4 dBm | média: -23.7 dBm | abaixo de -27: 2
# ```
#
# com a pior e a média **com uma casa decimal**. Não use `min`, `max` nem `sum` —
# use os padrões da aula. A lista tem pelo menos um elemento.

# %%
def relatorio(potencias, limite):
    # sua solução aqui
    pass

# %%
confere(relatorio, [
    ((medicoes_sul, -27), "pior: -28.4 dBm | média: -23.7 dBm | abaixo de -27: 2"),
    (([-20.0], -27), "pior: -20.0 dBm | média: -20.0 dBm | abaixo de -27: 0"),
    (([-30.0, -10.0], -25), "pior: -30.0 dBm | média: -20.0 dBm | abaixo de -25: 1"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Três padrões no mesmo laço (ou em três laços, se preferir): **extremo** para a pior,
# **acumulador** para a média, **contador** para os abaixo do limite. No fim, uma
# f-string com `:.1f`.
#
# </details>

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 03](https://lacouth.github.io/python_telecom-site/listas/lista03/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista03.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `media`**

# %% [markdown]
# **1.** Qual dos cinco padrões é este exercício?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# O **acumulador**: a soma nasce em `0` antes do laço e cresce a cada item. A quantidade de itens é o `len(valores)`.
#
# </details>

# %% [markdown]
# **2.** O que acontece com `media([])` se você só dividir a soma pela quantidade?

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# `ZeroDivisionError`: a soma é `0` e a quantidade também. Por isso o teste da lista vazia vem **antes** da divisão, com um `return 0.0` só para esse caso.
#
# </details>

# %% [markdown]
# **3.** Quando arredondar?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# No fim, sobre a média pronta: `round(..., 2)`.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `for i, p in enumerate([-20.1, -25.3]): print(i)` imprime:
# a) `1` e `2`  b) `0` e `1`  c) `-20.1` e `-25.3`  d) os pares

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. O `enumerate` conta a partir de zero, como os índices da lista.
#
# </details>

# %% [markdown]
# **2.** Num filtro, `abaixo = []` foi escrito **dentro** do `for`. No fim, `abaixo` tem:
# a) todos os itens que passaram  b) no máximo um item  c) sempre nada  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. A lista renasce vazia a cada volta: sobra, no máximo, o item da última volta, se ele tiver passado no `if`.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 03](https://lacouth.github.io/python_telecom-site/listas/lista03/) — os
#   cinco padrões, com testes automáticos no Colab.
# - Releia o [capítulo 3 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/03-listas-lacos/).
# - **Na próxima noite A:** mini-teste sobre esta aula (os padrões e onde nasce cada
#   variável).
