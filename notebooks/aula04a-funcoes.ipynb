# %% [markdown]
# # Aula 04A · Funções
#
# Esta semana apresenta o [capítulo 4 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/). A ideia central: **uma função, uma decisão**.
# Função é o jeito de dar nome a um cálculo, testá-lo sozinho e reaproveitá-lo — e
# a docstring é a frase que diz o que ela decide. Se você não consegue escrever a
# frase, ainda não sabe o que a função faz.
#
# **Ao fim das duas noites você consegue:**
#
# 1. escrever uma função com docstring, parâmetros, valor padrão e `return`;
# 2. explicar o que acontece com as variáveis de dentro da função quando ela termina;
# 3. dizer se uma função **altera** a lista que recebeu ou **devolve uma nova** — e
#    decompor um problema em funções pequenas.
#
# **Noite A — a ideia** (1h40): 📝 mini-teste · 📟 chamado · 1. definindo · 2. valor
# padrão e retorno múltiplo · 3. escopo · 4. altera ou devolve novo? · 5. decompor ·
# 6. testando com `assert` · 🚪 antes de sair
#
# O chamado se resolve na [noite
# B](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula04b-funcoes.ipynb),
# no encontro seguinte, que é laboratório: nenhum assunto novo, os 🎯 que ficaram e a
# lista começada em sala.

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **✍️ Passo:** o código é escrito ao vivo, em pedaços pequenos — a instrução
#   está logo acima de cada célula vazia. Estudando sozinho, escreva você mesmo; o
#   código completo está no capítulo do site (links 📖).
# - Depois de escrever e **antes de rodar**, registre a sua previsão. Só então rode
#   e abra o **▶ O que aconteceu**. A previsão errada é a parte que ensina — não a
#   apague.
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica e uma solução
#   estão recolhidas: tente antes de abrir.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 📝 Mini-teste — dez minutos
#
# Caderno fechado. O **Mini-teste 04**, no papel, cobre as duas noites da Aula 03:
# rastrear um trecho curto e escrever uma função pequena. Depois dele, o chamado de
# hoje.

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0421 — NOC Maré Net**
# >
# > *"Estagiário, o projeto de cada novo cliente de fibra passa por uma planilha de
# > **orçamento de potência**: potência do transmissor, menos a perda da fibra, do
# > splitter e dos conectores, dá a potência que chega; comparada com a
# > sensibilidade da ONU (−27 dBm), dá a margem. A planilha vive quebrando quando
# > alguém arrasta a fórmula errada. Transforma isso em código que dá para testar?"*
#
# Na noite B você monta o orçamento a partir de funções pequenas, cada uma com
# uma decisão só.

# %% [markdown]
# ## 1. Definindo
#
# `def` cria a função; entre parênteses vêm os **parâmetros**; a **docstring**, logo
# na primeira linha, diz em uma frase o que ela faz; `return` devolve o resultado
# para quem chamou.
#
# 📖 [capítulo 4 · Definindo](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#definindo)

# %% [markdown]
# > 💡 **Pense assim: a máquina de café.**
# >
# > Uma função é uma máquina: você põe os ingredientes (os **argumentos**), ela faz o
# > trabalho lá dentro, e sai o resultado (o valor do `return`). Os **parâmetros** são
# > os nomes dos compartimentos da máquina — `dbm`, `limite` —, e os argumentos são o
# > que você põe neles numa chamada específica — `-21.0`, `-25.0`. A mesma máquina serve
# > para quantas chamadas você quiser.
# >
# > E a diferença que mais confunde no começo: **`return` entrega** o café na sua mão,
# > para você fazer o que quiser com ele (guardar, comparar, somar); **`print` só
# > mostra** o café pela vitrine — você vê, mas não leva. Uma função sem `return`
# > devolve `None`. Veja também [Uma primeira função](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#uma-primeira-funcao).

# %% [markdown]
# **✍️ Passo 1.** Escreva a função `margem(potencia_rx, sensibilidade)`. **Comece pela docstring**:
# `"""Folga do enlace, em dB."""`. Só então o corpo: `return round(potencia_rx - sensibilidade, 2)`.
# Depois, imprima `margem(-21.4, -27.0)` e `margem(-28.0, -27.0)`.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** os dois resultados são positivos ou negativos? Em qual dos dois o enlace fecha?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `5.6` e `-1.0`. Margem positiva quer dizer que chega mais potência do que a ONU
# precisa — o enlace **fecha**, com 5,6 dB de folga. Negativa, não fecha. Escrever a
# docstring primeiro obriga a decidir **o que** a função faz antes de pensar em
# **como**.
#
# </details>

# %% [markdown]
# **✍️ Passo 2.** Chame `margem(-21.4)` — com um argumento só.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** funciona, usa zero no lugar do que falta, ou dá erro?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `TypeError`, dizendo que falta o argumento `sensibilidade`. O Python não inventa
# valor para parâmetro que não tem padrão — o próximo bloco mostra como dar um.
#
# </details>

# %% [markdown]
# **✍️ Passo 3.** Escreva uma função **sem `return`**: `def media(valores):` com uma linha só,
# `soma = sum(valores) / len(valores)`. Depois faça `resultado = media([1, 2, 3])` e
# imprima `resultado + 1`.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** o que tem em `resultado`? A última linha funciona?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `resultado` é **`None`**, e a última linha dá `TypeError` (não dá para somar
# `None` com número). A função calculou a média, mas não a devolveu: função sem
# `return` devolve `None`. O erro aparece longe de onde está a causa — numa linha que
# nem é da função.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Perda da fibra
#
# Escreva `perda_fibra(km, atenuacao)`, que devolve a perda de um trecho de fibra em
# dB: o comprimento em km vezes a atenuação em dB/km, **arredondado com 2 casas**.
# Não esqueça a docstring.

# %%
def perda_fibra(km, atenuacao):
    # sua solução aqui
    pass

# %%
confere(perda_fibra, [
    ((10, 0.35), 3.5),
    ((2.5, 0.35), 0.88),
    ((20, 0.25), 5.0),
    ((0, 0.35), 0.0),
])

# %% [markdown]
# ## 2. Valor padrão e retorno múltiplo
#
# Um parâmetro pode ter **valor padrão** — usado quando quem chama não passa nada.
# E uma função pode devolver **mais de um valor**, separados por vírgula; quem chama
# recebe os dois de uma vez.
#
# 📖 [capítulo 4 · Valor padrão e retorno múltiplo](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#valor-padrao-e-retorno-multiplo)

# %% [markdown]
# > 💡 **Pense assim: o “de sempre” da lanchonete.**
# >
# > O cliente de todo dia pede "o de sempre", e só explica o pedido quando quer algo
# > diferente. O valor padrão é o "de sempre" da função: se quem chama não diz nada, o
# > limite é −25; se diz, vale o que foi dito.

# %% [markdown]
# **✍️ Passo 4.** Escreva `classifica(dbm, limite=-25.0)`: **se** `dbm >= limite`, `return "ok"`;
# senão, `return "fora"`. Imprima `classifica(-21.0)`, `classifica(-27.0)` e
# `classifica(-27.0, limite=-30.0)`.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** o que sai em cada uma das três chamadas?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `ok`, `fora` e `ok`. Nas duas primeiras o limite é o padrão, `-25.0`; na terceira,
# quem chamou trocou o limite para `-30.0`, e `-27.0` passou a estar dentro.
#
# </details>

# %% [markdown]
# **✍️ Passo 5.** Imprima `classifica(-25.0)` e `classifica(-25.01)`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** o valor **exatamente igual** ao limite passa ou não passa?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `ok` e `fora`. A comparação é `>=`, então o igual passa. Fronteira é onde mora o
# erro: com `>` em vez de `>=`, o `-25.0` sairia `fora`, e ninguém perceberia sem
# testar exatamente esse valor.
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Escreva `min_max(valores)`, que faz `return min(valores), max(valores)`. Imprima
# `min_max([-21.4, -27.0, -19.8])`. Depois faça
# `menor, maior = min_max([-21.4, -27.0, -19.8])` e imprima `menor` e `maior`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** o que a função devolve — dois números separados ou uma coisa só?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Devolve **uma coisa só**: o par `(-27.0, -19.8)`, entre parênteses. Isso é uma
# **tupla** — uma sequência que você vai conhecer melhor na Aula 06. Com
# `menor, maior = ...`, o par é desempacotado nas duas variáveis, como no `enumerate`.
#
# </details>

# %% [markdown]
# ## 3. Escopo
#
# Variável criada **dentro** da função só existe lá dentro, e só enquanto ela roda.
# O que sai da função é o **valor** do `return` — não a variável.
#
# 📖 [capítulo 4 · Escopo](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#escopo)

# %% [markdown]
# > 💡 **Pense assim: a cozinha do restaurante.**
# >
# > O que acontece na cozinha fica na cozinha: o cozinheiro usa as panelas e os
# > rascunhos que quiser (as variáveis de dentro da função), e quando o prato fica
# > pronto, só o prato sai pela janela (o `return`). As panelas não vão para a mesa —
# > e o cliente não consegue mexer nelas do salão.

# %% [markdown]
# **✍️ Passo 7.** Crie `limite = -25.0` fora de qualquer função. Escreva `conta_fora(valores)`, que
# cria `quantidade = 0`, conta os valores menores que `limite` e devolve
# `quantidade`. Imprima `conta_fora([-21.0, -27.0, -30.0])`.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** a função consegue usar `limite`, que foi criada fora dela?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Sai `2`, e sim: a função **lê** a variável de fora. Funciona — mas a função passou
# a depender de algo que não aparece na lista de parâmetros.
#
# </details>

# %% [markdown]
# **✍️ Passo 8.** Agora imprima `quantidade`, fora da função.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** depois da chamada, `quantidade` ainda existe?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `NameError: name 'quantidade' is not defined`. A variável nasceu quando a função
# começou e morreu quando ela terminou. O que sobreviveu foi o **valor** devolvido.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Achar que a variável "fica lá dentro esperando", e — do outro lado — deixar a
# > função depender de variável de fora, como `limite`. A regra prática: **tudo de que a
# > função precisa entra por parâmetro, e tudo que ela produz sai pelo `return`**. Uma
# > `conta_fora(valores, limite)` é testável sozinha; a de cima, não.

# %% [markdown]
# ## 4. Altera ou devolve novo?
#
# Número passado para uma função chega **copiado**. Lista chega **a própria**: se a
# função a alterar, quem chamou vê a alteração. Por isso toda função que recebe uma
# lista toma uma decisão — e a docstring precisa dizer qual.
#
# 📖 [capítulo 4 · A decisão que a docstring precisa contar](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#a-decisao-que-a-docstring-precisa-contar)

# %% [markdown]
# > 💡 **Pense assim: emprestar o caderno ou dar uma cópia.**
# >
# > Passar uma lista para uma função é **emprestar o caderno**, não entregar uma
# > fotocópia: se a função escrever nele, o caderno volta escrito. Quem empresta
# > precisa saber se o colega vai só ler ou vai anotar — e é isso que a docstring
# > avisa.

# %% [markdown]
# **✍️ Passo 9.** Escreva `com_margem(valores, margem)` com docstring `"""Devolve uma lista NOVA,
# sem tocar na recebida."""`: crie `novos = []`, faça `novos.append(valor + margem)`
# para cada valor e devolva `novos`. Crie `medicoes = [-21.0, -19.0]` e imprima
# `com_margem(medicoes, -3)` e depois `medicoes`.

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** depois da chamada, `medicoes` mudou?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Não: sai `[-24.0, -22.0]` e depois `[-21.0, -19.0]`. A função montou uma lista
# nova e não tocou na recebida.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** Escreva `registra(historico, valor)` com docstring `"""Altera a lista recebida, de
# propósito."""`: faça `historico.append(valor)` e devolva `historico`. Imprima
# `registra(medicoes, -27.0)` e depois `medicoes`.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** e agora, o que aconteceu com a lista de quem chamou?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `medicoes` agora tem **três** elementos. `historico` e `medicoes` são dois nomes
# para **a mesma lista**: o `append` lá dentro alterou a lista de quem chamou.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Supor que argumento é sempre cópia. As duas escolhas são legítimas — devolver novo
# > é o padrão seguro para um cálculo; alterar é o esperado de um registro. O defeito é
# > a função que **altera sem avisar**: quem chamou continua usando a lista achando que
# > ela não mudou.

# %% [markdown]
# ## 5. Decompor: o exercício que importa
#
# Um relatório pode ser um bloco só, com o `if` e a f-string dentro do laço. Funciona.
# A diferença aparece quando algo muda: com funções pequenas, cada mudança mexe em
# **uma função de uma linha**. Quando a docstring precisa de um "e", provavelmente são
# duas funções.
#
# 📖 [capítulo 4 · Decompor: o exercício que importa](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#decompor-o-exercicio-que-importa)

# %% [markdown]
# > 💡 **Pense assim: as peças do carro.**
# >
# > Uma montadora testa o freio, o motor e a direção separadamente, antes de montar o
# > carro. Se o carro pronto der defeito, dá para trocar só a peça que falhou. Funções
# > pequenas são essas peças: cada uma testada sozinha, e o relatório é a montagem.

# %% [markdown]
# **✍️ Passo 11.** Escreva duas funções de uma linha: `fora_da_faixa(potencia, limite)`, que devolve
# `potencia < limite`, e `linha(site, potencia)`, que devolve
# `f"{site:<16}{potencia:>8.2f}"`. Teste cada uma **sozinha**:
# `print(fora_da_faixa(-27.5, -25.0))` e `print(linha("ONU-SUL-4512", -27.5))`.

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** o que cada chamada devolve?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `True` e a linha alinhada `ONU-SUL-4512      -27.50`. Cada função faz uma coisa, e
# dá para conferir cada uma sem montar o relatório inteiro.
#
# </details>

# %%
# 📦 dados prontos — só rode esta célula
sites = ["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02", "ONU-LESTE-77"]
potencias = [-21.0, -27.5, -19.0, -28.1]

# %% [markdown]
# **✍️ Passo 12.** Agora componha: `relatorio(sites, potencias, limite=-25.0)` percorre
# `zip(sites, potencias)` e, **se** `fora_da_faixa(...)`, faz `linhas.append(linha(...))`.
# No fim, acrescenta `f"{len(linhas)} de {len(sites)} fora da faixa"` e devolve
# `"\n".join(linhas)`. Teste com as listas `sites` e `potencias` da célula de dados acima, imprimindo o
# relatório.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** se amanhã o critério passar a incluir "potência alta demais", quantas funções mudam?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Saem as duas ONUs fora da faixa e a linha `2 de 4 fora da faixa`. Se o critério
# mudar, muda **só** `fora_da_faixa`; se o formato mudar (acrescentar a data), muda
# **só** `linha`. O `relatorio` nem fica sabendo.
#
# </details>

# %% [markdown]
# ## 6. Testando com `assert`
#
# `assert condição` não faz nada quando a condição é verdadeira, e levanta
# `AssertionError` quando é falsa. É o teste mais barato que existe — e é com ele que
# as listas deste curso se corrigem sozinhas. O `confere` dos 🎯 é a mesma ideia, com
# mensagens mais amigáveis.
#
# 📖 [capítulo 4 · Testando com `assert`](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#testando-com-assert)

# %% [markdown]
# > 💡 **Pense assim: conferir o troco.**
# >
# > `assert` é conferir o troco antes de sair do caixa: se estiver certo, você segue
# > sem dizer nada; se estiver errado, você para na hora e reclama. É por isso que a
# > célula de teste não mostra nada quando tudo passa, e para no primeiro caso que
# > falha.

# %% [markdown]
# **✍️ Passo 13.** Escreva `assert margem(-21.4, -27.0) == 5.6` e, na linha de baixo,
# `assert margem(-21.4, -27.0) == 5.0`.

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** o que cada uma das duas linhas faz?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# A primeira **não faz nada** — a condição é verdadeira, e silêncio quer dizer que
# passou. A segunda levanta `AssertionError`: é o teste avisando que a função não
# devolveu o que se esperava.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Uma função sem `return` devolve:
# a) o último valor calculado  b) `0`  c) `None`  d) erro de sintaxe

# %% [markdown]
# > 🌉 **Esta fica sem resposta aqui.** Pense nela até o encontro seguinte: é a
# > primeira coisa da noite B.

# %% [markdown]
# **2.** `menor, maior = min_max(v)` funciona porque a função devolve:
# a) duas variáveis  b) uma tupla  c) uma lista de dois  d) um dicionário

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b** — e o desempacotamento também funcionaria com uma lista de dois.
#
# </details>

# %% [markdown]
# **3.** Uma função recebe uma lista e faz `v.append(1)`. Depois da chamada, a lista
# de quem chamou:
# a) está inalterada  b) tem um elemento a mais  c) foi copiada  d) virou `None`

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **b**. Lista chega à função **a própria**, não uma cópia.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - **No encontro seguinte — noite B:** laboratório, sem assunto novo. Os 🎯 que
#   ficaram, o chamado resolvido e a [Lista
#   04](https://lacouth.github.io/python_telecom-site/listas/lista04/) começada em sala.
# - Releia no [capítulo 4 do
#   site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/)
#   as seções que ficaram difíceis: o link 📖 de cada bloco leva direto a elas.
# - Guarde a pergunta 1 do 🚪: ela abre a noite B.
