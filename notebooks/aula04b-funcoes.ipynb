# %% [markdown]
# # Aula 04B · Funções
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 4 do
# site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula04a-funcoes.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 04, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# Uma função sem `return` devolve:
# a) o último valor calculado  b) `0`  c) `None`  d) erro de sintaxe

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **c**.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **A função devolve; quem imprime é outro.** O `confere` só enxerga o que a função **devolve** com `return`. Uma função que
# faz `print` do resultado e não tem `return` parece funcionar — o número aparece na
# tela — e entrega `None` para quem a chamou.
#
# Antes de rodar o `confere`, percorra a função com o dedo: **todo caminho termina
# num `return`?** Inclusive o caminho do `else`, inclusive o da lista vazia.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Vem do bloco *2. Valor padrão e retorno múltiplo* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 4 · Valor padrão e retorno múltiplo](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#valor-padrao-e-retorno-multiplo)

# %% [markdown]
# ### 🎯 Sua vez — Classificar a potência
#
# Escreva `classifica_potencia(dbm, minimo=-27.0, maximo=-8.0)`, que devolve
# `"baixa"` se `dbm` é menor que `minimo`, `"alta"` se é maior que `maximo`, e
# `"ok"` caso contrário (as bordas são `"ok"`).

# %%
def classifica_potencia(dbm, minimo=-27.0, maximo=-8.0):
    # sua solução aqui
    pass

# %%
confere(classifica_potencia, [
    ((-21.0,), "ok"),
    ((-28.0,), "baixa"),
    ((-5.0,), "alta"),
    ((-27.0,), "ok"),
    ((-28.0, -30.0), "ok"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# O último caso passa um `minimo` diferente do padrão: `-28.0` está acima de
# `-30.0`, então é `"ok"`. Use os parâmetros, não os números `-27` e `-8` escritos
# no corpo.
#
# </details>

# %% [markdown]
# Vem do bloco *4. Altera ou devolve novo?* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 4 · A decisão que a docstring precisa contar](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/#a-decisao-que-a-docstring-precisa-contar)

# %% [markdown]
# ### 🎯 Sua vez — Sem leituras inválidas
#
# Uma leitura de potência **positiva** é inválida (o medidor falhou). Escreva
# `sem_invalidas(medicoes)`, que devolve uma lista **nova** só com as leituras menores
# ou iguais a zero — **sem alterar** a lista recebida.

# %%
def sem_invalidas(medicoes):
    # sua solução aqui
    pass

# %%
confere(sem_invalidas, [
    (([-21.0, 3.5, -19.0],), [-21.0, -19.0]),
    (([2.0, 1.0],), []),
    (([],), []),
])
original = [-21.0, 3.5, -19.0]
sem_invalidas(original)
confere_valor("original (não podia mudar)", original, [-21.0, 3.5, -19.0])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# É o padrão filtro. Se você usou `medicoes.remove(...)`, a última conferência
# reclama: `remove` altera a lista de quem chamou.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #0421 — NOC Maré Net**
# >
# > *"Estagiário, o projeto de cada novo cliente de fibra passa por uma planilha de
# > **orçamento de potência**: potência do transmissor, menos a perda da fibra, do
# > splitter e dos conectores, dá a potência que chega; comparada com a
# > sensibilidade da ONU (−27 dBm), dá a margem. A planilha vive quebrando quando
# > alguém arrasta a fórmula errada. Transforma isso em código que dá para testar?"*
#
# O orçamento de potência do projeto:
#
# | Item | Valor |
# |---|---|
# | perda da fibra | `km × 0,35 dB/km` |
# | conectores | 1,0 dB (dois conectores de 0,5 dB) |
# | potência recebida | `tx − fibra − splitter − conectores` |
# | margem | `recebida − sensibilidade` (sensibilidade: −27 dBm) |

# %% [markdown]
# ### 🎯 Sua vez — O orçamento de potência
#
# A função `perda_fibra` já está escrita. Escreva:
#
# - `potencia_recebida(tx_dbm, km, splitter_db)`, que devolve a potência que chega à
#   ONU, **arredondada com 2 casas**;
# - `orcamento(tx_dbm, km, splitter_db, sensibilidade=-27.0)`, que devolve **dois
#   valores**: a potência recebida e a margem (também com 2 casas).
#
# Use cada função dentro da seguinte — nada de repetir a conta.

# %%
def perda_fibra(km, atenuacao=0.35):
    """Perda de um trecho de fibra, em dB."""
    return round(km * atenuacao, 2)


def potencia_recebida(tx_dbm, km, splitter_db):
    # sua solução aqui
    pass


def orcamento(tx_dbm, km, splitter_db, sensibilidade=-27.0):
    pass

# %%
confere(potencia_recebida, [((3.0, 10, 17.5), -19.0), ((1.5, 20, 21.0), -27.5)])
confere(orcamento, [
    ((3.0, 10, 17.5), (-19.0, 8.0)),
    ((1.5, 20, 21.0), (-27.5, -0.5)),
    ((1.5, 20, 21.0, -28.0), (-27.5, 0.5)),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# `potencia_recebida` chama `perda_fibra(km)` (a atenuação tem valor padrão) e
# subtrai o splitter e o `1.0` dos conectores. `orcamento` chama
# `potencia_recebida(...)`, calcula a margem e faz `return recebida, margem`.
#
# </details>

# %% [markdown]
# O segundo projeto não fecha: margem de −0,5 dB. Com um splitter 1:64 a 20 km, a
# ONU recebe menos do que precisa — e a função disse isso sem ninguém arrastar
# fórmula. Trocar para um splitter 1:32 (17,5 dB) resolveria? Teste chamando
# `orcamento(1.5, 20, 17.5)` numa célula nova.

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 04](https://lacouth.github.io/python_telecom-site/listas/lista04/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista04.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `aplica_ganho`**

# %% [markdown]
# **1.** O que o valor padrão `ganho=0.0` já resolve sozinho?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# O caso em que quem chama não informa o ganho. Não precisa de `if` para descobrir se ele veio: se não veio, vale `0.0`.
#
# </details>

# %% [markdown]
# **2.** O exercício diz "uma linha". Qual é a conta?

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# Somar o ganho à potência e arredondar com duas casas, num `return`.
#
# </details>

# %% [markdown]
# **3.** Como conferir as duas formas de chamar?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# Chame com e sem o segundo argumento, como no enunciado: `aplica_ganho(-21.5, 3)` e `aplica_ganho(-21.5)`. Os dois precisam funcionar.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Depois de `def f(x): print(x * 2)` e `y = f(3)`, `y` vale:
# a) `6`  b) `None`  c) `"6"`  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. O `6` aparece na tela, mas a função não tem `return`: devolve `None`.
#
# </details>

# %% [markdown]
# **2.** Com `def perda(km, atenuacao=0.35)`, a chamada `perda(10, 0.4)` usa atenuação:
# a) `0.35`  b) `0.4`  c) as duas  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. O padrão só vale quando o argumento não é passado.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 04](https://lacouth.github.io/python_telecom-site/listas/lista04/) —
#   funções, com testes automáticos no Colab.
# - Releia o [capítulo 4 do site](https://lacouth.github.io/python_telecom-site/unidade1-fundamentos/04-funcoes/), principalmente a seção sobre alterar ou devolver novo.
# - **Na próxima noite A:** mini-teste sobre esta aula (`return`, valor padrão, escopo).
