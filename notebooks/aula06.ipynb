# %% [markdown]
# # Aula 06 · Conjuntos, tuplas e inventário
#
# Esta aula apresenta o [capítulo 6 do site](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/). A ideia central: **cada estrutura responde uma
# pergunta**. O conjunto responde "quem está lá?" — e compara duas fotos da rede numa
# linha. A tupla é o registro que não muda. E o inventário de verdade é uma **lista
# de dicionários**, percorrida com os mesmos padrões de sempre.
#
# **Ao fim da aula você consegue:**
#
# 1. usar um conjunto para tirar repetições e comparar duas coleções (o que
#    apareceu, o que sumiu);
# 2. explicar por que a tupla pode ser chave de dicionário e a lista não;
# 3. percorrer uma lista de dicionários com os padrões da Unidade 1 e indexá-la pelo
#    nome.
#
# **Roteiro:** 📟 chamado · 🔥 aquecimento · 1. conjuntos · 2. operações entre
# conjuntos · 3. tuplas · 4. estruturas dentro de estruturas · 5. consultar pelo nome ·
# 📟 resolvendo o chamado · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **✍️ Passo:** o código é escrito ao vivo, em pedaços pequenos — a instrução
#   está logo acima de cada célula vazia. Estudando sozinho, escreva você mesmo; o
#   código completo está no capítulo do site (links 📖).
# - Depois de escrever e **antes de rodar**, registre a sua previsão. Só então rode
#   e abra o **▶ O que aconteceu**. A previsão errada é a parte que ensina — não a
#   apague.
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica e uma solução
#   estão recolhidas: tente antes de abrir.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 📟 O chamado de hoje
#
# > **Chamado #0603 — NOC Maré Net**
# >
# > *"Estagiário, auditoria: o sistema de gerência (NMS) diz que temos uma lista de
# > equipamentos; a equipe de campo percorreu os sites e anotou outra. **As duas não
# > batem.** Preciso saber o que o NMS tem e o campo não achou (equipamento fantasma)
# > e o que o campo achou e o NMS não conhece (equipamento sem gerência). A lista de
# > campo tem repetição, porque cada técnico anotou o seu pedaço."*
#
# No fim da aula você resolve isso em poucas linhas — com conjuntos.

# %% [markdown]
# ## 🔥 Aquecimento — da aula passada
#
# Sem rodar nada: o que este trecho imprime?
#
# ```python
# contagem = {}
# for nome in ["OLT-A", "ONU-B", "OLT-A"]:
#     contagem[nome] = contagem.get(nome, 0) + 1
# print(contagem)
# print("OLT-A" in contagem, 2 in contagem)
# ```

# %% [markdown]
# <details>
# <summary><b>Resposta</b></summary>
#
# Imprime `{'OLT-A': 2, 'ONU-B': 1}` e `True False`. O `in` num dicionário pergunta
# pela **chave**: `"OLT-A"` é chave, `2` é valor.
#
# </details>

# %% [markdown]
# ## 1. Conjuntos: quando só importa quem está lá
#
# Um conjunto guarda itens **sem repetição e sem ordem**. Serve para uma pergunta só
# — "quem está lá?" —, e responde muito bem: testar se um item está no conjunto é
# direto, como a chave de um dicionário.
#
# 📖 [capítulo 6 · Conjuntos: quando só importa quem está lá](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#conjuntos-quando-so-importa-quem-esta-la)

# %% [markdown]
# **✍️ Passo 1.** Crie `vistos = {"OLT-CENTRO-01", "ONU-SUL-4512", "OLT-CENTRO-01"}` — repare que um
# nome aparece duas vezes. Imprima `len(vistos)` e `"ONU-SUL-4512" in vistos`.

# %%
# ✍️ passo 1

# %% [markdown]
# **Preveja:** quantos itens tem `vistos`?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `2` e `True`. O repetido entrou uma vez só: o conjunto **não guarda repetição**.
#
# </details>

# %% [markdown]
# **✍️ Passo 2.** Imprima `type(set())` e `type({})`.

# %%
# ✍️ passo 2

# %% [markdown]
# **Preveja:** `{}` cria um conjunto vazio ou um dicionário vazio?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `set()` é conjunto; `{}` é **dicionário**. O dicionário chegou primeiro à linguagem
# e ficou com as chaves vazias. Conjunto vazio se escreve `set()` — e cresce com
# `.add(item)`.
#
# </details>

# %% [markdown]
# **✍️ Passo 3.** Imprima `vistos[0]`.

# %%
# ✍️ passo 3

# %% [markdown]
# **Preveja:** por que isso pode não funcionar?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `TypeError`: conjunto não aceita índice. Sem ordem, **não há primeiro**. Se precisar
# de ordem, `sorted(vistos)` devolve uma lista ordenada.
#
# </details>

# %% [markdown]
# **✍️ Passo 4.** Crie `nomes = ["A", "B", "A", "C", "B"]` e imprima `len(set(nomes))` e
# `sorted(set(nomes))`.

# %%
# ✍️ passo 4

# %% [markdown]
# **Preveja:** quantos nomes distintos há?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `3` e `['A', 'B', 'C']`. Converter a lista em conjunto tira as repetições; o
# `sorted` devolve para uma lista, em ordem. É o jeito curto de responder "quantos
# distintos?".
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Quantos equipamentos distintos
#
# Escreva `quantos_distintos(nomes)`, que devolve quantos nomes **diferentes** há na
# lista.

# %%
def quantos_distintos(nomes):
    # sua solução aqui
    pass

# %%
confere(quantos_distintos, [
    ((["OLT-A", "ONU-B", "OLT-A"],), 2),
    ((["X", "X", "X"],), 1),
    (([],), 0),
])

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def quantos_distintos(nomes):
#     return len(set(nomes))
# ```
#
# </details>

# %% [markdown]
# ## 2. As operações entre conjuntos
#
# Duas fotos da rede — ontem e hoje — viram dois conjuntos, e as operações respondem
# as perguntas do NOC: `-` (diferença), `&` (os dois), `|` (qualquer um), `^` (só um
# dos dois).
#
# 📖 [capítulo 6 · As operações entre conjuntos](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#as-operacoes-entre-conjuntos)

# %% [markdown]
# **✍️ Passo 5.** Crie `ontem = {"OLT-CENTRO-01", "OLT-NORTE-02", "ONU-SUL-4512"}` e
# `hoje = {"OLT-CENTRO-01", "OLT-NORTE-02", "RADIO-OESTE-01"}`. Imprima
# `sorted(hoje - ontem)` e `sorted(ontem - hoje)`.

# %%
# ✍️ passo 5

# %% [markdown]
# **Preveja:** antes de rodar: qual equipamento apareceu e qual sumiu? Qual das duas linhas
# responde cada pergunta?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `hoje - ontem` dá `['RADIO-OESTE-01']` — **apareceu**. `ontem - hoje` dá
# `['ONU-SUL-4512']` — **sumiu**. Leia `a - b` como "o que está em `a` e não está em
# `b`". No mercado isso tem nome: **detecção de drift** — e a segunda linha é a que
# gera chamado.
#
# </details>

# %% [markdown]
# **✍️ Passo 6.** Imprima `sorted(hoje & ontem)`, `sorted(hoje | ontem)` e `sorted(hoje ^ ontem)`.

# %%
# ✍️ passo 6

# %% [markdown]
# **Preveja:** o que cada uma das três responde?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `&` dá os que **continuam** (estão nos dois); `|` dá **todos** que já foram vistos;
# `^` dá os que **mudaram** — apareceram ou sumiram.
#
# </details>

# %% [markdown]
# **✍️ Passo 7.** Faça a mesma pergunta de "quem sumiu" **sem conjuntos**: `sumiram = []`, percorra
# `sorted(ontem)` e, **se** `nome not in hoje`, faça `sumiram.append(nome)`. Imprima
# `sumiram`.

# %%
# ✍️ passo 7

# %% [markdown]
# **Preveja:** o resultado é o mesmo da diferença entre conjuntos?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# É o mesmo: `['ONU-SUL-4512']`. O `ontem - hoje` é exatamente esse filtro, escrito
# numa linha.
#
# </details>

# %% [markdown]
# > ⚠️ **Armadilha.** Achar que a operação de conjuntos é só sintaxe bonita. Com o laço, há quatro linhas
# > em que se pode trocar `ontem` e `hoje` de lugar às sete da manhã; com a diferença,
# > há uma — e ela se lê em voz alta.

# %% [markdown]
# ### 🎯 Sua vez — O que apareceu
#
# Escreva `apareceram(ontem, hoje)`, que recebe **duas listas** de nomes (que podem ter
# repetição) e devolve a **lista ordenada** dos nomes que estão em `hoje` e não
# estavam em `ontem`.

# %%
def apareceram(ontem, hoje):
    # sua solução aqui
    pass

# %%
confere(apareceram, [
    ((["OLT-A", "ONU-B"], ["OLT-A", "RADIO-C", "RADIO-C"]), ["RADIO-C"]),
    ((["A", "B"], ["B", "A"]), []),
    (([], ["Z", "Y"]), ["Y", "Z"]),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Converta as duas listas com `set(...)`, faça a diferença e devolva `sorted(...)` do
# resultado.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def apareceram(ontem, hoje):
#     return sorted(set(hoje) - set(ontem))
# ```
#
# </details>

# %% [markdown]
# ## 3. Tuplas: a sequência que não muda
#
# A tupla é uma sequência entre parênteses que **não muda** depois de criada — um
# registro: *(equipamento, momento, potência)*. Você já a usou sem saber o nome, no
# `return menor, maior` da Aula 04. E por não mudar, ela pode ser **chave de
# dicionário**.
#
# 📖 [capítulo 6 · Tuplas: a sequência que não muda](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#tuplas-a-sequencia-que-nao-muda)

# %% [markdown]
# **✍️ Passo 8.** Crie `medicao = ("OLT-CENTRO-01", "2026-03-02 14:00:00", -21.4)`. Imprima
# `medicao[0]` e `len(medicao)`. Depois desempacote: `nome, momento, dbm = medicao` e
# imprima `nome, dbm`.

# %%
# ✍️ passo 8

# %% [markdown]
# **Preveja:** índice e `len` funcionam como na lista?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# Funcionam: `OLT-CENTRO-01` e `3`, e o desempacotamento põe cada campo numa
# variável. Ler uma tupla é como ler uma lista.
#
# </details>

# %% [markdown]
# **✍️ Passo 9.** Tente mudar a potência: `medicao[2] = -22.0`.

# %%
# ✍️ passo 9

# %% [markdown]
# **Preveja:** qual é a mensagem, e com qual outra ela se parece?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `TypeError`: a tupla não aceita atribuição a item. É a mesma família de mensagem
# da string imutável da Aula 02 — e pela mesma razão.
#
# </details>

# %% [markdown]
# **✍️ Passo 10.** Crie `leituras = {}` e guarde duas leituras com **tupla como chave**:
# `leituras[("OLT-CENTRO-01", "2026-03-02")] = -21.4` e
# `leituras[("OLT-CENTRO-01", "2026-03-03")] = -21.9`. Imprima `len(leituras)` e
# `leituras[("OLT-CENTRO-01", "2026-03-03")]`.

# %%
# ✍️ passo 10

# %% [markdown]
# **Preveja:** quantas chaves tem `leituras`, se o equipamento é o mesmo nas duas?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# **Duas** chaves: a chave é o **par** (equipamento, dia), e os dois pares são
# diferentes. Indexar por par é o que uma série de medições precisa — e só é possível
# porque a tupla não muda. Com uma lista no lugar, seria o `TypeError` da Aula 05.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Leitura do dia
#
# Escreva `leitura_do_dia(leituras, equipamento, dia)`, que devolve a potência
# guardada para aquele par, ou o texto `"sem leitura"` se o par não existir.

# %%
def leitura_do_dia(leituras, equipamento, dia):
    # sua solução aqui
    pass

# %%
exemplo = {("OLT-CENTRO-01", "2026-03-02"): -21.4, ("OLT-CENTRO-01", "2026-03-03"): -21.9}
confere(leitura_do_dia, [
    ((exemplo, "OLT-CENTRO-01", "2026-03-03"), -21.9),
    ((exemplo, "OLT-CENTRO-01", "2026-03-09"), "sem leitura"),
    ((exemplo, "ONU-SUL-4512", "2026-03-02"), "sem leitura"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# A chave é a tupla `(equipamento, dia)`. E para "o valor ou um padrão, se não
# existir", a Aula 05 tem o método certo.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def leitura_do_dia(leituras, equipamento, dia):
#     return leituras.get((equipamento, dia), "sem leitura")
# ```
#
# </details>

# %% [markdown]
# ## 4. Estruturas dentro de estruturas
#
# Todo inventário chega no mesmo formato: uma **lista de dicionários**, um dicionário
# por equipamento. Não há nada novo — é a lista da Aula 03 com o dicionário da Aula 05
# dentro. O que muda é o caminho até o dado: primeiro a posição na lista, depois a
# chave no dicionário.
#
# 📖 [capítulo 6 · Estruturas dentro de estruturas](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#estruturas-dentro-de-estruturas)
#
# Rode a célula abaixo: é o inventário que vamos usar.

# %%
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
    {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
    {"nome": "OLT-NORTE-02", "tipo": "OLT", "portas": 8, "em_servico": False},
]

# %% [markdown]
# **✍️ Passo 11.** Imprima `len(inventario)`. Depois chegue ao nome do primeiro equipamento **um passo
# por vez**: `primeiro = inventario[0]`, `print(primeiro)`, `print(primeiro["nome"])`.
# Por fim, as duas coisas numa linha só: `print(inventario[0]["nome"])`.

# %%
# ✍️ passo 11

# %% [markdown]
# **Preveja:** `len(inventario)` é 3 ou 12? E o que é `primeiro` — um nome, uma lista ou outra
# coisa?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `3`: a lista tem três **dicionários**, e `len` conta os itens da lista, não os pares
# de dentro. `primeiro` é um dicionário inteiro; `["nome"]` entra nele.
# `inventario[0]["nome"]` é o mesmo caminho, lido da esquerda para a direita.
#
# </details>

# %% [markdown]
# **✍️ Passo 12.** Percorra: `for equipamento in inventario:` e, **se** `equipamento["em_servico"]`,
# imprima `equipamento["nome"], equipamento["portas"]`.

# %%
# ✍️ passo 12

# %% [markdown]
# **Preveja:** o que é `equipamento` a cada volta do laço? Quantas linhas saem?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# A cada volta, `equipamento` é **um dicionário**. Saem duas linhas — a OLT-NORTE-02
# está fora de serviço e o `if` a pula.
#
# </details>

# %% [markdown]
# **✍️ Passo 13.** Total de portas em serviço: `total = 0` e, no laço, **se** o equipamento está em
# serviço, `total = total + equipamento["portas"]`. Imprima `total`.

# %%
# ✍️ passo 13

# %% [markdown]
# **Preveja:** o total inclui a OLT fora de serviço? Que número sai?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `17` — 16 da OLT-CENTRO-01 mais 1 da ONU. É o **acumulador** da Aula 03, com um
# campo do dicionário no lugar do número.
#
# </details>

# %% [markdown]
# **✍️ Passo 14.** Mais dois padrões sobre o mesmo inventário. **Distintos:** `tipos = set()` e, no
# laço, `tipos.add(e["tipo"])`; imprima `sorted(tipos)`. **Contagem de grandeza:**
# `portas_por_tipo = {}` e, para os em serviço,
# `portas_por_tipo[e["tipo"]] = portas_por_tipo.get(e["tipo"], 0) + e["portas"]`;
# imprima `portas_por_tipo`.

# %%
# ✍️ passo 14

# %% [markdown]
# **Preveja:** a última linha é a contagem da Aula 05. O que muda em relação a ela?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# `['OLT', 'ONU']` e `{'OLT': 16, 'ONU': 1}`. A contagem é a mesma linha da Aula 05 —
# a única diferença é **o que se soma**: lá era `+ 1` (ocorrências), aqui é
# `+ e["portas"]` (uma grandeza). Cada estrutura nova **não** exige uma técnica nova.
#
# </details>

# %% [markdown]
# ### 🎯 Sua vez — Portas de um tipo
#
# Escreva `total_portas(inventario, tipo)`, que devolve o total de portas dos
# equipamentos **daquele tipo** que estão **em serviço**.

# %%
def total_portas(inventario, tipo):
    # sua solução aqui
    pass

# %%
confere(total_portas, [
    ((inventario, "OLT"), 16),
    ((inventario, "ONU"), 1),
    ((inventario, "RADIO"), 0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Acumulador com um `if` de duas condições, ligadas por `and`: o tipo tem que ser o
# pedido **e** o equipamento tem que estar em serviço.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def total_portas(inventario, tipo):
#     total = 0
#     for e in inventario:
#         if e["tipo"] == tipo and e["em_servico"]:
#             total = total + e["portas"]
#     return total
# ```
#
# </details>

# %% [markdown]
# ## 5. Consultar pelo nome, sem percorrer tudo
#
# Procurar um equipamento pelo nome percorrendo a lista funciona — mas se você vai
# consultar muitas vezes, vale montar **uma vez** um dicionário indexado pelo nome, e
# depois consultar direto. É a ideia do índice de um livro.
#
# 📖 [capítulo 6 · Consultar pelo nome, sem percorrer tudo](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#consultar-pelo-nome-sem-percorrer-tudo)

# %% [markdown]
# **✍️ Passo 15.** Monte o índice: `por_nome = {}` e, para cada `e` do inventário,
# `por_nome[e["nome"]] = e`. Imprima `por_nome["OLT-NORTE-02"]["portas"]` e
# `sorted(por_nome)`.

# %%
# ✍️ passo 15

# %% [markdown]
# **Preveja:** o que é o valor guardado em `por_nome["OLT-NORTE-02"]`? E se eu precisar consultar
# 500 nomes numa lista de 2000 equipamentos?
#
# _Sua previsão:_
#
# → escreva aqui **antes** de rodar a célula acima.

# %% [markdown]
# <details>
# <summary><b>▶ O que aconteceu</b></summary>
#
# O valor é o **dicionário inteiro** do equipamento — por isso dá para continuar com
# `["portas"]` e sai `8`. Com a lista, cada uma das 500 consultas percorreria até 2000
# itens; com o índice, a lista é percorrida **uma vez** e cada consulta vai direto.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# Rode a célula abaixo: as duas listas da auditoria.

# %%
nms = ["OLT-CENTRO-01", "OLT-NORTE-02", "ONU-SUL-4512", "SWITCH-NORTE-02", "RADIO-OESTE-01"]
campo = ["OLT-CENTRO-01", "SWITCH-NORTE-02", "OLT-CENTRO-01", "ONU-LESTE-77",
         "RADIO-OESTE-01", "SWITCH-NORTE-02", "OLT-NORTE-02"]

# %% [markdown]
# ### 🎯 Sua vez — A auditoria
#
# Escreva `auditoria(nms, campo)`, que devolve **dois valores**, cada um uma lista
# **ordenada**:
#
# 1. os **fantasmas**: estão no NMS e o campo não achou;
# 2. os **sem gerência**: o campo achou e o NMS não conhece.

# %%
def auditoria(nms, campo):
    # sua solução aqui
    pass

# %%
confere(auditoria, [
    ((nms, campo), (["ONU-SUL-4512"], ["ONU-LESTE-77"])),
    ((["A", "B"], ["B", "A", "A"]), ([], [])),
    ((["A"], ["C", "B"]), (["A"], ["B", "C"])),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Duas diferenças de conjuntos, em sentidos opostos — cuidado com os lados. No fim,
# `return sorted(...), sorted(...)`.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>✅ Uma solução</b></summary>
#
# ```python
# def auditoria(nms, campo):
#     no_nms = set(nms)
#     no_campo = set(campo)
#     fantasmas = sorted(no_nms - no_campo)
#     sem_gerencia = sorted(no_campo - no_nms)
#     return fantasmas, sem_gerencia
# ```
#
# </details>

# %% [markdown]
# **Resposta ao chamado:** a `ONU-SUL-4512` está no NMS mas não foi achada em campo
# (retirada sem baixa no sistema?), e a `ONU-LESTE-77` está instalada e ninguém a
# gerencia — se ela cair, nenhum alarme vai tocar.

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `{}` cria:
# a) um conjunto vazio  b) um dicionário vazio  c) uma tupla vazia  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. Conjunto vazio é `set()`.
#
# </details>

# %% [markdown]
# **2.** Para saber quais equipamentos **sumiram** entre ontem e hoje:
# a) `hoje - ontem`  b) `ontem - hoje`  c) `hoje & ontem`  d) `hoje | ontem`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**: o que estava ontem e não está hoje.
#
# </details>

# %% [markdown]
# **3.** Num laço `for e in inventario`, onde `inventario` é uma lista de
# dicionários, `e` é:
# a) o nome do equipamento  b) um dicionário  c) o índice do item  d) uma lista

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# **b**. Por isso o acesso ao nome é `e["nome"]`.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 06](https://lacouth.github.io/python_telecom-site/listas/lista06/) —
#   conjuntos, tuplas e inventário, com testes automáticos no Colab.
# - Releia o [capítulo 6 do site](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/).
# - **Na próxima aula:** mini-teste sobre esta aula (conjuntos e lista de
#   dicionários).
