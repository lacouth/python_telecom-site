# %% [markdown]
# # Aula 06B · Conjuntos, tuplas e inventário
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 6 do
# site](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula06a-conjuntos-tuplas.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 06, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# `{}` cria:
# a) um conjunto vazio  b) um dicionário vazio  c) uma tupla vazia  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. Conjunto vazio é `set()`.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **Conjunto não tem ordem nem repetição.** É por isso que o conjunto compara duas listas numa linha — e é por isso que o
# resultado dele precisa de `sorted` antes de virar relatório ou resposta.
#
# A ordem em que um conjunto aparece na tela **não é garantida**: pode mudar de uma
# execução para a outra. Resposta que depende dela passa hoje e falha amanhã. E o
# conjunto vazio é `set()`: o `{}` cria um **dicionário**.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Rode as células abaixo: são os dados da noite A que os exercícios usam.

# %%
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
    {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
    {"nome": "OLT-NORTE-02", "tipo": "OLT", "portas": 8, "em_servico": False},
]

# %% [markdown]
# Vem do bloco *3. Tuplas: a sequência que não muda* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 6 · Tuplas: a sequência que não muda](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#tuplas-a-sequencia-que-nao-muda)

# %% [markdown]
# ### 🎯 Sua vez — Leitura do dia
#
# Escreva `leitura_do_dia(leituras, equipamento, dia)`, que devolve a potência
# guardada para aquele par, ou o texto `"sem leitura"` se o par não existir.

# %%
def leitura_do_dia(leituras, equipamento, dia):
    # sua solução aqui
    pass

# %%
exemplo = {("OLT-CENTRO-01", "2026-03-02"): -21.4, ("OLT-CENTRO-01", "2026-03-03"): -21.9}
confere(leitura_do_dia, [
    ((exemplo, "OLT-CENTRO-01", "2026-03-03"), -21.9),
    ((exemplo, "OLT-CENTRO-01", "2026-03-09"), "sem leitura"),
    ((exemplo, "ONU-SUL-4512", "2026-03-02"), "sem leitura"),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# A chave é a tupla `(equipamento, dia)`. E para "o valor ou um padrão, se não
# existir", a Aula 05 tem o método certo.
#
# </details>

# %% [markdown]
# Vem do bloco *4. Estruturas dentro de estruturas* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 6 · Estruturas dentro de estruturas](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/#estruturas-dentro-de-estruturas)

# %% [markdown]
# ### 🎯 Sua vez — Portas de um tipo
#
# Escreva `total_portas(inventario, tipo)`, que devolve o total de portas dos
# equipamentos **daquele tipo** que estão **em serviço**.

# %%
def total_portas(inventario, tipo):
    # sua solução aqui
    pass

# %%
confere(total_portas, [
    ((inventario, "OLT"), 16),
    ((inventario, "ONU"), 1),
    ((inventario, "RADIO"), 0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Acumulador com um `if` de duas condições, ligadas por `and`: o tipo tem que ser o
# pedido **e** o equipamento tem que estar em serviço.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #0603 — NOC Maré Net**
# >
# > *"Estagiário, auditoria: o sistema de gerência (NMS) diz que temos uma lista de
# > equipamentos; a equipe de campo percorreu os sites e anotou outra. **As duas não
# > batem.** Preciso saber o que o NMS tem e o campo não achou (equipamento fantasma)
# > e o que o campo achou e o NMS não conhece (equipamento sem gerência). A lista de
# > campo tem repetição, porque cada técnico anotou o seu pedaço."*
#
# Rode a célula abaixo: as duas listas da auditoria.

# %%
nms = ["OLT-CENTRO-01", "OLT-NORTE-02", "ONU-SUL-4512", "SWITCH-NORTE-02", "RADIO-OESTE-01"]
campo = ["OLT-CENTRO-01", "SWITCH-NORTE-02", "OLT-CENTRO-01", "ONU-LESTE-77",
         "RADIO-OESTE-01", "SWITCH-NORTE-02", "OLT-NORTE-02"]

# %% [markdown]
# ### 🎯 Sua vez — A auditoria
#
# Escreva `auditoria(nms, campo)`, que devolve **dois valores**, cada um uma lista
# **ordenada**:
#
# 1. os **fantasmas**: estão no NMS e o campo não achou;
# 2. os **sem gerência**: o campo achou e o NMS não conhece.

# %%
def auditoria(nms, campo):
    # sua solução aqui
    pass

# %%
confere(auditoria, [
    ((nms, campo), (["ONU-SUL-4512"], ["ONU-LESTE-77"])),
    ((["A", "B"], ["B", "A", "A"]), ([], [])),
    ((["A"], ["C", "B"]), (["A"], ["B", "C"])),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Duas diferenças de conjuntos, em sentidos opostos — cuidado com os lados. No fim,
# `return sorted(...), sorted(...)`.
#
# </details>

# %% [markdown]
# **Resposta ao chamado:** a `ONU-SUL-4512` está no NMS mas não foi achada em campo
# (retirada sem baixa no sistema?), e a `ONU-LESTE-77` está instalada e ninguém a
# gerencia — se ela cair, nenhum alarme vai tocar.

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 06](https://lacouth.github.io/python_telecom-site/listas/lista06/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista06.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `equipamentos_distintos`**

# %% [markdown]
# **1.** Onde está o nome do equipamento em cada linha?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# No quarto campo: `linha.split()[3]`, como na Aula 05.
#
# </details>

# %% [markdown]
# **2.** Como nasce o conjunto, e como ele cresce?

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# Nasce com `set()`, antes do laço, e cresce com `add`. A repetição some sozinha: adicionar um nome que já está lá não muda nada.
#
# </details>

# %% [markdown]
# **3.** Por que o `sorted` no fim?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# Porque o enunciado pede uma **lista ordenada**, e o conjunto não tem ordem. `sorted` recebe o conjunto e devolve uma lista nova, em ordem alfabética.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** `len({"OLT-A", "OLT-B", "OLT-A"})` vale:
# a) `3`  b) `2`  c) `1`  d) erro

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. O conjunto guarda `"OLT-A"` uma vez só.
#
# </details>

# %% [markdown]
# **2.** Com `t = (-21.4, "OLT-A")`, a linha `t[0] = -20.0` dá:
# a) muda a tupla  b) `TypeError`  c) cria outra tupla  d) `None`

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **b**. A tupla não muda depois de criada — é por isso que ela pode ser chave de dicionário.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 06](https://lacouth.github.io/python_telecom-site/listas/lista06/) —
#   conjuntos, tuplas e inventário, com testes automáticos no Colab.
# - Releia o [capítulo 6 do site](https://lacouth.github.io/python_telecom-site/unidade2-colecoes/06-conjuntos-tuplas/).
# - **Na próxima noite A:** mini-teste sobre esta aula (conjuntos e lista de
#   dicionários).
