# %% [markdown]
# # Aula 12B · matplotlib e KPIs
#
# **Noite B — o problema.** Nenhum conceito novo: esta noite é laboratório sobre o
# [capítulo 12 do
# site](https://lacouth.github.io/python_telecom-site/unidade6-dados/12-matplotlib-kpis/),
# que a [noite
# A](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/aula12a-matplotlib-kpis.ipynb)
# apresentou. Faltou à noite A? Cada exercício traz o link 📖 para a seção que ele usa
# — e o caderno da noite A tem os passos.
#
# **Roteiro** (1h40): 🔥 aquecimento · ⚠️ a regra da noite · 🎯 prática · 📟 resolvendo o
# chamado · 📋 a Lista 12, começada aqui · 🚪 antes de sair

# %% [markdown]
# ## Como usar este caderno
#
# - **Rode a célula ⚙️** logo abaixo antes de tudo (e de novo se o Colab reiniciar).
# - **🎯 Sua vez:** escreva a solução e rode a célula `confere` logo abaixo dela —
#   ✅ quer dizer que acertou, ❌ mostra o que ainda falta. A dica está recolhida:
#   tente antes de abrir.
# - Travou? Antes da dica, abra o link 📖 do exercício: a seção do capítulo que
#   ele usa tem o exemplo completo.

# %%
# ⚙️ Rode esta célula antes de tudo. Ela prepara a correção automática dos
# exercícios 🎯 — não precisa ler agora (usa coisas que só veremos mais tarde).
import math


def _mostra(argumentos):
    return ", ".join(repr(a) for a in argumentos)


def _igual(veio, esperado):
    if isinstance(esperado, float) and isinstance(veio, (int, float)):
        return math.isclose(veio, esperado, abs_tol=1e-9)
    return veio == esperado


def confere(funcao, casos):
    """Chama funcao com cada caso (argumentos, esperado) e diz se acertou."""
    certos = 0
    for numero, (argumentos, esperado) in enumerate(casos, start=1):
        chamada = f"{funcao.__name__}({_mostra(argumentos)})"
        try:
            veio = funcao(*argumentos)
        except Exception as erro:
            print(f"❌ {chamada} deu erro: {type(erro).__name__}: {erro}")
            continue
        if _igual(veio, esperado):
            certos += 1
            print(f"✅ {chamada} devolveu {veio!r}")
        elif veio is None:
            print(f"❌ {chamada} devolveu None — faltou o return?")
        else:
            print(f"❌ {chamada} devolveu {veio!r}, mas devia ser {esperado!r}")
    print(f"{certos} de {len(casos)} certos")


def confere_valor(nome, valor, esperado):
    """Diz se a variável `nome` ficou com o valor esperado."""
    if _igual(valor, esperado):
        print(f"✅ {nome} = {valor!r}")
    else:
        print(f"❌ {nome} vale {valor!r}, mas devia ser {esperado!r}")


# --- dados desta aula ---
import os
import urllib.request

ARQUIVO = "medicoes_mes.csv"
if not os.path.exists(ARQUIVO):
    urllib.request.urlretrieve(
        "https://lacouth.github.io/python_telecom-site/dados/medicoes_mes.csv", ARQUIVO)
print(ARQUIVO, "pronto")

# %% [markdown]
# ## 🔥 Aquecimento — a pergunta que ficou
#
# No fim da noite A ficou uma pergunta sem resposta. Responda de cabeça, sem rodar.
#
# Para mostrar a **evolução** do tráfego ao longo do mês, o gráfico é:
# a) barras  b) linha  c) histograma  d) pizza

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **b**. Linha para evolução no tempo; barras para comparar grupos; histograma para
# distribuição.
#
# </details>

# %% [markdown]
# ## ⚠️ A regra da noite
#
# **Escreva a pergunta antes do gráfico.** A pergunta escolhe o tipo — **linha** para evolução, **barras** para comparar,
# **histograma** para distribuição —, a referência (o SLA, o limite) e o título.
#
# Todo gráfico de hoje sai com os **eixos rotulados, com unidade**: gráfico sem
# unidade não responde nada. E o `savefig` vem **antes** do `show`.

# %% [markdown]
# ## 🎯 Prática
#
# Nenhum passo novo: cada exercício usa uma seção da noite A, indicada no link 📖
# logo acima dele. Do mais simples para o mais completo.

# %% [markdown]
# Rode as células abaixo: são os dados da noite A que os exercícios usam.

# %%
# 📦 dados prontos — só rode esta célula
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("medicoes_mes.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df["dia"] = df["timestamp"].dt.day
df["hora"] = df["timestamp"].dt.hour
df["no_ar"] = df["estado"] == "UP"

# %% [markdown]
# Vem do bloco *3. O gráfico que engana* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 12 · O gráfico que engana](https://lacouth.github.io/python_telecom-site/unidade6-dados/12-matplotlib-kpis/#o-grafico-que-engana)

# %% [markdown]
# ### 🎯 Sua vez — Quantas horas isso dá?
#
# Para dizer a diferença em horas, em vez de %, escreva
# `horas_fora(disponibilidade, horas=744)`, que converte uma disponibilidade em % no
# número de horas fora do ar no período, com 1 casa.

# %%
def horas_fora(disponibilidade, horas=744):
    # sua solução aqui
    pass

# %%
confere(horas_fora, [
    ((99.731,), 2.0),
    ((99.194,), 6.0),
    ((99.5,), 3.7),
    ((100,), 0.0),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# A fração fora do ar é `(100 - disponibilidade) / 100`; vezes as horas do período.
#
# </details>

# %% [markdown]
# Vem do bloco *4. Histograma: como os valores se distribuem* da noite A, e os passos citados na dica são de lá: 📖 [capítulo 12 · Histograma: como os valores se distribuem](https://lacouth.github.io/python_telecom-site/unidade6-dados/12-matplotlib-kpis/#histograma-como-os-valores-se-distribuem)

# %% [markdown]
# ### 🎯 Sua vez — Quantas medições na faixa
#
# O histograma conta medições por faixa. Escreva `quantas_na_faixa(df, minimo, maximo)`,
# que devolve quantas medições de potência ficaram **de `minimo` (inclusive) até
# `maximo` (exclusive)**, como `int`.

# %%
def quantas_na_faixa(df, minimo, maximo):
    # sua solução aqui
    pass

# %%
confere(quantas_na_faixa, [
    ((df, -27, -25), 244),
    ((df, -25, -20), 2722),
    ((df, -20, -19), 738),
])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# Uma máscara com duas condições — `>= minimo` e `< maximo` —, cada uma entre
# parênteses, ligadas por `&`; some e converta com `int(...)`.
#
# </details>

# %% [markdown]
# ## 📟 Resolvendo o chamado
#
# O chamado que a noite A abriu:
#
# > **Chamado #1215 — NOC Maré Net**
# >
# > *"Estagiário, a reunião mensal com a diretoria é amanhã. Eles não leem tabela. Preciso
# > de **uma figura** que mostre, de relance, quais OLTs descumpriram o SLA de 99,5% em
# > março — e de outra que explique por que a equipe de campo tem que visitar a
# > OLT-SUL-03 esta semana, mesmo ela nunca tendo caído."*
#
# A primeira figura do chamado: as barras de disponibilidade com o SLA.

# %% [markdown]
# ### 🎯 Sua vez — A figura do SLA
#
# Escreva `grafico_sla(df, sla)`, que **desenha** as barras da disponibilidade de cada
# enlace com a linha do SLA, eixo y de 98 a 100,2 (e diga isso no título), eixo y com
# `%` — e **devolve** a lista ordenada dos enlaces abaixo do SLA. Chame `plt.show()` no
# fim da função.

# %%
def grafico_sla(df, sla):
    # sua solução aqui
    pass

# %%
confere(grafico_sla, [((df, 99.5), ["OLT-LESTE-04", "OLT-OESTE-05"])])

# %% [markdown]
# <details>
# <summary><b>💡 Dica</b></summary>
#
# A disponibilidade é a do passo da seção 2. Desenhe como lá, com `plt.ylim(98, 100.2)`;
# antes do `return`, o filtro `disp[disp < sla]` e `sorted(....index.tolist())`.
#
# </details>

# %% [markdown]
# A segunda figura do chamado é a linha da seção 1 da noite A: a potência da OLT-SUL-03 cruzando o
# alerta no dia 22 e seguindo para a sensibilidade da ONU no começo de abril. Ela nunca
# caiu — e é exatamente por isso que o gráfico importa: nenhum alarme de "fora do ar"
# teria avisado.

# %% [markdown]
# ## 📋 A lista, começada aqui
#
# Abra a [Lista 12](https://lacouth.github.io/python_telecom-site/listas/lista12/) —
# ou direto o [caderno dela no
# Colab](https://colab.research.google.com/github/lacouth/python_telecom-site/blob/main/notebooks/lista12.ipynb)
# — e rode a célula de preparo. O **exercício 1** a turma faz junto, respondendo às
# perguntas abaixo **antes** de escrever; do 2 em diante, cada um no seu ritmo, com o
# professor circulando.
#
# **Exercício 1 — `potencia_por_dia`**

# %% [markdown]
# **1.** Por onde começar?

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# Pelo filtro: um DataFrame novo só com as linhas do enlace pedido, com a máscara `df["enlace"] == enlace`.
#
# </details>

# %% [markdown]
# **2.** De onde sai o dia?

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# O `timestamp` já chega convertido, então `.dt.day` dá o dia do mês. Guarde numa coluna nova, `dia`, no DataFrame filtrado.
#
# </details>

# %% [markdown]
# **3.** E o dicionário?

# %% [markdown]
# <details>
# <summary><b>Resposta da 3</b></summary>
#
# Agrupe pelo dia, tire a média da potência, arredonde com 2 casas e termine com `.to_dict()`. Olhe o nome da coluna de potência no CSV antes de escrever.
#
# </details>

# %% [markdown]
# ## 🚪 Antes de sair
#
# Responda de cabeça, sem rodar.
#
# **1.** Para mostrar como as potências de um mês **se distribuem**, o gráfico é:
# a) linha  b) barras  c) histograma  d) pizza

# %% [markdown]
# <details>
# <summary><b>Resposta da 1</b></summary>
#
# **c**. Histograma: quantas medições caíram em cada faixa de valor.
#
# </details>

# %% [markdown]
# **2.** `plt.axhline(99.5)` desenha:
# a) uma linha horizontal na altura 99,5  b) uma linha vertical  c) uma barra  d) um ponto

# %% [markdown]
# <details>
# <summary><b>Resposta da 2</b></summary>
#
# **a**. É a referência que diz ao leitor onde fica o SLA.
#
# </details>

# %% [markdown]
# ## 🏠 Para casa
#
# - [Lista 12](https://lacouth.github.io/python_telecom-site/listas/lista12/) —
#   matplotlib e KPIs, com testes automáticos no Colab.
# - Releia o [capítulo 12 do site](https://lacouth.github.io/python_telecom-site/unidade6-dados/12-matplotlib-kpis/), principalmente o checklist antes de pôr um gráfico num
#   relatório: 📖 [capítulo 12 · Checklist de um gráfico de relatório](https://lacouth.github.io/python_telecom-site/unidade6-dados/12-matplotlib-kpis/#checklist-de-um-grafico-de-relatorio).
# - **Semana que vem:** revisão na noite A e **Avaliação 2** na noite B (capítulos 9 a 12). Refaça as listas 09 a 12.
