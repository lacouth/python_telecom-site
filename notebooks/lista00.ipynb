# %% [markdown]
# # Lista 00 · Primeiros passos: variáveis, decisões e repetições
#
# Esta é a lista do [Capítulo 0](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/),
# para quem está começando a programar. Ela cobre, em ordem: contas com variáveis,
# comparações, `if`/`elif`/`else`, `and`/`or`, `while` e `for`.
#
# Todo exercício tem o mesmo formato: uma **função** já começada, com o nome e os
# valores que ela recebe. O seu trabalho é escrever o corpo dela, no lugar do
# `# TODO`, e terminar com um `return` que devolve o resultado. Depois, rode a
# célula de teste logo abaixo: ela diz se a função está certa.
#
# Se um termo de telecomunicações parecer estranho, a página
# [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/) explica. E se
# travar, releia a seção do capítulo indicada no enunciado — os exemplos de lá são
# quase a resposta.
#
# ---
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.
#
# Termo de telecom estranho no enunciado? Veja
# [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/) ou o
# [glossário](https://lacouth.github.io/python_telecom-site/apendices/glossario/).

# %% [markdown]
# ### Exercício 01
#
# Uma OLT tem várias **portas**, e cada porta atende um certo número de clientes
# (veja [OLT, divisor e ONU](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/#olt-divisor-e-onu-a-fibra-ate-a-casa-do-cliente)).
#
# Escreva a função `clientes_atendidos`, que recebe a quantidade de portas e a
# quantidade de clientes por porta e **devolve** o total de clientes que a OLT atende.
#
# ```python
# clientes_atendidos(16, 32)   # -> 512
# clientes_atendidos(8, 64)    # -> 512
# ```
#
# Dica: é uma multiplicação (`*`). Reveja [Uma primeira função](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#uma-primeira-funcao)
# para lembrar do `return`.

# %%
def clientes_atendidos(portas, clientes_por_porta):
    """Devolve o total de clientes atendidos pela OLT."""
    # TODO: multiplique as portas pelos clientes por porta e devolva o resultado
    pass

# %%
# Célula de teste — Exercício 01
assert clientes_atendidos(16, 32) == 512
assert clientes_atendidos(8, 64) == 512
assert clientes_atendidos(1, 1) == 1
assert clientes_atendidos(0, 32) == 0
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# O sinal perde força em cada parte do caminho: na fibra, nos divisores e nos
# conectores (veja [Atenuação, sensibilidade e margem](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/#atenuacao-sensibilidade-e-margem)).
# A perda total do caminho, em dB, é a soma das três.
#
# Escreva a função `perda_total`, que recebe as três perdas e devolve a soma delas.
#
# ```python
# perda_total(5.0, 17.0, 1.5)   # -> 23.5
# ```

# %%
def perda_total(perda_fibra, perda_divisores, perda_conectores):
    """Devolve a perda total do caminho, em dB."""
    # TODO: some as três perdas e devolva o resultado
    pass

# %%
# Célula de teste — Exercício 02
assert perda_total(5.0, 17.0, 1.5) == 23.5
assert perda_total(0, 0, 0) == 0
assert perda_total(2.5, 3.5, 0.5) == 6.5
assert perda_total(10, 20, 1) == 31
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# A **disponibilidade** é a porcentagem do tempo em que o serviço funcionou (veja
# [Disponibilidade, SLA e KPI](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/#disponibilidade-sla-e-kpi)).
# Um mês de 30 dias tem 720 horas. Se a disponibilidade foi de 99%, o serviço ficou
# fora do ar 1% dessas horas:
#
# ```
# horas fora = 720 * (100 - disponibilidade) / 100
# ```
#
# Escreva a função `horas_fora`, que recebe a disponibilidade (em %) e devolve as
# horas fora do ar no mês, **arredondadas para duas casas decimais**.
#
# ```python
# horas_fora(99)      # -> 7.2
# horas_fora(99.9)    # -> 0.72
# ```
#
# Dica: `round(valor, 2)` arredonda `valor` para duas casas. As contas com números
# decimais às vezes dão resultados como `0.7200000000000273`; o `round` resolve.

# %%
def horas_fora(disponibilidade):
    """Devolve as horas fora do ar num mês de 720 horas, com duas casas."""
    # TODO: aplique a fórmula do enunciado e devolva o resultado com round(..., 2)
    pass

# %%
# Célula de teste — Exercício 03
assert horas_fora(99) == 7.2
assert horas_fora(99.9) == 0.72
assert horas_fora(99.5) == 3.6
assert horas_fora(100) == 0
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Nas ONUs da Maré Net, uma potência **abaixo de −27 dBm** é fraca demais.
#
# Escreva a função `abaixo_do_limite`, que recebe a potência (em dBm) e devolve
# `True` se ela estiver abaixo de −27, e `False` se não estiver.
#
# ```python
# abaixo_do_limite(-28.0)   # -> True
# abaixo_do_limite(-21.4)   # -> False
# abaixo_do_limite(-27)     # -> False   (−27 não está ABAIXO de −27)
# ```
#
# Dica: uma comparação já é `True` ou `False` — dá para devolver a comparação
# direto. Reveja [Comparações](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#comparacoes-perguntas-de-sim-ou-nao).

# %%
def abaixo_do_limite(potencia):
    """Devolve True se a potência estiver abaixo de -27 dBm."""
    # TODO: devolva o resultado da comparação da potência com -27
    pass

# %%
# Célula de teste — Exercício 04
assert abaixo_do_limite(-28.0) == True
assert abaixo_do_limite(-21.4) == False
assert abaixo_do_limite(-27) == False
assert abaixo_do_limite(-27.1) == True
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# Escreva a função `classifica`, que recebe a potência de uma ONU (em dBm) e devolve
# um texto:
#
# | Potência | Devolve |
# |---|---|
# | −25 ou mais | `"bom"` |
# | de −27 até −25 (sem incluir o −25) | `"atencao"` |
# | abaixo de −27 | `"critico"` |
#
# ```python
# classifica(-21.4)   # -> "bom"
# classifica(-26.0)   # -> "atencao"
# classifica(-30.0)   # -> "critico"
# ```
#
# Dica: é o exemplo da seção [`elif` e `else`](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#elif-e-else-mais-de-um-caminho),
# com `return` no lugar do `print`.

# %%
def classifica(potencia):
    """Classifica a potência em 'bom', 'atencao' ou 'critico'."""
    # TODO: use if, elif e else, com um return em cada caminho
    pass

# %%
# Célula de teste — Exercício 05
assert classifica(-21.4) == "bom"
assert classifica(-25) == "bom"
assert classifica(-26.0) == "atencao"
assert classifica(-27) == "atencao"
assert classifica(-27.5) == "critico"
assert classifica(-30.0) == "critico"
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# O NOC só abre chamado para a equipe de campo quando as **duas** coisas acontecem:
# o cliente está em serviço (`em_servico` é `True`) **e** a potência está abaixo de
# −27 dBm. Cliente que cancelou o contrato não gera chamado, com qualquer potência.
#
# Escreva a função `abre_chamado`, que devolve `True` quando é preciso abrir
# chamado e `False` quando não é.
#
# ```python
# abre_chamado(-28.0, True)    # -> True
# abre_chamado(-28.0, False)   # -> False
# abre_chamado(-21.0, True)    # -> False
# ```
#
# Dica: reveja [`and`, `or` e `not`](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#and-or-e-not).

# %%
def abre_chamado(potencia, em_servico):
    """Devolve True se o cliente está em serviço e a potência está abaixo de -27 dBm."""
    # TODO: junte as duas condições com and e devolva o resultado
    pass

# %%
# Célula de teste — Exercício 06
assert abre_chamado(-28.0, True) == True
assert abre_chamado(-28.0, False) == False
assert abre_chamado(-21.0, True) == False
assert abre_chamado(-21.0, False) == False
print("Exercício 06: todos os testes passaram!")

# %% [markdown]
# ### Exercício 07
#
# Cada divisor que reparte o sinal em dois tira 3 dB da potência. Começando de uma
# potência inicial, quantos divisores cabem **enquanto** a potência estiver acima de
# −27 dBm?
#
# Escreva a função `divisores_possiveis`, que recebe a potência inicial e devolve
# quantos divisores cabem, contando como no exemplo da seção
# [`while`](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#while-repetir-enquanto):
# enquanto a potência for maior que −27, tire 3 dela e conte mais um divisor.
#
# ```python
# divisores_possiveis(-15.0)   # -> 4   (-18, -21, -24, -27)
# divisores_possiveis(-26.0)   # -> 1   (-29)
# divisores_possiveis(-30.0)   # -> 0   (já está abaixo)
# ```

# %%
def divisores_possiveis(potencia):
    """Devolve quantos divisores de 3 dB cabem enquanto a potência estiver acima de -27 dBm."""
    # TODO: crie um contador valendo 0, repita com while e devolva o contador
    pass

# %%
# Célula de teste — Exercício 07
assert divisores_possiveis(-15.0) == 4
assert divisores_possiveis(-26.0) == 1
assert divisores_possiveis(-30.0) == 0
assert divisores_possiveis(-27) == 0
assert divisores_possiveis(0) == 9
print("Exercício 07: todos os testes passaram!")

# %% [markdown]
# ### Exercício 08
#
# Uma promoção da Maré Net trouxe 1 cliente novo no primeiro dia, 2 no segundo, 3 no
# terceiro, e assim por diante. Quantos clientes novos chegaram no total, depois de
# um certo número de dias?
#
# Escreva a função `clientes_novos`, que recebe o número de dias e devolve o total.
#
# ```python
# clientes_novos(3)   # -> 6    (1 + 2 + 3)
# clientes_novos(5)   # -> 15   (1 + 2 + 3 + 4 + 5)
# ```
#
# Dica: um `for` com `range` que vai de 1 até `dias` (lembre que o `range` para
# **antes** do segundo número), somando cada dia numa variável que começa em 0.
# Reveja [`for`](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#for-repetir-para-cada-item).

# %%
def clientes_novos(dias):
    """Devolve 1 + 2 + ... + dias."""
    # TODO: crie a soma valendo 0, percorra os dias com for e range e devolva a soma
    pass

# %%
# Célula de teste — Exercício 08
assert clientes_novos(3) == 6
assert clientes_novos(5) == 15
assert clientes_novos(1) == 1
assert clientes_novos(0) == 0
assert clientes_novos(30) == 465
print("Exercício 08: todos os testes passaram!")

# %% [markdown]
# ### Exercício 09
#
# Escreva a função `conta_abaixo`, que recebe uma lista de medições de potência e um
# limite, e devolve **quantas** medições estão abaixo do limite.
#
# ```python
# conta_abaixo([-21.4, -28.0, -19.5, -27.3], -27)   # -> 2
# conta_abaixo([-21.4, -28.0, -19.5, -27.3], -20)   # -> 3
# ```
#
# Dica: é o exemplo da seção [Juntando tudo](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/00-primeiros-passos/#juntando-tudo),
# com o limite vindo do parâmetro e um `return` no fim, fora do `for`.

# %%
def conta_abaixo(medicoes, limite):
    """Devolve quantas medições estão abaixo do limite."""
    # TODO: um contador, um for sobre as medições e um if dentro dele
    pass

# %%
# Célula de teste — Exercício 09
assert conta_abaixo([-21.4, -28.0, -19.5, -27.3], -27) == 2
assert conta_abaixo([-21.4, -28.0, -19.5, -27.3], -20) == 3
assert conta_abaixo([-21.4, -19.5], -27) == 0
assert conta_abaixo([], -27) == 0
print("Exercício 09: todos os testes passaram!")

# %% [markdown]
# ### Exercício 10
#
# A média de uma lista de números é a soma de todos dividida pela quantidade.
#
# Escreva a função `media`, que recebe uma lista (com pelo menos uma medição) e
# devolve a média, **arredondada para duas casas**.
#
# ```python
# media([-20.0, -22.0, -24.0])   # -> -22.0
# media([-21.4, -28.0, -19.5])   # -> -22.97
# ```
#
# Dica: dentro de um único `for`, use **duas** variáveis que começam em 0: uma soma
# (que ganha cada medição) e um contador (que ganha 1 a cada volta). Depois do laço,
# divida uma pela outra e arredonde com `round(valor, 2)`.

# %%
def media(medicoes):
    """Devolve a média das medições, com duas casas."""
    # TODO: soma e quantidade num mesmo for; depois divida e arredonde
    pass

# %%
# Célula de teste — Exercício 10
assert media([-20.0, -22.0, -24.0]) == -22.0
assert media([-21.4, -28.0, -19.5]) == -22.97
assert media([-25.0]) == -25.0
assert media([10, 20]) == 15.0
print("Exercício 10: todos os testes passaram!")
