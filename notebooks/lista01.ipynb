# %% [markdown]
# # Lista 01 · Primeiros scripts: tipos, contas e formatação
#
# Esta lista cobre o que o capítulo 1 mostrou, apoiada no Capítulo 0:
# tipos numéricos, divisão inteira, `round`, `if/elif/else` e f-strings.
#
# Todos os enunciados saem do mesmo lugar: as contas que aparecem numa planilha de
# projeto de enlace. Nenhum deles precisa de mais de cinco linhas — se a sua
# solução está ficando longa, provavelmente há uma conta mais direta.
#
# ---
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.
#
# Termo de telecom estranho no enunciado? Veja
# [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/) ou o
# [glossário](https://lacouth.github.io/python_telecom-site/apendices/glossario/).

# %% [markdown]
# ### Exercício 01
#
# Em telecom, potência quase nunca é medida em miliwatts: é medida em **dBm**, que
# é a mesma potência numa escala logarítmica. A conversão é
#
# ```
# potencia_dbm = 10 * log10(potencia_mw)
# ```
#
# Escreva a função `mw_para_dbm`, que recebe a potência em miliwatts e devolve o
# valor em dBm **arredondado para duas casas**.
#
# ```python
# mw_para_dbm(1)     # -> 0.0
# mw_para_dbm(0.001) # -> -30.0
# ```
#
# Dica: `math.log10` já está importado para você.

# %%
import math


def mw_para_dbm(mw):
    """Converte potência em miliwatts para dBm, com duas casas decimais."""
    # TODO: aplique 10 * log10(mw) e arredonde com round(..., 2)
    pass

# %%
# Célula de teste — Exercício 01
assert mw_para_dbm(1) == 0.0
assert mw_para_dbm(10) == 10.0
assert mw_para_dbm(0.001) == -30.0
assert mw_para_dbm(2) == 3.01
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# Agora o caminho inverso: dado um valor em dBm, devolva a potência em miliwatts,
# **arredondada para quatro casas**.
#
# ```
# potencia_mw = 10 ** (potencia_dbm / 10)
# ```
#
# ```python
# dbm_para_mw(0)   # -> 1.0
# dbm_para_mw(-30) # -> 0.001
# ```

# %%
def dbm_para_mw(dbm):
    """Converte dBm para miliwatts, com quatro casas decimais."""
    # TODO: 10 elevado a (dbm / 10); em Python, potência é **
    pass

# %%
# Célula de teste — Exercício 02
assert dbm_para_mw(0) == 1.0
assert dbm_para_mw(10) == 10.0
assert dbm_para_mw(-30) == 0.001
assert dbm_para_mw(-3) == 0.5012
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# Um cliente quer saber quanto tempo leva para baixar um arquivo. O tamanho vem em
# **megabytes** e a taxa contratada, em **megabits por segundo** — é exatamente aí
# que quase todo mundo erra por um fator de 8.
#
# Escreva `tempo_download(tamanho_mb, taxa_mbps)`, que devolve o tempo em segundos
# arredondado para duas casas.
#
# ```python
# tempo_download(100, 100)  # -> 8.0   (100 MB = 800 Mb, a 100 Mb/s)
# tempo_download(1, 10)     # -> 0.8
# ```

# %%
def tempo_download(tamanho_mb, taxa_mbps):
    """Tempo, em segundos, para transferir tamanho_mb a taxa_mbps."""
    # TODO: converta megabytes para megabits antes de dividir
    pass

# %%
# Célula de teste — Exercício 03
assert tempo_download(100, 100) == 8.0
assert tempo_download(1, 10) == 0.8
assert tempo_download(50, 200) == 2.0
assert tempo_download(700, 60) == 93.33
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Um enlace de fibra perde sinal de duas formas: pela **atenuação do cabo** (tantos
# dB por quilômetro) e pelos **conectores e emendas** no caminho.
#
# Escreva `atenuacao_total(km, db_por_km, conectores, perda_conector)`, que devolve
# a perda total em dB, arredondada para duas casas.
#
# ```python
# atenuacao_total(10, 0.35, 4, 0.5)  # -> 5.5
# ```

# %%
def atenuacao_total(km, db_por_km, conectores, perda_conector):
    """Perda total do enlace, em dB: cabo mais conectores."""
    # TODO: some a perda do cabo com a perda de todos os conectores
    pass

# %%
# Célula de teste — Exercício 04
assert atenuacao_total(10, 0.35, 4, 0.5) == 5.5
assert atenuacao_total(0, 0.35, 0, 0.5) == 0.0
assert atenuacao_total(20, 0.2, 2, 0.75) == 5.5
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# A **margem** de um enlace é o quanto de folga sobra depois de descontar todas as
# perdas: o que chega ao receptor menos o mínimo que ele consegue entender
# (a *sensibilidade*). Margem negativa significa enlace que não fecha.
#
# Escreva `margem_enlace(potencia_tx, perdas, sensibilidade)`, com o resultado
# arredondado para duas casas.
#
# ```python
# margem_enlace(3, 5.5, -21)   # -> 18.5
# margem_enlace(-10, 20, -21)  # -> -9.0
# ```

# %%
def margem_enlace(potencia_tx, perdas, sensibilidade):
    """Folga do enlace, em dB. Negativa significa que o enlace não fecha."""
    # TODO: potência que chega menos a sensibilidade do receptor
    pass

# %%
# Célula de teste — Exercício 05
assert margem_enlace(3, 5.5, -21) == 18.5
assert margem_enlace(-10, 20, -21) == -9.0
assert margem_enlace(0, 21, -21) == 0.0
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# Escreva `percentual(parte, total)`, que devolve quanto `parte` representa de
# `total`, em porcentagem, arredondado para duas casas.
#
# Atenção ao caso que derruba o programa em produção: **se `total` for zero,
# devolva `0.0`** em vez de deixar o Python levantar `ZeroDivisionError`.
#
# ```python
# percentual(3, 4)   # -> 75.0
# percentual(0, 0)   # -> 0.0
# ```

# %%
def percentual(parte, total):
    """Quanto `parte` representa de `total`, em %. Devolve 0.0 se total for 0."""
    # TODO: trate o total zerado antes de dividir
    pass

# %%
# Célula de teste — Exercício 06
assert percentual(3, 4) == 75.0
assert percentual(1, 3) == 33.33
assert percentual(0, 0) == 0.0
assert percentual(5, 0) == 0.0
assert percentual(0, 10) == 0.0
print("Exercício 06: todos os testes passaram!")

# %% [markdown]
# ### Exercício 07
#
# Relatório que se lê rápido é relatório com número alinhado e casas decimais
# constantes. Escreva `formata_potencia(valor)`, que devolve uma **string** com o
# valor em duas casas decimais seguido de ` dBm`.
#
# ```python
# formata_potencia(-21.5)    # -> "-21.50 dBm"
# formata_potencia(3)        # -> "3.00 dBm"
# ```
#
# Dica: dentro de uma f-string, `f"{valor:.2f}"` já faz o arredondamento.

# %%
def formata_potencia(valor):
    """Devolve o valor formatado com duas casas e a unidade dBm."""
    # TODO: use uma f-string com :.2f
    pass

# %%
# Célula de teste — Exercício 07
assert formata_potencia(-21.5) == "-21.50 dBm"
assert formata_potencia(3) == "3.00 dBm"
assert formata_potencia(-7.126) == "-7.13 dBm"
assert formata_potencia(0) == "0.00 dBm"
print("Exercício 07: todos os testes passaram!")

# %% [markdown]
# ### Exercício 08
#
# Numa rede GPON, a potência óptica que chega à ONU do assinante costuma ser
# classificada por faixas. Escreva `classifica_sinal(dbm)` seguindo esta regra:
#
# | Faixa | Devolve |
# |---|---|
# | maior ou igual a `-8` | `"alto demais"` |
# | de `-8` (exclusive) até `-25` | `"bom"` |
# | menor que `-25` até `-27` | `"limite"` |
# | menor que `-27` | `"sem sinal"` |
#
# ```python
# classifica_sinal(-3)    # -> "alto demais"
# classifica_sinal(-21)   # -> "bom"
# classifica_sinal(-26)   # -> "limite"
# classifica_sinal(-30)   # -> "sem sinal"
# ```

# %%
def classifica_sinal(dbm):
    """Classifica a potência óptica recebida pela ONU."""
    # TODO: encadeie if / elif / else, do maior para o menor
    pass

# %%
# Célula de teste — Exercício 08
assert classifica_sinal(-3) == "alto demais"
assert classifica_sinal(-8) == "alto demais"
assert classifica_sinal(-21) == "bom"
assert classifica_sinal(-25) == "bom"
assert classifica_sinal(-26) == "limite"
assert classifica_sinal(-27) == "limite"
assert classifica_sinal(-30) == "sem sinal"
print("Exercício 08: todos os testes passaram!")

# %% [markdown]
# ### Exercício 09
#
# O tempo de indisponibilidade de um enlace chega do sistema em segundos, mas o
# relatório precisa dele no formato `HH:MM:SS`, com dois dígitos em cada campo.
#
# Escreva `converte_segundos(total)`.
#
# ```python
# converte_segundos(3661)   # -> "01:01:01"
# converte_segundos(59)     # -> "00:00:59"
# converte_segundos(86399)  # -> "23:59:59"
# ```
#
# Dica: `//` é a divisão inteira e `%` é o resto. Numa f-string, `f"{h:02d}"`
# completa com zero à esquerda.

# %%
def converte_segundos(total):
    """Converte uma quantidade de segundos para o formato HH:MM:SS."""
    # TODO: use // e % para separar horas, minutos e segundos
    pass

# %%
# Célula de teste — Exercício 09
assert converte_segundos(3661) == "01:01:01"
assert converte_segundos(59) == "00:00:59"
assert converte_segundos(0) == "00:00:00"
assert converte_segundos(86399) == "23:59:59"
assert converte_segundos(600) == "00:10:00"
print("Exercício 09: todos os testes passaram!")

# %% [markdown]
# ### Exercício 10
#
# Um enlace ficou fora do ar por `segundos_fora` num mês de `dias` dias. Escreva
# `disponibilidade(segundos_fora, dias)`, que devolve a disponibilidade em
# porcentagem, **com quatro casas decimais** — porque em telecom a diferença entre
# 99,9% e 99,99% é a diferença entre nove horas e cinquenta minutos de queda por
# ano.
#
# ```python
# disponibilidade(0, 30)       # -> 100.0
# disponibilidade(2592, 30)    # -> 99.9
# ```

# %%
def disponibilidade(segundos_fora, dias):
    """Disponibilidade do enlace no período, em %, com quatro casas."""
    # TODO: quantos segundos tem o período? quanto disso ficou no ar?
    pass

# %%
# Célula de teste — Exercício 10
assert disponibilidade(0, 30) == 100.0
assert disponibilidade(2592, 30) == 99.9
assert disponibilidade(259.2, 30) == 99.99
assert disponibilidade(86400, 30) == 96.6667
print("Exercício 10: todos os testes passaram!")
