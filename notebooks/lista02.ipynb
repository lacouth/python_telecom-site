# %% [markdown]
# # Lista 02 · Strings: o formato em que a rede fala
#
# Tudo que um equipamento de rede te entrega é texto: uma linha de log, um nome de
# site, um endereço MAC, a saída de um comando. Esta lista treina a operação que
# você vai repetir o curso inteiro — **pegar um texto e extrair dele o pedaço que
# interessa**.
#
# A partir do exercício 04 as questões usam sempre o mesmo formato de log, que é o
# mesmo que você vai processar arquivo adentro na Unidade 3.
#
# ---
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.

# %% [markdown]
# ### Exercício 01
#
# Nomes de equipamento chegam de um jeito quando vêm do formulário do técnico e de
# outro quando vêm do inventário: com espaço sobrando, em minúsculas, misturados.
#
# Escreva `normaliza_site(nome)`, que remove os espaços das pontas e devolve tudo
# em maiúsculas.
#
# ```python
# normaliza_site("  olt-centro-01 ")  # -> "OLT-CENTRO-01"
# ```

# %%
def normaliza_site(nome):
    """Devolve o nome sem espaços nas pontas e todo em maiúsculas."""
    # TODO: .strip() tira os espaços das pontas; .upper() muda a caixa
    pass

# %%
# Célula de teste — Exercício 01
assert normaliza_site("  olt-centro-01 ") == "OLT-CENTRO-01"
assert normaliza_site("OLT-SUL-02") == "OLT-SUL-02"
assert normaliza_site("   ") == ""
assert normaliza_site("onu_cliente 4") == "ONU_CLIENTE 4"
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# O identificador de um equipamento carrega informação: `OLT-CENTRO-01` diz o tipo,
# a localidade e o número. Escreva `partes_do_id(identificador)`, que devolve uma
# **lista** com as três partes separadas pelo hífen.
#
# ```python
# partes_do_id("OLT-CENTRO-01")  # -> ["OLT", "CENTRO", "01"]
# ```

# %%
def partes_do_id(identificador):
    """Separa o identificador nos pedaços delimitados por hífen."""
    # TODO: .split("-") devolve exatamente uma lista
    pass

# %%
# Célula de teste — Exercício 02
assert partes_do_id("OLT-CENTRO-01") == ["OLT", "CENTRO", "01"]
assert partes_do_id("ONU-SUL-4512") == ["ONU", "SUL", "4512"]
assert partes_do_id("SWITCH") == ["SWITCH"]
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# Aproveitando o formato do exercício anterior: escreva `localidade(identificador)`,
# que devolve **só a parte do meio** de um identificador `TIPO-LOCALIDADE-NUMERO`.
#
# ```python
# localidade("OLT-CENTRO-01")  # -> "CENTRO"
# ```
#
# Se o identificador não tiver as três partes, devolva a string vazia.

# %%
def localidade(identificador):
    """Devolve a localidade de um identificador TIPO-LOCALIDADE-NUMERO."""
    # TODO: separe as partes e confira quantas são antes de pegar a do meio
    pass

# %%
# Célula de teste — Exercício 03
assert localidade("OLT-CENTRO-01") == "CENTRO"
assert localidade("ONU-SUL-4512") == "SUL"
assert localidade("SWITCH") == ""
assert localidade("OLT-CENTRO") == ""
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Uma linha do log de alarmes tem sempre este formato, com campos separados por
# espaço:
#
# ```
# 2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal na porta GPON0/1/3
# ```
#
# Escreva `severidade(linha)`, que devolve o terceiro campo — a severidade do
# alarme.
#
# ```python
# severidade("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal")
# # -> "CRITICAL"
# ```

# %%
def severidade(linha):
    """Devolve a severidade (terceiro campo) de uma linha de log."""
    # TODO: .split() sem argumento quebra em qualquer espaço em branco
    pass

# %%
# Célula de teste — Exercício 04
assert severidade("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal") == "CRITICAL"
assert severidade("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 porta ativada") == "INFO"
assert severidade("2026-03-01 23:10:05 WARNING ONU-SUL-4512 sinal degradado") == "WARNING"
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# Ainda no log do exercício anterior: escreva `eh_critico(linha)`, que devolve
# `True` se a severidade da linha for `CRITICAL` e `False` caso contrário.
#
# ```python
# eh_critico("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal")  # -> True
# eh_critico("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 porta ativada")     # -> False
# ```
#
# Cuidado com a tentação de usar `"CRITICAL" in linha`: a palavra pode aparecer no
# texto da mensagem sem ser a severidade — e o último teste cobra exatamente isso.

# %%
def eh_critico(linha):
    """Diz se a severidade da linha é CRITICAL."""
    # TODO: compare o campo de severidade, não a linha inteira
    pass

# %%
# Célula de teste — Exercício 05
assert eh_critico("2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal") is True
assert eh_critico("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 porta ativada") is False
assert eh_critico("2026-03-02 09:00:00 INFO SWITCH-NORTE-02 alarme CRITICAL encerrado") is False
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# Antes de mandar um relatório para fora da empresa, os endereços IP dos clientes
# são mascarados: o último octeto vira `x`.
#
# Escreva `mascara_ip(ip)`.
#
# ```python
# mascara_ip("10.0.3.47")     # -> "10.0.3.x"
# mascara_ip("192.168.1.100") # -> "192.168.1.x"
# ```

# %%
def mascara_ip(ip):
    """Substitui o último octeto do IP por 'x'."""
    # TODO: separe nos pontos, troque a última parte e junte de novo com "."
    pass

# %%
# Célula de teste — Exercício 06
assert mascara_ip("10.0.3.47") == "10.0.3.x"
assert mascara_ip("192.168.1.100") == "192.168.1.x"
assert mascara_ip("8.8.8.8") == "8.8.8.x"
print("Exercício 06: todos os testes passaram!")

# %% [markdown]
# ### Exercício 07
#
# O endereço MAC vem do equipamento como doze caracteres colados e em minúsculas.
# O padrão do relatório é em maiúsculas e separado por dois-pontos.
#
# Escreva `formata_mac(mac)`.
#
# ```python
# formata_mac("00aabbccddee")  # -> "00:AA:BB:CC:DD:EE"
# ```
#
# Dica: pegue os pedaços de dois em dois com fatiamento — `mac[0:2]`, `mac[2:4]`…

# %%
def formata_mac(mac):
    """Formata doze caracteres hexadecimais como um MAC AA:BB:CC:DD:EE:FF."""
    # TODO: seis pedaços de dois caracteres, em maiúsculas, unidos por ":"
    pass

# %%
# Célula de teste — Exercício 07
assert formata_mac("00aabbccddee") == "00:AA:BB:CC:DD:EE"
assert formata_mac("001A2B3C4D5E") == "00:1A:2B:3C:4D:5E"
assert formata_mac("ffffffffffff") == "FF:FF:FF:FF:FF:FF"
print("Exercício 07: todos os testes passaram!")

# %% [markdown]
# ### Exercício 08
#
# Escreva `conta_reinicios(texto, equipamento)`, que devolve quantas vezes o nome
# do equipamento aparece num bloco de log.
#
# ```python
# log = "OLT-SUL-02 reiniciou\nONU-SUL-9 caiu\nOLT-SUL-02 reiniciou"
# conta_reinicios(log, "OLT-SUL-02")  # -> 2
# ```

# %%
def conta_reinicios(texto, equipamento):
    """Quantas vezes o nome do equipamento aparece no texto."""
    # TODO: strings têm um método que conta ocorrências
    pass

# %%
# Célula de teste — Exercício 08
log = "OLT-SUL-02 reiniciou\nONU-SUL-9 caiu\nOLT-SUL-02 reiniciou"
assert conta_reinicios(log, "OLT-SUL-02") == 2
assert conta_reinicios(log, "ONU-SUL-9") == 1
assert conta_reinicios(log, "OLT-NORTE-01") == 0
assert conta_reinicios("", "OLT-SUL-02") == 0
print("Exercício 08: todos os testes passaram!")

# %% [markdown]
# ### Exercício 09
#
# O inventário antigo gravava todo equipamento com o prefixo `NE_` (de *network
# element*). O novo não usa mais esse prefixo, mas os dois convivem na migração.
#
# Escreva `remove_prefixo(nome, prefixo)`, que remove o prefixo **se ele estiver
# lá** e devolve o nome inalterado caso contrário.
#
# ```python
# remove_prefixo("NE_OLT-CENTRO-01", "NE_")  # -> "OLT-CENTRO-01"
# remove_prefixo("OLT-CENTRO-01", "NE_")     # -> "OLT-CENTRO-01"
# ```

# %%
def remove_prefixo(nome, prefixo):
    """Remove o prefixo do nome, se ele existir."""
    # TODO: .startswith() responde se o prefixo está lá; o fatiamento corta
    pass

# %%
# Célula de teste — Exercício 09
assert remove_prefixo("NE_OLT-CENTRO-01", "NE_") == "OLT-CENTRO-01"
assert remove_prefixo("OLT-CENTRO-01", "NE_") == "OLT-CENTRO-01"
assert remove_prefixo("NE_NE_X", "NE_") == "NE_X"
assert remove_prefixo("", "NE_") == ""
print("Exercício 09: todos os testes passaram!")

# %% [markdown]
# ### Exercício 10
#
# Junte formatação de número e de texto: escreva `linha_relatorio(site, potencia)`,
# que devolve uma linha com o nome do site ocupando **16 colunas à esquerda** e a
# potência ocupando **8 colunas à direita**, com duas casas decimais.
#
# ```python
# linha_relatorio("OLT-CENTRO-01", -21.456)
# # -> "OLT-CENTRO-01     -21.46"
# ```
#
# Dica: dentro da f-string, `{site:<16}` alinha à esquerda em 16 colunas e
# `{potencia:>8.2f}` alinha à direita em 8 colunas com duas casas.

# %%
def linha_relatorio(site, potencia):
    """Monta uma linha de relatório com colunas de largura fixa."""
    # TODO: uma única f-string resolve
    pass

# %%
# Célula de teste — Exercício 10
assert linha_relatorio("OLT-CENTRO-01", -21.456) == "OLT-CENTRO-01     -21.46"
assert linha_relatorio("ONU-1", 0) == "ONU-1               0.00"
assert len(linha_relatorio("OLT-CENTRO-01", -21.456)) == 24
assert len(linha_relatorio("X", 1)) == 24
print("Exercício 10: todos os testes passaram!")
