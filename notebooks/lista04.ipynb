# %% [markdown]
# # Lista 04 · Funções: dividir para conseguir testar
#
# Você já escrevia funções antes deste curso. O que esta lista acrescenta é o que
# faz diferença num programa que outra pessoa vai ler: **valor padrão**, **retorno
# de mais de um valor**, **função que chama função** e a decisão mais importante de
# todas — a sua função **altera** o que recebeu ou **devolve** algo novo?
#
# O exercício 10 junta tudo: ele é, em miniatura, o relatório que o projeto final
# vai produzir.
#
# ---
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.

# %% [markdown]
# ### Exercício 01
#
# Escreva `aplica_ganho(potencia, ganho=0.0)`, que soma um ganho à potência e
# devolve o resultado com duas casas. O parâmetro `ganho` tem **valor padrão**: se
# quem chama não informar, vale `0.0`.
#
# ```python
# aplica_ganho(-21.5, 3)   # -> -18.5
# aplica_ganho(-21.5)      # -> -21.5
# ```

# %%
def aplica_ganho(potencia, ganho=0.0):
    """Soma o ganho à potência, com duas casas decimais."""
    # TODO: uma linha
    pass

# %%
# Célula de teste — Exercício 01
assert aplica_ganho(-21.5, 3) == -18.5
assert aplica_ganho(-21.5) == -21.5
assert aplica_ganho(0, -1.25) == -1.25
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# Uma função pode devolver mais de um valor de uma vez: basta separá-los por
# vírgula, e quem chama recebe uma **tupla**.
#
# Escreva `min_max(valores)`, que devolve `(menor, maior)`. Para a lista vazia,
# devolva `(None, None)`.
#
# ```python
# menor, maior = min_max([-21.0, -27.5, -19.0])
# # menor -> -27.5, maior -> -19.0
# ```

# %%
def min_max(valores):
    """Devolve (menor, maior) da lista, ou (None, None) se ela estiver vazia."""
    # TODO: um laço só resolve os dois; devolva os dois separados por vírgula
    pass

# %%
# Célula de teste — Exercício 02
assert min_max([-21.0, -27.5, -19.0]) == (-27.5, -19.0)
assert min_max([5]) == (5, 5)
assert min_max([]) == (None, None)
menor, maior = min_max([1, 2, 3])
assert menor == 1 and maior == 3
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# Escreva `dentro_da_faixa(valor, minimo=-25.0, maximo=-8.0)`, que devolve `True`
# se o valor estiver **dentro** da faixa (inclusive nas pontas) e `False` caso
# contrário. Os padrões são a faixa aceitável de potência numa ONU.
#
# ```python
# dentro_da_faixa(-21.0)           # -> True
# dentro_da_faixa(-30.0)           # -> False
# dentro_da_faixa(-30.0, -35, -8)  # -> True
# ```

# %%
def dentro_da_faixa(valor, minimo=-25.0, maximo=-8.0):
    """Diz se o valor está entre minimo e maximo, inclusive."""
    # TODO: em Python dá para escrever minimo <= valor <= maximo
    pass

# %%
# Célula de teste — Exercício 03
assert dentro_da_faixa(-21.0) is True
assert dentro_da_faixa(-25.0) is True
assert dentro_da_faixa(-8.0) is True
assert dentro_da_faixa(-30.0) is False
assert dentro_da_faixa(0.0) is False
assert dentro_da_faixa(-30.0, -35, -8) is True
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Escreva `com_margem(valores, margem)`, que devolve uma **nova lista** com a
# margem somada a cada valor. A lista recebida **não pode ser alterada** — os
# testes cobram isso.
#
# ```python
# original = [-21.0, -19.0]
# com_margem(original, -3)   # -> [-24.0, -22.0]
# original                   # -> [-21.0, -19.0], intacta
# ```

# %%
def com_margem(valores, margem):
    """Nova lista com a margem somada a cada valor, sem alterar a original."""
    # TODO: crie uma lista nova; não use valores[i] = ...
    pass

# %%
# Célula de teste — Exercício 04
original = [-21.0, -19.0]
assert com_margem(original, -3) == [-24.0, -22.0]
assert original == [-21.0, -19.0]
assert com_margem([], 5) == []
assert com_margem([0], 0) == [0]
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# Agora o contrário do exercício anterior — e é por isso que ele existe.
#
# Escreva `registra(historico, valor)`, que **acrescenta** o valor à lista recebida
# e devolve a própria lista. Aqui a lista de quem chamou muda mesmo: é o efeito que
# se espera de um histórico.
#
# ```python
# h = [-21.0]
# registra(h, -19.0)   # -> [-21.0, -19.0]
# h                    # -> [-21.0, -19.0], alterada
# ```
#
# !!! warning "Os dois exercícios juntos"
#     A diferença entre o 04 e o 05 não está em Python: está em **decidir** se a sua
#     função altera o que recebeu ou devolve coisa nova. Quem chama precisa saber a
#     resposta — e é a docstring que conta.

# %%
def registra(historico, valor):
    """Acrescenta o valor ao histórico recebido e devolve a mesma lista."""
    # TODO: .append() altera a lista no lugar
    pass

# %%
# Célula de teste — Exercício 05
h = [-21.0]
assert registra(h, -19.0) == [-21.0, -19.0]
assert h == [-21.0, -19.0]
vazia = []
resultado = registra(vazia, 1)
assert resultado is vazia
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# Uma função pode (e deve) chamar outra. Neste exercício você escreve **duas**:
#
# - `classifica(dbm)` — devolve `"bom"` se o valor estiver entre `-25` e `-8`
#   (inclusive), e `"ruim"` caso contrário;
# - `classifica_todos(valores)` — devolve a lista das classificações, usando
#   `classifica` para cada valor.
#
# ```python
# classifica_todos([-21.0, -30.0])  # -> ["bom", "ruim"]
# ```
#
# A segunda função não deve repetir a regra da primeira: a regra mora num lugar só.

# %%
def classifica(dbm):
    """Devolve "bom" se a potência está entre -25 e -8 dBm, senão "ruim"."""
    # TODO
    pass


def classifica_todos(valores):
    """Classifica cada valor da lista, usando classifica()."""
    # TODO: laço, chamada a classifica(), append
    pass

# %%
# Célula de teste — Exercício 06
assert classifica(-21.0) == "bom"
assert classifica(-30.0) == "ruim"
assert classifica(-25.0) == "bom"
assert classifica_todos([-21.0, -30.0]) == ["bom", "ruim"]
assert classifica_todos([]) == []
print("Exercício 06: todos os testes passaram!")

# %% [markdown]
# ### Exercício 07
#
# Escreva `tabela(sites, potencias)`, que recebe duas listas do mesmo tamanho e
# devolve uma lista de linhas formatadas, uma por site — no formato da Lista 02,
# exercício 10: nome em 16 colunas à esquerda, potência em 8 à direita com duas
# casas.
#
# ```python
# tabela(["OLT-A"], [-21.456])
# # -> ["OLT-A             -21.46"]
# ```
#
# Dica: percorra as posições com `range(len(sites))`, ou os pares com
# `zip(sites, potencias)`.

# %%
def tabela(sites, potencias):
    """Uma linha formatada por site, com nome e potência alinhados."""
    # TODO: percorra as duas listas em paralelo
    pass

# %%
# Célula de teste — Exercício 07
assert tabela(["OLT-A"], [-21.456]) == ["OLT-A             -21.46"]
assert tabela([], []) == []
linhas = tabela(["OLT-A", "ONU-1"], [-21.0, -19.5])
assert len(linhas) == 2
assert linhas[1] == "ONU-1             -19.50"
print("Exercício 07: todos os testes passaram!")

# %% [markdown]
# ### Exercício 08
#
# Escreva `conta_se_abaixo(valores, limite=-25.0)`, que conta quantos valores estão
# abaixo do limite — e que **devolve cedo** `0` se a lista estiver vazia, sem nem
# entrar no laço.
#
# ```python
# conta_se_abaixo([-21.0, -27.5])   # -> 1
# conta_se_abaixo([])               # -> 0
# ```
#
# O ponto do exercício é o `return` antecipado: tratar o caso impossível na
# primeira linha deixa o resto da função sem nenhuma condição extra.

# %%
def conta_se_abaixo(valores, limite=-25.0):
    """Quantos valores estão abaixo do limite. Lista vazia devolve 0."""
    # TODO: trate a lista vazia com um return logo no começo
    pass

# %%
# Célula de teste — Exercício 08
assert conta_se_abaixo([-21.0, -27.5]) == 1
assert conta_se_abaixo([]) == 0
assert conta_se_abaixo([-30, -28, -26], -27) == 2
print("Exercício 08: todos os testes passaram!")

# %% [markdown]
# ### Exercício 09
#
# Escreva `estatisticas(valores)`, que devolve a tupla
# `(quantidade, media, menor, maior)` com a média arredondada em duas casas. Para a
# lista vazia, devolva `(0, 0.0, None, None)`.
#
# Use as funções que você já escreveu nesta lista sempre que puder: `min_max` já
# resolve dois dos quatro valores.
#
# ```python
# estatisticas([-21.0, -19.0])  # -> (2, -20.0, -21.0, -19.0)
# ```

# %%
def min_max(valores):
    """Devolve (menor, maior) da lista, ou (None, None) se ela estiver vazia."""
    if not valores:
        return None, None
    return min(valores), max(valores)


def estatisticas(valores):
    """Devolve (quantidade, media, menor, maior) das medições."""
    # TODO: aproveite min_max() acima
    pass

# %%
# Célula de teste — Exercício 09
assert estatisticas([-21.0, -19.0]) == (2, -20.0, -21.0, -19.0)
assert estatisticas([]) == (0, 0.0, None, None)
assert estatisticas([5]) == (1, 5.0, 5, 5)
print("Exercício 09: todos os testes passaram!")

# %% [markdown]
# ### Exercício 10
#
# Feche a unidade montando o relatório inteiro a partir de funções pequenas.
#
# Escreva `relatorio(sites, potencias, limite=-25.0)`, que devolve uma string com
# uma linha por site **abaixo** do limite, e uma última linha com o total. Sites
# dentro da faixa não aparecem.
#
# Cada linha usa o formato da Lista 02, exercício 10: nome em 16 colunas à
# esquerda, potência em 8 colunas à direita com duas casas.
#
# ```python
# relatorio(
#     ["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02", "ONU-LESTE-77"],
#     [-21.0, -27.5, -19.0, -28.1],
# )
# ```
#
# devolve (mostrado aqui já impresso):
#
# ```
# ONU-SUL-4512      -27.50
# ONU-LESTE-77      -28.10
# 2 de 4 fora da faixa
# ```
#
# Se nenhum site estiver fora, a saída é só `"0 de N fora da faixa"`.
#
# Comece decidindo quais funções pequenas você precisa — uma que diz se um valor
# está fora, outra que formata a linha — e só depois monte o relatório com elas.
# Uma função que faz as três coisas ao mesmo tempo funciona, mas é a que você não
# vai conseguir testar por partes.

# %%
def relatorio(sites, potencias, limite=-25.0):
    """Relatório dos sites com potência abaixo do limite, e o total ao final."""
    # TODO: filtre, formate cada linha e acrescente a linha de total
    pass

# %%
# Célula de teste — Exercício 10
esperado = "ONU-SUL-4512      -27.50\nONU-LESTE-77      -28.10\n2 de 4 fora da faixa"
saida = relatorio(
    ["OLT-CENTRO-01", "ONU-SUL-4512", "OLT-NORTE-02", "ONU-LESTE-77"],
    [-21.0, -27.5, -19.0, -28.1],
)
assert saida == esperado
assert relatorio(["A", "B"], [-1.0, -2.0]) == "0 de 2 fora da faixa"
assert relatorio([], []) == "0 de 0 fora da faixa"
print("Exercício 10: todos os testes passaram!")
