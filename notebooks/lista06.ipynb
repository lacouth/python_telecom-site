# %% [markdown]
# # Lista 06 · Conjuntos, tuplas e inventário
#
# Os cinco primeiros exercícios são sobre **comparar coletas**: o que apareceu na
# rede, o que sumiu, o que continua. É a operação que abre o dia num centro de
# operações, e com conjuntos ela cabe em uma linha.
#
# Do exercício 06 em diante, o dado passa a ser o **inventário** — uma lista de
# dicionários, que é o formato em que ele chega de qualquer sistema de gerência. Os
# laços são os mesmos cinco da Lista 03: o que muda é que cada item agora é um
# dicionário, e o `if` olha um campo dele.
#
# ---
#
# **Como usar este caderno:** cada exercício tem duas células. Na primeira,
# escreva a sua solução no lugar do `# TODO`. A segunda tem os testes —
# rode-a e ela diz se a sua função está correta. Não altere a célula de teste.
#
# Se um teste falhar, o Python mostra um `AssertionError` apontando a linha:
# é aquele caso específico que a sua função ainda não atende.
#
# Termo de telecom estranho no enunciado? Veja
# [A rede da Maré Net](https://lacouth.github.io/python_telecom-site/unidade0-primeiros-passos/rede-marenet/) ou o
# [glossário](https://lacouth.github.io/python_telecom-site/apendices/glossario/).

# %% [markdown]
# ### Exercício 01
#
# Escreva `equipamentos_distintos(linhas)`, que devolve a **lista ordenada** dos
# nomes de equipamento que aparecem nas linhas de log, sem repetição.
#
# ```python
# equipamentos_distintos([
#     "2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal",
#     "2026-03-02 10:02:55 CRITICAL OLT-CENTRO-01 temperatura alta",
#     "2026-03-02 09:00:00 INFO ONU-SUL-4512 porta ativada",
# ])
# # -> ["OLT-CENTRO-01", "ONU-SUL-4512"]
# ```
#
# Na Lista 03 você fez isso com um laço e `not in`. Aqui, use conjunto — e lembre
# que ele não tem ordem, por isso o `sorted` no fim.

# %%
def equipamentos_distintos(linhas):
    """Lista ordenada dos equipamentos que aparecem no log, sem repetição."""
    # TODO: acumule num set e devolva sorted(...)
    pass

# %%
# Célula de teste — Exercício 01
linhas = [
    "2026-03-02 14:03:17 CRITICAL OLT-CENTRO-01 perda de sinal",
    "2026-03-02 10:02:55 CRITICAL OLT-CENTRO-01 temperatura alta",
    "2026-03-02 09:00:00 INFO ONU-SUL-4512 porta ativada",
]
assert equipamentos_distintos(linhas) == ["OLT-CENTRO-01", "ONU-SUL-4512"]
assert equipamentos_distintos([]) == []
assert equipamentos_distintos([linhas[0]]) == ["OLT-CENTRO-01"]
print("Exercício 01: todos os testes passaram!")

# %% [markdown]
# ### Exercício 02
#
# Todo dia de manhã a coleta traz a lista de equipamentos que responderam. Comparar
# com a de ontem é o relatório mais útil que existe.
#
# Escreva `apareceram(ontem, hoje)`, que recebe duas listas de nomes e devolve a
# **lista ordenada** dos que estão em `hoje` e não estavam em `ontem`.
#
# ```python
# apareceram(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"])  # -> ["RADIO-C"]
# ```

# %%
def apareceram(ontem, hoje):
    """Equipamentos que estão na coleta de hoje e não estavam na de ontem."""
    # TODO: a diferença entre conjuntos resolve em uma linha
    pass

# %%
# Célula de teste — Exercício 02
assert apareceram(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"]) == ["RADIO-C"]
assert apareceram(["OLT-A"], ["OLT-A"]) == []
assert apareceram([], ["X", "A"]) == ["A", "X"]
assert apareceram(["X"], []) == []
print("Exercício 02: todos os testes passaram!")

# %% [markdown]
# ### Exercício 03
#
# O outro lado do exercício anterior, e o que de fato acorda a equipe de campo:
# escreva `sumiram(ontem, hoje)`, que devolve a lista ordenada dos equipamentos que
# responderam ontem e **não responderam hoje**.
#
# ```python
# sumiram(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"])  # -> ["OLT-B"]
# ```

# %%
def sumiram(ontem, hoje):
    """Equipamentos que responderam ontem e não responderam hoje."""
    # TODO: mesma operação do exercício anterior, com os lados trocados
    pass

# %%
# Célula de teste — Exercício 03
assert sumiram(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"]) == ["OLT-B"]
assert sumiram(["OLT-A"], ["OLT-A"]) == []
assert sumiram(["B", "A"], []) == ["A", "B"]
print("Exercício 03: todos os testes passaram!")

# %% [markdown]
# ### Exercício 04
#
# Escreva `resumo_coleta(ontem, hoje)`, que devolve a **tupla**
# `(quantos_apareceram, quantos_sumiram, quantos_continuam)`.
#
# ```python
# resumo_coleta(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"])  # -> (1, 1, 1)
# ```
#
# Aproveite as operações entre conjuntos: `-` para cada lado e `&` para o que está
# nos dois.

# %%
def resumo_coleta(ontem, hoje):
    """Devolve (apareceram, sumiram, continuam) entre duas coletas."""
    # TODO: três operações de conjunto e um return com vírgulas
    pass

# %%
# Célula de teste — Exercício 04
assert resumo_coleta(["OLT-A", "OLT-B"], ["OLT-A", "RADIO-C"]) == (1, 1, 1)
assert resumo_coleta([], []) == (0, 0, 0)
assert resumo_coleta(["A"], ["A"]) == (0, 0, 1)
novos, perdidos, mantidos = resumo_coleta([], ["A", "B"])
assert novos == 2 and perdidos == 0 and mantidos == 0
print("Exercício 04: todos os testes passaram!")

# %% [markdown]
# ### Exercício 05
#
# Escreva `faixas_livres(usadas, total)`, que recebe a lista das portas já ocupadas
# numa OLT e o número total de portas, e devolve a **lista ordenada** das portas
# livres. As portas são numeradas de `1` a `total`.
#
# ```python
# faixas_livres([1, 3], 5)  # -> [2, 4, 5]
# faixas_livres([], 3)      # -> [1, 2, 3]
# ```
#
# Dica: `set(range(1, total + 1))` é o conjunto de todas as portas.

# %%
def faixas_livres(usadas, total):
    """Portas ainda livres numa OLT de `total` portas."""
    # TODO: todas as portas menos as usadas
    pass

# %%
# Célula de teste — Exercício 05
assert faixas_livres([1, 3], 5) == [2, 4, 5]
assert faixas_livres([], 3) == [1, 2, 3]
assert faixas_livres([1, 2, 3], 3) == []
assert faixas_livres([2, 2, 2], 3) == [1, 3]
print("Exercício 05: todos os testes passaram!")

# %% [markdown]
# ### Exercício 06
#
# A partir daqui os exercícios usam o **inventário**, que é sempre uma lista de
# dicionários:
#
# ```python
# inventario = [
#     {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
#     {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
#     {"nome": "OLT-NORTE-02", "tipo": "OLT", "portas": 8, "em_servico": False},
# ]
# ```
#
# Escreva `nomes_em_servico(inventario)`, que devolve a lista dos nomes dos
# equipamentos com `"em_servico"` verdadeiro, **na ordem do inventário**.
#
# ```python
# nomes_em_servico(inventario)  # -> ["OLT-CENTRO-01", "ONU-SUL-4512"]
# ```
#
# É o padrão do filtro da Lista 03, com dicionários no lugar de números: o `if`
# agora olha um campo (`equipamento["em_servico"]`), e o que entra na lista nova é
# outro campo (`equipamento["nome"]`).

# %%
def nomes_em_servico(inventario):
    """Nomes dos equipamentos em serviço, na ordem do inventário."""
    # TODO: lista nova, laço sobre o inventário, if e append
    pass

# %%
# Célula de teste — Exercício 06
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
    {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
    {"nome": "OLT-NORTE-02", "tipo": "OLT", "portas": 8, "em_servico": False},
]
assert nomes_em_servico(inventario) == ["OLT-CENTRO-01", "ONU-SUL-4512"]
assert nomes_em_servico([]) == []
assert nomes_em_servico([inventario[2]]) == []
print("Exercício 06: todos os testes passaram!")

# %% [markdown]
# ### Exercício 07
#
# Escreva `portas_por_nome(inventario)`, que devolve o dicionário `{nome: portas}` a
# partir do inventário.
#
# ```python
# portas_por_nome(inventario)
# # -> {"OLT-CENTRO-01": 16, "ONU-SUL-4512": 1, "OLT-NORTE-02": 8}
# ```
#
# É a mesma ideia do dicionário indexado por nome do capítulo 6: percorrer a lista
# uma vez e montar um dicionário que responde direto, sem procurar.

# %%
def portas_por_nome(inventario):
    """Devolve {nome: portas} a partir do inventário."""
    # TODO: dicionário vazio, laço, e uma atribuição por equipamento
    pass

# %%
# Célula de teste — Exercício 07
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
    {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
]
assert portas_por_nome(inventario) == {"OLT-CENTRO-01": 16, "ONU-SUL-4512": 1}
assert portas_por_nome([]) == {}
print("Exercício 07: todos os testes passaram!")

# %% [markdown]
# ### Exercício 08
#
# Escreva `tipos_presentes(inventario)`, que devolve a lista ordenada dos **tipos**
# distintos de equipamento no inventário.
#
# ```python
# tipos_presentes(inventario)  # -> ["OLT", "ONU"]
# ```
#
# Nem todo equipamento tem o campo `"tipo"` preenchido: quando faltar, conte-o como
# `"DESCONHECIDO"`.

# %%
def tipos_presentes(inventario):
    """Lista ordenada dos tipos distintos presentes no inventário."""
    # TODO: conjunto vazio com set(), laço com .add(), e sorted() no fim
    pass

# %%
# Célula de teste — Exercício 08
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT"},
    {"nome": "ONU-SUL-4512", "tipo": "ONU"},
    {"nome": "OLT-NORTE-02", "tipo": "OLT"},
    {"nome": "X-1"},
]
assert tipos_presentes(inventario) == ["DESCONHECIDO", "OLT", "ONU"]
assert tipos_presentes([]) == []
assert tipos_presentes([{"nome": "A"}]) == ["DESCONHECIDO"]
print("Exercício 08: todos os testes passaram!")

# %% [markdown]
# ### Exercício 09
#
# Junte agrupamento com estrutura aninhada: escreva
# `portas_por_tipo(inventario)`, que devolve `{tipo: total de portas}`, contando
# **apenas os equipamentos em serviço**.
#
# ```python
# portas_por_tipo(inventario)  # -> {"OLT": 16, "ONU": 1}
# ```
#
# (A `OLT-NORTE-02` do exemplo está fora de serviço, então as 8 portas dela não
# entram.)

# %%
def portas_por_tipo(inventario):
    """Total de portas em serviço, por tipo de equipamento."""
    # TODO: filtre, e some com totais.get(tipo, 0) + portas
    pass

# %%
# Célula de teste — Exercício 09
inventario = [
    {"nome": "OLT-CENTRO-01", "tipo": "OLT", "portas": 16, "em_servico": True},
    {"nome": "ONU-SUL-4512", "tipo": "ONU", "portas": 1, "em_servico": True},
    {"nome": "OLT-NORTE-02", "tipo": "OLT", "portas": 8, "em_servico": False},
]
assert portas_por_tipo(inventario) == {"OLT": 16, "ONU": 1}
assert portas_por_tipo([]) == {}
assert portas_por_tipo([inventario[2]]) == {}
print("Exercício 09: todos os testes passaram!")

# %% [markdown]
# ### Exercício 10
#
# Feche a unidade com o relatório de mudança de inventário. Escreva
# `diferencas(ontem, hoje)`, que recebe dois inventários (listas de dicionários) e
# devolve um **dicionário** com três chaves:
#
# ```python
# {
#     "apareceram": [nomes ordenados],
#     "sumiram": [nomes ordenados],
#     "mudaram_portas": [nomes ordenados],
# }
# ```
#
# `"mudaram_portas"` lista os equipamentos que estão nos dois inventários mas com
# número de portas diferente — é o que, na prática, indica que alguém mexeu no
# equipamento sem avisar.
#
# ```python
# ontem = [{"nome": "OLT-A", "portas": 16}, {"nome": "OLT-B", "portas": 8}]
# hoje  = [{"nome": "OLT-A", "portas": 24}, {"nome": "RADIO-C", "portas": 2}]
#
# diferencas(ontem, hoje)
# # -> {"apareceram": ["RADIO-C"], "sumiram": ["OLT-B"], "mudaram_portas": ["OLT-A"]}
# ```
#
# A função `indexa`, que transforma a lista em `{nome: equipamento}`, já vem escrita
# no esqueleto. Com os dois inventários indexados, `set(antes)` e `set(agora)` são os
# conjuntos de nomes — e aí os exercícios 02, 03 e 04 desta lista respondem duas das
# três perguntas.

# %%
def indexa(inventario):
    """Converte a lista de dicionários em {nome: equipamento}. JÁ ESCRITA."""
    por_nome = {}
    for equipamento in inventario:
        por_nome[equipamento["nome"]] = equipamento
    return por_nome


def diferencas(ontem, hoje):
    """Compara dois inventários: o que apareceu, o que sumiu e o que mudou."""
    # TODO: use indexa() nos dois inventários. As chaves de cada dicionário são
    # os nomes — compare os dois conjuntos de chaves para achar o que apareceu e
    # o que sumiu, e percorra a interseção comparando o número de portas.
    pass

# %%
# Célula de teste — Exercício 10
ontem = [{"nome": "OLT-A", "portas": 16}, {"nome": "OLT-B", "portas": 8}]
hoje = [{"nome": "OLT-A", "portas": 24}, {"nome": "RADIO-C", "portas": 2}]

assert diferencas(ontem, hoje) == {
    "apareceram": ["RADIO-C"],
    "sumiram": ["OLT-B"],
    "mudaram_portas": ["OLT-A"],
}
assert diferencas([], []) == {"apareceram": [], "sumiram": [], "mudaram_portas": []}
assert diferencas(ontem, ontem) == {
    "apareceram": [], "sumiram": [], "mudaram_portas": []
}
print("Exercício 10: todos os testes passaram!")
