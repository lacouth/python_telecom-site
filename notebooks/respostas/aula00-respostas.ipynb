# %% [markdown]
# # Aula 00 · Respostas dos 🎯
#
# Uma solução para cada exercício 🎯 do caderno de estudo 00 (Primeiros passos em programação).
#
# **Tente antes de abrir.** Olhar a solução antes de tentar troca o exercício por uma
# leitura — e é a tentativa, inclusive a errada, que fixa. Se travar, use primeiro a
# 💡 Dica do próprio caderno.
#
# Para conferir uma solução, copie-a para a célula do exercício no caderno de estudo
# (depois de rodar a célula ⚙️ de lá) e rode o `confere`. Há outras soluções certas:
# se o seu `confere` deu ✅, a sua também está.

# %% [markdown]
# ## 🎯 Clientes da OLT

# %%
portas = 16
por_porta = 32
total = portas * por_porta

# %% [markdown]
# ## 🎯 Sinal fraco?

# %%
potencia = -28.3
fraco = potencia < -27

# %% [markdown]
# ## 🎯 Classificando uma medição

# %%
potencia = -25.5
if potencia >= -25:
    situacao = "bom"
elif potencia >= -27:
    situacao = "atencao"
else:
    situacao = "critico"

# %% [markdown]
# ## 🎯 Somando de 1 a 10

# %%
soma = 0
for numero in range(1, 11):
    soma = soma + numero

# %% [markdown]
# ## 🎯 Margem suficiente

# %%
def margem_ok(potencia, sensibilidade):
    margem = potencia - sensibilidade
    return margem >= 3

# %% [markdown]
# ## 🎯 Quantas ONUs críticas

# %%
def quantas_criticas(medicoes):
    criticas = 0
    for potencia in medicoes:
        if potencia < -27:
            criticas = criticas + 1
    return criticas
